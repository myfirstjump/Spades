# %%
# Booking hotel crawler
import requests
import time
from bs4 import BeautifulSoup
from collections import Counter
import re
import time

# %%
# data
data = {'aid':304142,
'label':'gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AED6AEBkgIBeagCAw',
'sid':'25f3195cbf76726e8ffac861269a0d24',
'checkin_month':8,
'checkin_monthday':24,
'checkin_year':2017,
'checkout_month':8,
'checkout_monthday':27,
'checkout_year':2017,
'class_interval':1,
'dest_id':-235402,
'dest_type':'city',
'dtdisc':0,
'group_adults':2,
'group_children':0,
'inac':0,
'index_postcard':0,
'label_click':'undef',
'no_rooms':1,
'postcard':0,
'raw_dest_type':'city',
'room1':'A,A',
'sb_price_type':'total',
'src':'index',
'src_elem':'sb',
'ss':'京都',
'ss_all':0,
'ssb':'empty',
'sshis':0,
'ssne':'京都',
'ssne_untouched':'京都',
'rows':40,
'offset':40,
'sr_ajax':1,
'b_gtt':'dLYAeZFVJfNTBdAHUdPHUBSSUVJfcbWYaNLDRCAET',
'_':1501060181667}


# headers

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}

#cookies

#cookie = {'Cookie':'zz_cook_tms_seg1=1; zz_cook_tms_seg3=5; header_signin_prompt=1; zz_cook_tms_ed=1; b1577f1603e12140d61ae5e8237aafdd=1; _ga=GA1.2.2067083198.1501046935; _gid=GA1.2.832559918.1501046935; BJS=-; has_preloaded=1; utag_main=v_id:015d7d5e90a50053be3f16ff21e80407200f506a00bd0$_sn:1$_ss:0$_st:1501063966716$4split:0$4split2:0$ses_id:1501046935719%3Bexp-session$_pn:24%3Bexp-session; bkng=11UmFuZG9tSVYkc2RlIyh9Yaa29%2F3xUOLbXpFeYC4TUhAJbaRO0jw2RDQsK5U5lBnZtZNYGGQ5Gwk68y4W5EpWdnDv%2Bl0uPZZ%2BX1kzZwIkbIaPcI%2FOB5CMfmR4pBZuFxwalc68jMR7N166r7QJFNHMrgySfuLcxZhRTkuTBKFXoggwF0EKZ8wYuuOOmmdrqiT22TD6yXtx3e4%3D; lastSeen=0; _gat=1'}

# cookie = {"Cookie":"zz_cook_tms_seg1=1; zz_cook_tms_seg3=5; has_preloaded=1; _ga=GA1.2.617223965.1501072140; _gid=GA1.2.315956932.1501215224; BJS=-; utag_main=v_id:015d7edf2a44007b7b194d6dded40407200b206a00bd0$_sn:4$_ss:1$_st:1501242420861$4split:3$4split2:1$ses_id:1501240620861%3Bexp-session$_pn:1%3Bexp-session; zz_cook_tms_ed=1; lastSeen=0; bkng=11UmFuZG9tSVYkc2RlIyh9YXjA6rtNF48dyfPzTHjBgvt%2FIVpKUxnIIdmW5HiPo3iIc4z4y7a6byDyavBWUBBW%2FJLa53WkC0SqN4DRsqeY9GKM1hkjaVaNzkBI%2FUMUfIAa9UNImEbe%2FnhVc%2BTFQ475OVhuJx01f36TW6ZFdUTcp7BNtMzT0mxFZWg5w9r7m2nl5j3g6X0gYVo%3D; _gat=1"}

cookie = {"Cookie":"zz_cook_tms_seg1=1; zz_cook_tms_seg3=5; has_preloaded=1; vpmss=1; zz_cook_tms_ed=1; _ga=GA1.2.617223965.1501072140; _gid=GA1.2.315956932.1501215224; _gat=1; BJS=-; lastSeen=0; utag_main=v_id:015d7edf2a44007b7b194d6dded40407200b206a00bd0$_sn:5$_ss:0$_st:1501247843531$4split:3$4split2:1$ses_id:1501244519782%3Bexp-session$_pn:3%3Bexp-session; bkng=11UmFuZG9tSVYkc2RlIyh9YfDNyGw8J7nzPnUG3Pr%2Bfv5Y5jNyxUPvdeKQu5iVwt17XmMLPaXKA5hcphCYbgaBrmmkrZkrhCSJw9fRMREyw3M8J7FCCG5OJ3%2Fzjs8FbAwhwKCd8rCZyhS%2BuUdxY%2BXMcgDxQbI07Bdc6abY3amdrgHL98F1CMeKrsCdAiY29xmUMWPnihzNxA0PNzJf%2BKy%2FQQ%3D%3D"}

# %%
cookie = {'Cookie':'zz_cook_tms_seg1=1; zz_cook_tms_seg3=5; header_signin_prompt=1; zz_cook_tms_ed=1; b1577f1603e12140d61ae5e8237aafdd=1; _ga=GA1.2.2067083198.1501046935; _gid=GA1.2.832559918.1501046935; BJS=-; has_preloaded=1; utag_main=v_id:015d7d5e90a50053be3f16ff21e80407200f506a00bd0$_sn:1$_ss:0$_st:1501063966716$4split:0$4split2:0$ses_id:1501046935719%3Bexp-session$_pn:24%3Bexp-session; bkng=11UmFuZG9tSVYkc2RlIyh9YfDNyGw8J7nzPnUG3Pr%2Bfv5IP%2FgNoyK0ntemXCDrSx%2FNQiovwPBBOoSUWAO0z9OynWDIbkBUXRY9tbJ8J5XtZ2D%2Ft8gWGoF3tivcrjOBL25%2Fy0uY%2Fvv7xGQzkCOEM%2FHIWTJUQaQy0wG28IyTfW%2F4itrYlp7tTUA5%2BaTqraLdpsxaJGp4YY9zMUDNMX5mfTyUhw%3D%3D; lastSeen=0; _gat=1'}

# %%
url = "https://www.booking.com/searchresults.zh-tw.html?checkin_month=10&checkin_monthday=19&checkin_year=2017&checkout_month=10&checkout_monthday=21&checkout_year=2017&class_interval=1&dest_id=-235402&dest_type=city&dtdisc=0&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&src=index&src_elem=sb&ss=%E4%BA%AC%E9%83%BD&ss_all=0&ss_raw=%E4%BA%AC%E9%83%BD&ssb=empty&sshis=0&rows=15&offset=0" 

###label=gen173nr-1FCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AEB6AEB-AELkgIBeagCAw&sid=a183ce86441ca9e2215ac7f0e3245379&

# %%
 
res = requests.get(url, headers = headers, cookies = cookie)
soup = BeautifulSoup(res.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# http://www.workingatbooking.com/
# --><!-- wdot-802 --><html class="noJS b_chrome b_chrome_59 supports_inline-block supports_flexbox_unprefixed supports_fontface " lang="zh-tw" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# booking_com: http://ogp.me/ns/fb/booking_com#">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <link data-main-css="1" href="https://t-ec.bstatic.com/static/css/main_ecv6/4ba4adc63570506adc1c88e5c557e6a65c45e0d9.css" rel="stylesheet"/>
# <link href="https://t-ec.bstatic.com/static/css/main_exps_ecv6/2b77e5e7e5c73ea7a90dab3119f4b2124278e409.css" rel="stylesheet"/>
# <link href="https://s-ec.bstatic.com/static/css/gprof_icons_ecv6/d8437889195bb88373b7c4559c811a71240af440.css" rel="stylesheet"/>
# <link href="https://s-ec.bstatic.com/static/css/searchresults_ecv6/284ae0523e399c55253945ab828945672e0bd179.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://t-ec.bstatic.com/static/css/mlt_ecv6/b0b01ece4837faaae07eb1a6e5198fc68c0459bd.css" rel="stylesheet"/> <!--[if IE 9]> <link rel="stylesheet" href="https://t-ec.bstatic.com/static/css/ie9lte/883f9ea1c58a3c3f440b17d92b198ae72c8ecb80.css" media="screen" /> <![endif]--> <!--[if IE 8]> <link rel="stylesheet" href="https://t-ec.bstatic.com/static/css/ie8lte_bundle/346b0ce385880c1245df61cc2abbbed67dc5c562.css" media="screen" /> <![endif]--> <!--[if IE 7]> <link rel="stylesheet" href="https://t-ec.bstatic.com/static/css/ie7lte_bundle/06559b6fbeeb53fb7ad88bb3e0dddc2c6d38fd0c.css" media="screen" /> <![endif]-->
# <style> #basiclayout { margin: 0px 0 0 0; } .breadcrumb { padding-left:7px; } #special_actions { margin: 3px 15px 3px 0; } .ticker_space { margin-top: 3px !important; } #logo_no_globe_new_logo { top: 14px; } .b_msie_6 #top, .b_msie_6 body.header_reshuffle #top {height:61px !important;} .b_msie_6 #special_actions { margin: 3px 15px 3px 0; overflow:visible; } body.header_reshuffle #top { min-height: 50px !important; height: 50px !important; } .nobg { background: #fff url("https://t-ec.bstatic.com/static/img/nobg_all_blue_iq/b700d9e3067c1186a3364012df4fe1c48ae6da44.png") repeat-x; background-position: 0 -50px; } </style> <link href="https://t-ec.bstatic.com/static/css/cjk/56798fca060f9e87fb2163bc0971be993ce46d37.css" rel="stylesheet"/>
# <link href="https://t-ec.bstatic.com/static/css/iq_overrides_ecv6/f43e5f1c8bf90084ced1a75ab0f2990fe8fcf3ae.css" rel="stylesheet" type="text/css"/>
# <script> if( window.performance && performance.measure && 'b-stylesheets') { performance.measure('b-stylesheets'); } </script>
# <title>
#   Booking.com :  位於京都的飯店.  現在就預訂飯店！
# </title>
# <meta content="飯店, 京都,  飯店, 住宿, 特別優惠，配套，特別，周末休息，城市休息，交易, 預算，便宜，折扣，省錢" name="keywords"/>
# <meta content="index,follow" name="robots"/>
# <link href="https://www.booking.com/searchresults.zh-tw.html?city=-235402" rel="canonical"/>
# <meta content="367003839" name="twitter:app:id:iphone"/>
# <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
# <meta content="367003839" name="twitter:app:id:ipad"/>
# <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
# <meta content="com.booking" name="twitter:app:id:googleplay"/>
# <meta content="367003839" property="al:ios:app_store_id"/>
# <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
# <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
# <meta content="com.booking" property="al:android:package"/>
# <meta content="位於京都的飯店" name="twitter:title"/>
# <meta content="booking://searchresults?dest_id=-235402&amp;dest_type=city&amp;affiliate_id=375119" property="al:ios:url"/>
# <meta content="booking://searchresults?dest_id=-235402&amp;dest_type=city&amp;affiliate_id=375119" property="al:android:url"/>
# <meta content="ff7f0b90ebb93e5bf7c7cafe77640ec1" name="p:domain_verify"/>
# <meta content="zh-tw" http-equiv="content-language"/>
# <meta content="text/javascript" http-equiv="content-script-type"/>
# <meta content="text/css" http-equiv="content-style-type"/>
# <meta content="_top" http-equiv="window-target"/>
# <meta content="48970bbca45d28c2" property="wb:webmaster"/>
# <meta content="city" property="og:type"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@bookingcom" name="twitter:site"/>
# <meta content="@bookingcom" name="twitter:creator"/>
# <meta content="請推薦最佳的飯店" property="og:title"/>
# <meta content="我在Booking.com 發現了多家喜愛的飯店。請幫我決定要預訂哪一家吧！" property="og:description"/>
# <meta content="zh-tw" property="og:locale"/>
# <meta content="https://www.booking.com/searchresults.zh-tw.html?dest_id=-235402;dest_type=city;ss=%25E4%25BA%25AC%25E9%2583%25BD" property="og:url"/>
# <meta content="Booking.com" property="og:site_name"/>
# <meta content="145362478954725" property="fb:app_id"/>
# <link href="https://www.booking.com/searchresults.zh-tw.html?dest_id=-235402;dest_type=city;offset=30;ss=%E4%BA%AC%E9%83%BD" rel="next"/>
# <link href="https://www.booking.com/searchresults.id.html?city=-235402" hreflang="id" rel="alternate" title="Bahasa Indonesia" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ms.html?city=-235402" hreflang="ms" rel="alternate" title="Bahasa Malaysia" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ca.html?city=-235402" hreflang="ca" rel="alternate" title="Català" type="text/html"/>
# <link href="https://www.booking.com/searchresults.cs.html?city=-235402" hreflang="cs" rel="alternate" title="Čeština" type="text/html"/>
# <link href="https://www.booking.com/searchresults.de.html?city=-235402" hreflang="de" rel="alternate" title="Deutsch" type="text/html"/>
# <link href="https://www.booking.com/searchresults.da.html?city=-235402" hreflang="da" rel="alternate" title="Dansk" type="text/html"/>
# <link href="https://www.booking.com/searchresults.et.html?city=-235402" hreflang="et" rel="alternate" title="Eesti" type="text/html"/>
# <link href="https://www.booking.com/searchresults.es.html?city=-235402" hreflang="es" rel="alternate" title="Español" type="text/html"/>
# <link href="https://www.booking.com/searchresults.es-ar.html?city=-235402" hreflang="es-ar" rel="alternate" title="Español (AR)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.en-gb.html?city=-235402" hreflang="en-gb" rel="alternate" title="English (UK)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.html?city=-235402" hreflang="en-us" rel="alternate" title="English (US)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.el.html?city=-235402" hreflang="el" rel="alternate" title="Ελληνικά" type="text/html"/>
# <link href="https://www.booking.com/searchresults.fr.html?city=-235402" hreflang="fr" rel="alternate" title="Français" type="text/html"/>
# <link href="https://www.booking.com/searchresults.tl.html?city=-235402" hreflang="tl" rel="alternate" title="Filipino" type="text/html"/>
# <link href="https://www.booking.com/searchresults.hr.html?city=-235402" hreflang="hr" rel="alternate" title="Hrvatski" type="text/html"/>
# <link href="https://www.booking.com/searchresults.it.html?city=-235402" hreflang="it" rel="alternate" title="Italiano" type="text/html"/>
# <link href="https://www.booking.com/searchresults.is.html?city=-235402" hreflang="is" rel="alternate" title="Íslenska" type="text/html"/>
# <link href="https://www.booking.com/searchresults.lv.html?city=-235402" hreflang="lv" rel="alternate" title="Latviski" type="text/html"/>
# <link href="https://www.booking.com/searchresults.lt.html?city=-235402" hreflang="lt" rel="alternate" title="Lietuvių" type="text/html"/>
# <link href="https://www.booking.com/searchresults.hu.html?city=-235402" hreflang="hu" rel="alternate" title="Magyar" type="text/html"/>
# <link href="https://www.booking.com/searchresults.nl.html?city=-235402" hreflang="nl" rel="alternate" title="Nederlands" type="text/html"/>
# <link href="https://www.booking.com/searchresults.no.html?city=-235402" hreflang="no" rel="alternate" title="Norsk" type="text/html"/>
# <link href="https://www.booking.com/searchresults.pl.html?city=-235402" hreflang="pl" rel="alternate" title="Polski" type="text/html"/>
# <link href="https://www.booking.com/searchresults.pt-pt.html?city=-235402" hreflang="pt-pt" rel="alternate" title="Português (PT)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.pt-br.html?city=-235402" hreflang="pt-br" rel="alternate" title="Português (BR)" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ru.html?city=-235402" hreflang="ru" rel="alternate" title="Русский" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ro.html?city=-235402" hreflang="ro" rel="alternate" title="Română" type="text/html"/>
# <link href="https://www.booking.com/searchresults.sr.html?city=-235402" hreflang="sr" rel="alternate" title="Srpski" type="text/html"/>
# <link href="https://www.booking.com/searchresults.fi.html?city=-235402" hreflang="fi" rel="alternate" title="Suomi" type="text/html"/>
# <link href="https://www.booking.com/searchresults.sk.html?city=-235402" hreflang="sk" rel="alternate" title="Slovenčina" type="text/html"/>
# <link href="https://www.booking.com/searchresults.sv.html?city=-235402" hreflang="sv" rel="alternate" title="Svenska" type="text/html"/>
# <link href="https://www.booking.com/searchresults.sl.html?city=-235402" hreflang="sl" rel="alternate" title="Slovenščina" type="text/html"/>
# <link href="https://www.booking.com/searchresults.tr.html?city=-235402" hreflang="tr" rel="alternate" title="Türkçe" type="text/html"/>
# <link href="https://www.booking.com/searchresults.vi.html?city=-235402" hreflang="vi" rel="alternate" title="Tiếng Việt" type="text/html"/>
# <link href="https://www.booking.com/searchresults.bg.html?city=-235402" hreflang="bg" rel="alternate" title="Български" type="text/html"/>
# <link href="https://www.booking.com/searchresults.uk.html?city=-235402" hreflang="uk" rel="alternate" title="Українська" type="text/html"/>
# <link href="https://www.booking.com/searchresults.th.html?city=-235402" hreflang="th" rel="alternate" title="ภาษาไทย" type="text/html"/>
# <link href="https://www.booking.com/searchresults.he.html?city=-235402" hreflang="he" rel="alternate" title="עברית" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ar.html?city=-235402" hreflang="ar" rel="alternate" title="العربية" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ko.html?city=-235402" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
# <link href="https://www.booking.com/searchresults.ja.html?city=-235402" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
# <link href="https://www.booking.com/searchresults.zh-tw.html?city=-235402" hreflang="zh-tw" rel="alternate" title="繁體中文" type="text/html"/>
# <link href="https://www.booking.com/searchresults.zh-cn.html?city=-235402" hreflang="zh-cn" rel="alternate" title="简体中文" type="text/html"/>
# <link href="https://s-ec.bstatic.com/static/img/b25logo/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon"/>
# <link href="https://t-ec.bstatic.com/static/img/apple-touch-icon/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon"/>
# <link href="/faq.zh-tw.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;" rel="help"/>
# <link href="https://t-ec.bstatic.com/static/opensearch/zh-tw/1859581c7130c5b270d62bdba03c8d191f0a6838.xml" rel="search" title="Booking.com網路飯店訂房" type="application/opensearchdescription+xml"/>
# <link href="https://plus.google.com/105443419075154950489" rel="publisher"/>
# <script>
# /*
# */
# (function avoidingXSSviaLocationHash() {
# var location = window.location,
# hash = location.hash,
# xss = /[<>'"]/;
# if (
# xss.test( decodeURIComponent( hash ) ) ||
# xss.test( hash )
# ) {
# location.hash = '';
# }
# })();
# document.documentElement.className = document.documentElement.className.replace('noJS', '') + ' hasJS';
# var sNSExperiments = 'experiments',
# sNSStartup = 'startup',
# sNSExperimentsLoad = 'experiments_load',
# sNSStartupLoad = 'startup_load';
# var b_experiments = {}, WIDTH, B = window.booking = {
# _onfly: [], // "on the fly" functions, will be executed as soon as external js files were loaded
# track: {
# queue: [],
# exp: function(value){
# if(!value) { return false; }
# this.queue.push(value);
# }
# },
# devTools: {
# trackedExperiments: []
# },
# user: {
# },
# env : {
# "b_gtt": 'dLYAeZFVJfNTBdAHUdPHUBFPGVJfcbQNeFJZWJLO',
# "b_action" : 'searchresults',
# "b_secure_domain" : 'https://secure.booking.com',
# "b_site_type" : 'www',
# "b_site_type_id": '1',
# "b_query_params_with_lang_no_ext": '?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24',
# "b_query_params_with_lang_no_ext_enforce_lang_aid_currency": '?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;lang=zh-tw;aid=304142;selected_currency=TWD',
# "b_calendar2" : '1',
# /*
# */
# "b_partner_channel_id": '3',
# "b_bookings_owned": '1',
# "b_real_action" : 'searchresults',
# "b_google_maps_key_params" : 'key=ABQIAAAAEG168dBcRndNV70R9mDglhSZn_smZpFKc3SoS1v7FyDshy3QMxSgeH0qWTH24Gc7je-iJ9DSXiNmcA&amp;client=gme-booking&indexing=true',
# "b_lang" : 'zh',
# "b_checkin_date": '2017-10-19',
# "b_checkout_date": '2017-10-21',
# "b_checkin_checkout_interval": 2,
# "b_has_valid_dates": '1',
# "b_countrycode" : 'jp',
# "b_guest_country" : 'tw',
# "b_locale" : 'zh-tw',
# "date_format_locale" : 'DDD, DD MMMM YYYY',
# "b_lang_for_url" : 'zh-tw',
# "b_this_urchin" : '/searchresults.zh-tw.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM&amp;class_interval=1&amp;dest_id=-235402&amp;dest_type=city&amp;group_adults=2&amp;group_children=0&amp;label_click=undef&amp;no_rooms=1&amp;offset=0&amp;raw_dest_type=city&amp;room1=A%2CA&amp;rows=15&amp;sb_price_type=total&amp;search_selected=1&amp;src=index&amp;src_elem=sb&amp;ss=%E4%BA%AC%E9%83%BD&amp;ss_raw=%E4%BA%AC%E9%83%BD&amp;ssb=empty&&amp;',
# "b_flag_to_suggest" : 'tw',
# "b_companyname" : 'Booking.com',
# "b_partner_vertical" : 'channel_direct',
# b_date_format: {"from_month_with_year":"自 {full_year} {month_name_from}","date_without_year":"{month_name} {day_of_month} 日","date_with_weekday_time_from":"{full_year} 年 {begin_marker}{month_name} {day_of_month} 日{end_marker}，{weekday}（{time} 起）","date_with_weekday_time_until":"{full_year} 年 {begin_marker}{month_name} {day_of_month} 日{end_marker}，{weekday}（{time} 前）","short_month_only":"{short_month_name}","month_with_year":"{full_year} 年 {month_name_with_year_only}","short_date_with_weekday_without_year":"{short_month_name} {day_of_month} 日（{short_weekday}）","date_with_short_weekday_with_year":"{full_year} 年 {month_name} {day_of_month} 日{short_weekday}","numeric_date_range_both_years":"{full_year}/{month}/{day_of_month}－{full_year_until}/{month_until}/{day_of_month_until}","date_with_weekday_to":"{full_year} 年 {month_name_to} {day_of_month} 日（{weekday_to}）","day_of_month_only":"{day_of_month}","numeric_date":"{full_year}/{month}/{day_of_month}","date_with_short_weekday_without_year":"{month_name} {day_of_month} 日{short_weekday}","short_date":"{full_year} 年 {short_month_name} {day_of_month} 日","long_date_range_both_years":"{full_year} 年 {month_name} {day_of_month} 日 － {full_year_until} 年 {day_of_month_until} {month_name_until} 日","in_month_with_year":"於 {full_year} {month_name_in}","date_with_weekday":"{full_year} 年 {month_name} {day_of_month} 日（{weekday}）","numeric_date_range":"{month}/{day_of_month}－{month_until}/{day_of_month_until}","short_date_without_year_range":"{short_month_name} {day_of_month} 日 - {short_month_name_until} {day_of_month_until} 日","range_from_long_date_time_until_long_date_time":"自 {full_year} 年 {month_name} {day_of_month} 日 {time} 至 {full_year_until} 年{month_name_until}   {day_of_month_until} 日 {time_until}","short_weekday_only":"{short_weekday}","short_month_with_year":"{full_year} 年 {short_month_name}","month_name_only":"{month_name_nom}","short_date_with_weekday":"{full_year} 年 {short_month_name} {day_of_month} 日（{short_weekday}）","short_date_without_year":"{short_month_name} {day_of_month} 日","date_with_year":"{full_year} 年 {month_name} {day_of_month} 日","date_with_weekday_with_markers":"{full_year} 年 {begin_marker}{short_month_name} {day_of_month} 日{end_marker} {weekday}","date_with_weekday_from":"{full_year} 年 {month_name_from} {day_of_month} 日（{weekday_from}）"},
# b_month_for_formatted_date: {"5":{"name_to":"5 月","name_only":"5 月","name_from":"5 月","name":"5 月","short_name":"5 月","name_with_year_only":"5 月","name_in":"5 月"},"4":{"name_to":"4 月","name_only":"4 月","name_from":"4 月","name":"4 月","short_name":"4 月","name_with_year_only":"4 月","name_in":"4 月"},"1":{"name_to":"1 月","name_only":"1 月","name_from":"1 月","name":"1 月","short_name":"1 月","name_with_year_only":"1 月","name_in":"1 月"},"11":{"name_to":"11 月","name_only":"11 月","name_from":"11 月","name":"11 月","short_name":"11 月","name_with_year_only":"11 月","name_in":"11 月"},"8":{"name_to":"8 月","name_only":"8 月","name_from":"8 月","name":"8 月","short_name":"8 月","name_with_year_only":"8 月","name_in":"8 月"},"3":{"name_to":"3 月","name_only":"3 月","name_from":"3 月","name":"3 月","short_name":"3 月","name_with_year_only":"3 月","name_in":"3 月"},"6":{"name_to":"6 月","name_only":"6 月","name_from":"6 月","name":"6 月","short_name":"6 月","name_with_year_only":"6 月","name_in":"6 月"},"7":{"name_to":"7 月","name_only":"7 月","name_from":"7 月","name":"7 月","short_name":"7 月","name_with_year_only":"7 月","name_in":"7 月"},"9":{"name_to":"9 月","name_only":"9 月","name_from":"9 月","name":"9 月","short_name":"9 月","name_with_year_only":"9 月","name_in":"9 月"},"10":{"name_to":"10 月","name_only":"10 月","name_from":"10 月","name":"10 月","short_name":"10 月","name_with_year_only":"10 月","name_in":"10 月"},"2":{"name_to":"2 月","name_only":"2 月","name_from":"2 月","name":"2 月","short_name":"2 月","name_with_year_only":"2 月","name_in":"2 月"},"12":{"name_to":"12 月","name_only":"12 月","name_from":"12 月","name":"12 月","short_name":"12 月","name_with_year_only":"12 月","name_in":"12 月"}},
# b_weekday_formatted_date: {"2":{"short":"週二","name_to":"星期二","name_on":"星期二","name_from":"星期二","name":"星期二","shortest":"週二"},"3":{"short":"週三","name_to":"星期三","name_on":"星期三","name_from":"星期三","name":"星期三","shortest":"週三"},"4":{"short":"週四","name_to":"星期四","name_on":"星期四","name_from":"星期四","name":"星期四","shortest":"週四"},"7":{"short":"週日","name_to":"星期日","name_on":"星期日","name_from":"星期日","name":"星期日","shortest":"週日"},"6":{"short":"週六","name_to":"星期六","name_on":"星期六","name_from":"星期六","name":"星期六","shortest":"週六"},"1":{"short":"週一","name_to":"星期一","name_on":"星期一","name_from":"星期一","name":"星期一","shortest":"週一"},"5":{"short":"週五","name_to":"星期五","name_on":"星期五","name_from":"星期五","name":"星期五","shortest":"週五"}},
# b_time_format: {"PM_symbol":{"name":"PM"},"AM_symbol":{"name":"AM"},"time":{"name":"{hour_24h}:{minutes}"}},
# "b_protocol": 'https',
# auth_level : "0",
# b_user_auth_level_is_none : 1,
# bb: {
# ibb: "",
# uibb: "",
# ibbta: "",
# itp: "0",
# iuibb: "",
# bme: "",
# euibb: "0",
# tp: "0"
# },
# b_run_sr_ajax: !!(window.history && window.history.pushState),
# b_run_map_sr_ajax: !!(window.history && window.history.pushState),
# b_destination_fullname: '京都',
# b_growls_close_fast: 1,
# fe_enable_login_with_phone_number: 1,
# asyncLoader: {
# async_wpm_overlay_css: 'https://t-ec.bstatic.com/static/css/async_wpm_overlay_assets_ecv6/9928ef390e005a57bba4b59d8a3df1f2d3160b1c.css',
# async_wpm_overlay_js: 'https://s-ec.bstatic.com/static/js/async_wpm_overlay_assets_ecv6/1305d93cecd75793db1447a45d2a492d87b7837b.js',
# empty: ''
# },
# fe_enable_fps_goal_with_value: 1,
# b_email_validation_regex : /^([\w-\.\+]+@([\w-]+\.)+[\w-]{2,14})?$/,
# b_domain_end : '.booking.com',
# b_original_url : 'https:&#47;&#47;www.booking.com&#47;searchresults.zh-tw.html?checkin_month=10&amp;checkin_monthday=19&amp;checkin_year=2017&amp;checkout_month=10&amp;checkout_monthday=21&amp;checkout_year=2017&amp;class_interval=1&amp;dest_id=-235402&amp;dest_type=city&amp;dtdisc=0&amp;group_adults=2&amp;group_children=0&amp;inac=0&amp;index_postcard=0&amp;label_click=undef&amp;no_rooms=1&amp;postcard=0&amp;raw_dest_type=city&amp;room1=A%2CA&amp;sb_price_type=total&amp;search_selected=1&amp;src=index&amp;src_elem=sb&amp;ss=%E4%BA%AC%E9%83%BD&amp;ss_all=0&amp;ss_raw=%E4%BA%AC%E9%83%BD&amp;ssb=empty&amp;sshis=0&amp;rows=15&amp;offset=0',
# b_this_url : '/searchresults.zh-tw.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# b_this_url_without_lang : '/searchresults.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# b_switch_language_url : {
# 'id' : '/searchresults.id.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=id;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'ms' : '/searchresults.ms.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=ms;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'ca' : '/searchresults.ca.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=ca;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'cs' : '/searchresults.cs.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=cs;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'de' : '/searchresults.de.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=de;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'da' : '/searchresults.da.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=da;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'et' : '/searchresults.et.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=et;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'es' : '/searchresults.es.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=es;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'es-ar' : '/searchresults.es-ar.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=es-ar;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'en-gb' : '/searchresults.en-gb.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=en-gb;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'en-us' : '/searchresults.en-us.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=en-us;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'el' : '/searchresults.el.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=el;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'fr' : '/searchresults.fr.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=fr;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'tl' : '/searchresults.tl.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=tl;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'hr' : '/searchresults.hr.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=hr;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'it' : '/searchresults.it.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=it;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'is' : '/searchresults.is.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=is;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'lv' : '/searchresults.lv.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=lv;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'lt' : '/searchresults.lt.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=lt;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'hu' : '/searchresults.hu.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=hu;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'nl' : '/searchresults.nl.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=nl;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'no' : '/searchresults.no.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=no;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'pl' : '/searchresults.pl.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=pl;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'pt-pt' : '/searchresults.pt-pt.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=pt-pt;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'pt-br' : '/searchresults.pt-br.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=pt-br;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'ru' : '/searchresults.ru.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=ru;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'ro' : '/searchresults.ro.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=ro;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'sr' : '/searchresults.sr.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=sr;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'fi' : '/searchresults.fi.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=fi;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'sk' : '/searchresults.sk.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=sk;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'sv' : '/searchresults.sv.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=sv;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'sl' : '/searchresults.sl.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=sl;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'tr' : '/searchresults.tr.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=tr;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'vi' : '/searchresults.vi.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=vi;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'bg' : '/searchresults.bg.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=bg;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'uk' : '/searchresults.uk.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=uk;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'th' : '/searchresults.th.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=th;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'he' : '/searchresults.he.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=he;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'ar' : '/searchresults.ar.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=ar;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'ko' : '/searchresults.ko.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=ko;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'ja' : '/searchresults.ja.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=ja;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'zh-tw' : '/searchresults.zh-tw.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=zh-tw;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&',
# 'zh-cn' : '/searchresults.zh-cn.html?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin_month=10;checkin_monthday=19;checkin_year=2017;checkout_month=10;checkout_monthday=21;checkout_year=2017;class_interval=1;dest_id=-235402;dest_type=city;group_adults=2;group_children=0;label_click=undef;lang=zh-cn;no_rooms=1;offset=0;raw_dest_type=city;room1=A%2CA;rows=15;sb_price_type=total;search_selected=1;soz=1;src=index;src_elem=sb;ss=%E4%BA%AC%E9%83%BD;ss_raw=%E4%BA%AC%E9%83%BD;ssb=empty&'
# },
# b_referrer : '',
# b_acc_type : '',
# b_req_login: '',
# jst : {'loading': true},
# b_timestamp : 1501244320,
# referal_tab: true,
# scripts_tracking : {
# bhc:{loaded:false,run:false},
# jquery:{loaded:false,run:false},
# main:{loaded:false,run:false},
# calendar2:{loaded:false,run:false},
# searchresults:{loaded:false,run:false},
# atlas:{loaded:false,run:false},
# atlas_cst:{loaded:false,run:false}
# },
# enable_scripts_tracking : 1,
# b_ufi : '-235402',
# "setvar_affiliate_is_bookings2" : 1,
# transl_close_x : '关闭',
# transl_checkin_title: '入住日期',
# transl_checkout_title: '退房日期',
# browser_lang: '',
# b_lang_is_cjk: true,
# b_hijri_calendar_available: false,
# b_aid: '304142',
# b_label: 'gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM',
# b_sid: '25f3195cbf76726e8ffac861269a0d24',
# b_dest_id: '-235402',
# ip_country: 'tw',
# country_currency: 'TWD',
# b_selected_currency: 'TWD',
# b_selected_language: 'zh-tw',
# b_selected_language_country_flag: 'tw',
# b_dest_type: 'city',
# b_go_to_hp_by_hid: '/srla/go_hp?label=gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM;sid=25f3195cbf76726e8ffac861269a0d24;checkin=2017-10-19;checkout=2017-10-21;ucfs=1;srpvid=78a05690bea701d5;highlighted_blocks=35948404_100638693_0_2_0;all_sr_blocks=35948404_100638693_0_2_0;room1=A%2CA;hpos=1;dest_type=city;dest_id=-235402;srfid=b2bedb8de6fb19784ec1995aa5ba361c0779be90X1;aid=304142;stype=1',
# b_filter_currency: 'TWD',
# b_has_filters: 0,
# inline_sort_headers: {
# 'star_track': {
# sortHeader: '依星等排序'
# },
# 'big_review_score_detailed': {
# sortHeader: '依評分排序'
# },
# 'address_text': {
# sortHeader: '依位置排序'
# },
# ...
# <strong>短信验证码已发送</strong><br/>
# 请在下方输入短信验证码。若长时间未收到，请点击重发验证码。
#  </div> </div>
# <div class="fe_banner fe_banner__w-icon fe_banner__red fe_banner__unify js-phone_error_message js-phone_generic_problem g-hidden "> <i class="fe_banner__icon bicon-btnclose"></i> <div class="fe_banner__message">
# <strong>抱歉，出错啦！</strong>
# </div> </div>
# <div class="fe_banner fe_banner__w-icon fe_banner__red fe_banner__unify js-phone_error_message js-phone_already_confirmed g-hidden "> <i class="fe_banner__icon bicon-btnclose"></i> <div class="fe_banner__message">
# <strong>抱歉，出错啦！</strong><br/>
# 请检查手机号码是否填写正确后再试
#  </div> </div>
# <div class="fe_banner fe_banner__w-icon fe_banner__red fe_banner__unify js-phone_error_message js-phone_code_missing g-hidden "> <i class="fe_banner__icon bicon-btnclose"></i> <div class="fe_banner__message">
# <strong>抱歉，出错啦！</strong><br/>
# 请输入验证码
#  </div> </div>
# <div class="fe_banner fe_banner__w-icon fe_banner__red fe_banner__unify js-phone_error_message js-phone_code_wrong g-hidden "> <i class="fe_banner__icon bicon-btnclose"></i> <div class="fe_banner__message">
# <strong>抱歉，出错啦！</strong><br/>
# 验证码错误，请稍后再试
#  </div> </div>
# <h3>验证手机号后即可激活帐号，开始精彩旅程</h3>
# <label class="bootstrapped-label">電話號碼：<strong class="js-verify_phone_number"></strong></label>
# <div class="clearfix"></div>
# <div class="js-verify_phone_confirmation_code_options ">
# 請在此輸入您的驗證碼
# <div class="clearfix"></div>
# <label class="verify_phone_confirmation_label">
# <input class="verify_phone_confirmation_code js-verify_phone_confirmation_code bootstrapped-input input-text input-block-level" data-validation="required{@Please enter a verification code}|numeric" maxlength="80" name="confirmation_code" type="text"/>
# </label>
# <div class="send_verification_code_actions">
# <div class="js-send_verification_code send_verification_code" data-resend-copy="重发验证码">短信获取验证码</div>
# <div class="js-wait_resend_verification_code wait_resend_verification_code g-hidden"><span class="js-resend_cta_countdown_number"></span>秒后重发</div>
# </div>
# <div class="clearfix"></div>
# <input class="bootstrapped-input btn btn-primary b-button_disabled js-send_verification_code_submit" disabled="disabled" type="submit" value="確定"/>
# </div>
# <div class="g-hidden js-verify_phone_confirmation_code_success">
# <div class="fe_banner fe_banner__w-icon fe_banner__green fe_banner__unify "> <i class="fe_banner__icon bicon-checkmark-circle"></i> <div class="fe_banner__message"> 手机号已验证 </div> </div>
# </div>
# <a class="js-phone_number_login_close" href="javascript:void(0)">取消</a>
# </div>
# <div class="user_access_menu_auth_next_step__sms form-section form-hidden-section auth_next_step_sms_verification_form">
# <div class="user_access_menu_auth_next_step__wrapper">
# <div class="alert alert-error" style="display:none;"></div>
# <div class="form-loading"><span class="form-loading-content">加載中...</span></div>
# <form action="#" class="js-auth_next_step__sms_verify_phone_form form-inline__no-block" method="POST"></form>
# <h3>2-Step Verification</h3>
# <label class="auth_next_step_sms_verification_form__code_sent">
# A text message with a 6-digit verification code was just sent to the associated phone.
# </label>
# <div class="clearfix"></div>
# <div class="js-auth_next_step__sms_verify_phone_confirmation_code_options ">
# Please enter your verification code here:
# <div class="clearfix"></div>
# <label class="verify_phone_confirmation_label">
# <input class="verify_phone_confirmation_code js-auth_next_step__sms_verify_phone_confirmation_code bootstrapped-input input-text input-block-level" data-validation="required{@Please enter a verification code}|numeric" maxlength="80" name="confirmation_code" type="text"/>
# </label>
# <div class="send_verification_code_actions">
# <div class="js-auth_next_step__sms_send_verification_code send_verification_code" data-resend-copy="Resend the code">Resend the code</div>
# <div class="js-auth_next_step__sms_wait_resend_verification_code wait_resend_verification_code g-hidden">Please, wait until resend: <span class="js-auth_next_step__sms_resend_cta_countdown_number"></span>s</div>
# </div>
# <div class="clearfix"></div>
# <input class=" bootstrapped-input btn btn-primary js-auth_next_step__sms_send_verification_code_submit" type="submit" value="登入"/>
# </div>
# <div class="g-hidden js-auth_next_step__sms_verify_phone_confirmation_code_success">
# <div class="fe_banner fe_banner__w-icon fe_banner__green fe_banner__unify "> <i class="fe_banner__icon bicon-checkmark-circle"></i> <div class="fe_banner__message"> 手机号已验证 </div> </div>
# </div>
# </div>
# </div>
# <iframe border="0" frameborder="0" height="1" id="log_tar" name="log_tar" src="about:blank" style="height:0px;width:1px;overflow:hidden;visibility:hidden;position:absolute;" width="1"></iframe>
# </div>
# </div>
# </div>
# <div id="logo-not-document-write" style="display: none;"></div>
# <script type="text/javascript">
# setTimeout(function(){
# var img = new Image(1,1);
# img.src = '/logo?ver=1&sid=25f3195cbf76726e8ffac861269a0d24&t='+1501244320+1;
# },0);
# </script>
# <noscript>
# <img src="/logo?ver=0&amp;sid=25f3195cbf76726e8ffac861269a0d24&amp;t=1501244320" style="display:none"/>
# </noscript>
# <div class=" b_map_marker_hover map_container_atlas b_map_custom_zoom map_iw_compact iw_skeleton b_map_br_zoom " id="b_map_container">
# <div class="b_map_controls_container"></div>
# <div id="map_atlas_custom_zoom">
# <a class="map_atlas_custom_zoom_increment notranslate" href="#">
# <span>+</span>
# </a>
# <a class="map_atlas_custom_zoom_decrement notranslate" href="#">
# <span>_</span>
# </a>
# </div>
# <div class="loading_grid_background" id="b_map_tiles">
# <div id="b_gmap_inner"></div>
# <div id="b_overlay"></div>
# <div id="map_detail_overlay"></div>
# </div>
# <div id="b_map_legend_html"></div>
# <div class="t_sr_map_close_button_fix map_close_4d map_close--text " id="close_map_lightbox">
# <span>
# 回到搜尋結果列表
# </span>
# <i class="bicon bicon-aclose"></i>
# </div>
# </div>
# <script type="text/javascript">
# (function(){
# window.lightningjs||function(c){function g(b,d){d&&(d+=(/\?/.test(d)?"&":"?")+"lv=1");c[b]||function(){var i=window,h=document,j=b,g=h.location.protocol,l="load",k=0;(function(){function b(){a.P(l);a.w=1;c[j]("_load")}c[j]=function(){function m(){m.id=e;return c[j].apply(m,arguments)}var b,e=++k;b=this&&this!=i?this.id||0:0;(a.s=a.s||[]).push([e,b,arguments]);m.then=function(b,c,h){var d=a.fh[e]=a.fh[e]||[],j=a.eh[e]=a.eh[e]||[],f=a.ph[e]=a.ph[e]||[];b&&d.push(b);c&&j.push(c);h&&f.push(h);return m};return m};var a=c[j]._={};a.fh={};a.eh={};a.ph={};a.l=d?d.replace(/^\/\//,(g=="https:"?g:"http:")+"//"):d;a.p={0:+new Date};a.P=function(b){a.p[b]=new Date-a.p[0]};a.w&&b();i.addEventListener?i.addEventListener(l,b,!1):i.attachEvent("on"+l,b);var q=function(){function b(){return["\u003Chead\u003E\u003C/head\u003E\u003C",c,' onload="var d=',n,";d.getElementsByTagName('head')[0].",d,"(d.",g,"('script')).",i,"='",a.l,"'\"></",c,">"].join("")}var c="body",e=h[c];if(!e)return setTimeout(q,100);a.P(1);var d="appendChild",g="createElement",i="src",k=h[g]("div"),l=k[d](h[g]("div")),f=h[g]("iframe"),n="document",p;k.style.display="none";e.insertBefore(k,e.firstChild).id=o+"-"+j;f.frameBorder="0";f.id=o+"-frame-"+j;/MSIE[ ]+6/.test(navigator.userAgent)&&(f[i]="javascript:false");f.allowTransparency="true";l[d](f);try{f.contentWindow[n].open()}catch(s){a.domain=h.domain,p="javascript:var d="+n+".open();d.domain='"+h.domain+"';",f[i]=p+"void(0);"}try{var r=f.contentWindow[n];r.write(b());r.close()}catch(t){f[i]=p+'d.write("'+b().replace(/"/g,String.fromCharCode(92)+'"')+'");d.close();'}a.P(2)};a.l&&q()})()}();c[b].lv="1";return c[b]}var o="lightningjs",k=window[o]=g(o);k.require=g;k.modules=c}({});
# function preloadUsabilla(){
# window.usabilla_live = lightningjs.require("usabilla_live", "//w.usabilla.com/78826ff9ad8b.js");
# }
# function onUsabillaClick(event){
# B[sNSStartup].lightbox.hide();
# if (event) {
# $(event.target).closest('.user_center_popover').hide()
# event.preventDefault();
# }
# if (!window.usabilla_live) {
# preloadUsabilla();
# }
# window.usabilla_live('data', { custom: { user_id: ""} });
# window.usabilla_live('data', { custom: { action: "searchresults"} });
# window.usabilla_live('click');
# }
# if(window.$) {
# $('.provide_website_feedback').click(onUsabillaClick);
# }
# (booking.eventEmitter || $( window )).bind('uc_popover_showed', function(event, options){
# if (options.id === 'uc_feedbacklink_box') {
# preloadUsabilla();
# }
# });
# }());
# </script>
# <script type="text/javascript">
# booking.ensureNamespaceExists('env');
# booking.env.google_analytics_tracking_enabled = 1;
# booking.env.b_label = 'gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM';
# booking.env.b_availability_checked = '1';
# booking.env.b_context_details = [];
# booking.env.b_context_details.push( { "b_type" : "city", "b_code" : "-235402" } );
# booking.env.b_multiple_destinations_found = '';
# if (typeof _gaq == 'object' || (window.ga && typeof window.ga === 'function')) {
# booking.ensureNamespaceExists('google');
# if (typeof booking.google.returnAnalyticsTrackingString != 'undefined') {
# booking.google.analyticsTrackingString = booking.google.returnAnalyticsTrackingString();
# }
# try {
# (function(q,u,i,c,k){window['GoogleAnalyticsObject']=q;
# window[q]=window[q]||function(){(window[q].q=window[q].q||[]).push(arguments)},
# window[q].l=1*new Date();c=i.createElement(u),k=i.getElementsByTagName(u)[0];
# c.async=true;c.src='//www.google-analytics.com/analytics.js';
# k.parentNode.insertBefore(c,k)})('ga','script',document);
# ga('create', 'UA-116109-18' ,{
# 'cookieDomain': '.booking.com'
# });
# ga('set', 'location', String(document.location.href).replace(/(auth_key|bn|pin|reset_hash|invitation_token)([^;&]+.)/gi, ''));
# ga('require', 'displayfeatures');
# ga('set', 'anonymizeIp', true);
# (function(){
# if (booking.env.b_group && booking.env.b_group.length) {
# var group = booking.env.b_group,
# g, i, length = group && group.length,
# value = {
# rooms: 1,
# adults: 0,
# children: 0,
# childrenAges: []
# },
# isGroupPresent = length > 1 || ( length === 1 && ( group[0].guests > 2 || group[0].ages.length > 0 ) ) || booking.env.b_group_rooms_wanted > 1;
# for ( i = 0; i < length; i += 1 ) {
# g = group[i];
# value.adults += parseInt(g.guests, 10);
# if (g.ages) for (var j = 0, jc = g.ages.length; j < jc; j++) value.childrenAges.push(g.ages[j].age);
# }
# value.rooms = booking.env.b_group_rooms_wanted || booking.env.bs_room_num || length;
# value.children = value.childrenAges.length;
# value.childrenAges = value.childrenAges.sort(function(a, b){return a - b;});
# booking.env.sGroupConfig = (value.rooms || '1') + ' rooms | ' + (value.adults || '1') + ' adults | ' + value.children + ' kids' + (
# value.children ? ' (' + value.childrenAges.join(' | ') + ')' : ''
# );
# booking.env.isGroupPresent = isGroupPresent;
# if (value.children || value.childrenAges.length > 0) {
# booking.env.ga_group_string = 'Family';
# } else if (value.adults === 1) {
# booking.env.ga_group_string = 'Solo';
# } else if (value.adults === 2) {
# booking.env.ga_group_string = 'Couple';
# } else {
# booking.env.ga_group_string = 'Group';
# }
# } else if(B.env.b_action !== 'index') {
# booking.env.ga_group_string = 'Couple';
# }
# var pageviewInfo = {
# page: booking.google.analyticsTrackingString || '/',
# dimension13: "" + (new Date('2017-10-19').getDay()) + "|" + (new Date('2017-10-21').getDay()),
# dimension14: "83",
# dimension94: "83",
# dimension15: "2",
# dimension95: "2",
# dimension16: "33",
# dimension17: "searchresults|-235402",
# dimension4: "25F3195",
# dimension5: "304142",
# dimension6: "3",
# dimension7: "1",
# dimension8: "gen173nr-1DCAQoggJCDGNpdHlfLTIzNTQwMkgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBA5ICAXmoAgM",
# dimension44: "",
# dimension9: booking.env.sGroupConfig || '',
# dimension11: "desktop",
# dimension12: "zh-tw",
# dimension10: "0",
# dimension29: "0",
# dimension84: "0",
# dimension31: "unknown",
# dimension45: 'tw->jp',
# dimension37: (booking.env.b_guest_country == booking.env.b_countrycode) ? 'domestic' : 'international',
# dimension46: 'city-1000-2000',
# dimension38: "Kyoto",
# dimension39: "Japan",
# dimension41: "-235402",
# dimension42: "Search Results (city)",
# dimension61: "0",
# dimension62: "0",
# dimension63: "1",
# dimension64: '',
# dimension68: "0",
# dimension71: "1",
# dimension107: (function(){try{return parseInt(localStorage['fps_avg'])||''}catch(e){return ''}})(),
# dimension85: booking.env.ga_group_string || '',
# dimension99: booking.env.ga_group_string || '',
# dimension91: "0",
# dimension100: "270",
# dimension199: "null"
# }
# $(window).load(function(){
# if (typeof ga !== 'function') return;
# ga(function(tracker) {
# var clientId = tracker.get('clientId');
# var axel = Math.random() + '';
# var a = axel * 10000000000000;
# var img = new Image(1,1);
# img.src = 'https://4228414.fls.doubleclick.net/activityi;src=4228414;type=audience;cat=mal-g0;u26=' + clientId + ';dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;ord=' + a + '?';
# });
# });
# setTimeout(function() {
# if (typeof ga !== 'function') return;
# try {
# ga(function(tracker) {
# var clientId = tracker.get('clientId');
# ga('set', 'dimension60', clientId);
# });
# if(pageviewInfo.page) {
# ga('set', 'page', pageviewInfo.page);
# }
# pageviewInfo.hitCallback = function () {
# try {
# B.require('ga-tracker').setPageAsTracked();
# } catch (e) {}
# }
# //Fix for https://jira.booking.com/jira/browse/VULN-2615
# //Stop leaking auth key to GA
# if (booking.env.b_action === 'myreservations') {
# var tempUrl = location.href;
# if (tempUrl.indexOf('?') > -1) {
# tempUrl = tempUrl.substr(0, tempUrl.indexOf('?'));
# if (booking.env.b_aid) {
# tempUrl += booking.env.b_query_params_delimiter + 'aid=' + booking.env.b_aid;
# }
# ga('set', 'location', tempUrl);
# }
# }
# ga('send', 'pageview', pageviewInfo);
# } catch (e) {}
# });
# })();
# } catch (err) {
# booking.reportError( err,'google_analytics_include');
# }
# } else {
# pageTracker = {
# _initData : function () { },
# _trackPageview : function () { },
# _setDomainName : function () { },
# _setAllowLinker : function () { },
# _link : function () { },
# _linkByPost : function () { },
# _addTrans : function () { },
# _addItem : function () { },
# _trackTrans : function () { },
# _addOrganic : function () { },
# _setVar : function () { },
# _setCookiePath : function () { },
# _setClientInfo : function () { },
# _setAllowHash : function () { },
# _setDetectFlash : function () { },
# _setDetectTitle : function () { },
# _setSessionTimeout : function () { },
# _setCookieTimeout : function () { },
# _setCampNameKey : function () { },
# _setCampMediumKey : function () { },
# _setCampSourceKey : function () { },
# _setCampTermKey : function () { },
# _setCampContentKey : function () { },
# _setCampIdKey : function () { },
# _setCampNOKey : function () { },
# _setAllowAnchor : function () { },
# _addIgnoredOrganic : function () { },
# _addIgnoredRef : function () { },
# _setSampleRate : function () { },
# _setLocalRemoteServerMode : function () { }
# };
# }
# </script>
# <span id="req_info" style="display:none;">281349|1,288857,282394|1,276056,283751,278606,286932,289504,282336|1,284330,284870,276521,275151|1,288993,287009,281709,279852,286721,284832,287770,288436,289173,284551,282394|4,288162,241959,286484,286576|1,287391,288361,273006,286564,283822|1,289510,288333|5,283880,284854,288350,288995,284562,278620,287395,282903,288017,276486,277906,287672,285271|1,285395,283391|2,282336,273965,288955,281273,285271,276088,284994,263206,278374,288783,286576,276968,283310|3,281581,286137,282718,288080,284562|1,273716,288880,288412,285523,281816,285605,287712,283822|2,274902,282649|1,280403,281349,276734,287863,281902,282888,286745,285990,283547,286043|1,279178,286043,287242,287672|1,281812,287722,282649|7,288528,279949,257921,278507,285380,288082,276339,280131|1,281546,276734|3,288274,283431,288590,229247|7,278173,272378,287426,273097,288333,286891,274533,288842,286870,287028,286511,286635,287327,287426|3,275785,282758,287000,289117,280029|3,284330|1,272681,289127,282394,229247,286996,283747,278673,289511,284210,275151,269862,282824,283911,283822,287456,202675,285521,287426|1,288651,275202,276880,263851,271402,280131,288531,288333|1,285021,288812</span>
# </body>
# </html>

# %%
# for item in items:
#         print(x); x+=1
#         name = item.select(".sr-hotel__name")[0].text
#         print(name)   
#         ii = item.select('.sr_rooms_table_block')[0].select('strong')

# %%
for i in range(0, 2):
    print(i)
# Out:
# 0
# 1

# %%
# 跑多頁
# headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}
# url1 = "https://www.booking.com/searchresults.zh-tw.html?label=gen173nr-1FCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AEB6AEB-AELkgIBeagCAw&sid=1be0bee52e034c3d2cf97e52fd2cf0d3&checkin_month=10&checkin_monthday=19&checkin_year=2017&checkout_month=10&checkout_monthday=21&checkout_year=2017&class_interval=1&dest_id=-235402&dest_type=city&dtdisc=0&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&src=index&src_elem=sb&ss=京都&ss_all=0&ss_raw=京都&ssb=empty&sshis=0&rows=40"
# cookie = {'Cookie':'zz_cook_tms_seg1=1; zz_cook_tms_seg3=5; header_signin_prompt=1; zz_cook_tms_ed=1; b1577f1603e12140d61ae5e8237aafdd=1; _ga=GA1.2.2067083198.1501046935; _gid=GA1.2.832559918.1501046935; BJS=-; has_preloaded=1; utag_main=v_id:015d7d5e90a50053be3f16ff21e80407200f506a00bd0$_sn:1$_ss:0$_st:1501063966716$4split:0$4split2:0$ses_id:1501046935719%3Bexp-session$_pn:24%3Bexp-session; bkng=11UmFuZG9tSVYkc2RlIyh9Yaa29%2F3xUOLbXpFeYC4TUhAJbaRO0jw2RDQsK5U5lBnZtZNYGGQ5Gwk68y4W5EpWdnDv%2Bl0uPZZ%2BX1kzZwIkbIaPcI%2FOB5CMfmR4pBZuFxwalc68jMR7N166r7QJFNHMrgySfuLcxZhRTkuTBKFXoggwF0EKZ8wYuuOOmmdrqiT22TD6yXtx3e4%3D; lastSeen=0; _gat=1'}
# res1 = requests.get(url1, headers = headers, cookies = cookie)
# soup1 = BeautifulSoup(res1.text, 'lxml')

# # 找總頁數
# pa1 = soup1.select('#right')[0].find(lambda x: x.get('data-et-view') == 'TULQWNVLBLWIJDAOfUYdXaO:1')
# pa1.find('h1').text
# pattern = "找到\s(\d+)\s間" #找頁數用
# pa2 = re.findall(pattern, pa1.find('h1').text)
# pageAmount = int(pa2[0])
# turnPage = round(pageAmount/50)

#
location = '京都'
y = 1
for page in range(0, 1):
    print("==="*20+"page:" + str(page+1))
    offset = page*40
    url2 = "https://www.booking.com/searchresults.zh-tw.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AED6AEBkgIBeagCAw&sid=25f3195cbf76726e8ffac861269a0d24&checkin_month=8&checkin_monthday=24&checkin_year=2017&checkout_month=8&checkout_monthday=27&checkout_year=2017&class_interval=1&dest_id=-235402&dest_type=city&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&src=index&src_elem=sb&ss=%E4%BA%AC%E9%83%BD&ssb=empty&ssne=%E4%BA%AC%E9%83%BD&ssne_untouched=%E4%BA%AC%E9%83%BD&rows=15&offset="+str(offset)###+"&sr_ajax=1&b_gtt=dLYAeZFVJfNTBdAHUdPHUBSSUVJfcbWYaNLDRCAET&_=1501050897864"
    res2 = requests.get(url2, headers = headers, cookies = cookie)
    soup2 = BeautifulSoup(res2.text, 'lxml')
    items = soup2.select(".sr_item")
    x = 1
    for item in items:
        print("Total count:" + str(y)); y+=1
        print("# in this page:" + str(x)); x+=1
        name = item.select(".sr-hotel__name")[0].text
        print(name.strip())   
        if (item.select(lambda x: x.get('data-et-click') == 'customGoal:OQRWSEcYC:4'))
        ii = item.select('.sr_rooms_table_block')[0].select('strong > b')
#         rr = re.findall("TWD\s(\w+,\w+$)", ii.text)
#         if x%3 == 0:
#         time.sleep(1);
        print(ii)
# Out:
# ============================================================page:1
# Total count:1
# # in this page:1
# APA Hotel Kyoto-eki Horikawa-Dori（京都站堀川通阿帕酒店）
# [<b>
# TWD 8,665
# </b>]
# Total count:2
# # in this page:2
# Guest House One More Heart Shichijo Omiya 1（再來心七條大宮1號旅館）
# [<b>
# TWD 7,311
# </b>]
# Total count:3
# # in this page:3
# Hotel Excellence Kyoto Station Hachijo（京都站八條口卓越酒店）
# []
# Total count:4
# # in this page:4
# HOTEL UNIZO Kyoto Shijo Karasuma（京都四條烏丸UNIZO酒店）
# [<b>
# TWD 8,237
# </b>]
# Total count:5
# # in this page:5
# Kotoha Kiyomizu - Guest House In Kyoto（京都清水寺科图哈宾馆）
# [<b>
# TWD 4,661
# </b>]
# Total count:6
# # in this page:6
# APA Hotel Kyoto Gion Excellent（京都祗園優秀APA酒店）
# [<b>
# TWD 12,456
# </b>]
# Total count:7
# # in this page:7
# Gozan Hotel & Serviced Apartment Higashiyama Sanjo（東山三條五山服務式公寓酒店）
# [<b>
# TWD 14,915
# </b>]
# Total count:8
# # in this page:8
# HOTEL MYSTAYS Kyoto Shijo（京都四條我的住宿酒店）
# [<b>
# TWD 9,126
# </b>]
# Total count:9
# # in this page:9
# Kyoto Century Hotel（京都世紀酒店）
# [<b>
# TWD 20,242
# </b>]
# Total count:10
# # in this page:10
# Hotel M's Est Shijo Karasuma（四條烏丸艾姆斯伊斯特酒店）
# [<b>
# TWD 10,967
# </b>]
# Total count:11
# # in this page:11
# New Miyako Hotel（新・都酒店）
# [<b>
# TWD 16,377
# </b>]
# Total count:12
# # in this page:12
# Daiwa Roynet Hotel Kyoto Ekimae（京都站前大和魯內酒店）
# [<b>
# TWD 18,630
# </b>]
# Total count:13
# # in this page:13
# Hotel Excellence Kyoto Ekimae（京都站前卓越酒店）
# []
# Total count:14
# # in this page:14
# Hotel Keihan Kyoto Grande（京阪京都大酒店）
# [<b>
# TWD 14,731
# </b>]
# Total count:15
# # in this page:15
# Hotel Gracery Kyoto Sanjo（京都三条格拉斯丽酒店）
# [<b>
# TWD 13,269
# </b>]
# Total count:16
# # in this page:16
# APA Hotel Kyoto Ekimae（京都站前APA酒店）
# [<b>
# TWD 10,561
# </b>]
# Total count:17
# # in this page:17
# Centurion Cabin & Spa Kyoto（京都百夫長膠囊間膠囊旅館及Spa）
# [<b>
# TWD 6,770
# </b>]

# %%
# 跑多頁
# headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}
url1 = "https://www.booking.com/searchresults.zh-tw.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AED6AEBkgIBeagCAw&sid=25f3195cbf76726e8ffac861269a0d24&checkin_month=8&checkin_monthday=24&checkin_year=2017&checkout_month=8&checkout_monthday=27&checkout_year=2017&class_interval=1&dest_id=-235402&dest_type=city&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&src=index&src_elem=sb&ss=%E4%BA%AC%E9%83%BD&ssb=empty&ssne=%E4%BA%AC%E9%83%BD&ssne_untouched=%E4%BA%AC%E9%83%BD&rows=50"###+"&sr_ajax=1&b_gtt=dLYAeZFVJfNTBdAHUdPHUBSSUVJfcbWYaNLDRCAET&_=1501050897864"
# cookie = {'Cookie':'zz_cook_tms_seg1=1; zz_cook_tms_seg3=5; header_signin_prompt=1; zz_cook_tms_ed=1; b1577f1603e12140d61ae5e8237aafdd=1; _ga=GA1.2.2067083198.1501046935; _gid=GA1.2.832559918.1501046935; BJS=-; has_preloaded=1; utag_main=v_id:015d7d5e90a50053be3f16ff21e80407200f506a00bd0$_sn:1$_ss:0$_st:1501063966716$4split:0$4split2:0$ses_id:1501046935719%3Bexp-session$_pn:24%3Bexp-session; bkng=11UmFuZG9tSVYkc2RlIyh9Yaa29%2F3xUOLbXpFeYC4TUhAJbaRO0jw2RDQsK5U5lBnZtZNYGGQ5Gwk68y4W5EpWdnDv%2Bl0uPZZ%2BX1kzZwIkbIaPcI%2FOB5CMfmR4pBZuFxwalc68jMR7N166r7QJFNHMrgySfuLcxZhRTkuTBKFXoggwF0EKZ8wYuuOOmmdrqiT22TD6yXtx3e4%3D; lastSeen=0; _gat=1'}
res1 = requests.get(url1, headers = headers, cookies = cookie)
soup1 = BeautifulSoup(res1.text, 'lxml')

# # 找總頁數
pa1 = soup1.select('#right')[0].find(lambda x: x.get('data-et-view') == 'TULQWNVLBLWIJDAOfUYdXaO:1')
pa1.find('h1').text
pattern = "找到\s(\d+)\s間" #找頁數用
pa2 = re.findall(pattern, pa1.find('h1').text)
pageAmount = int(pa2[0])
turnPage = round(pageAmount/15)

#
location = '京都'
tot = 1
print("pageAmount= " + str(pageAmount))
print("turnPage= " + str(turnPage))
for page in range(0, turnPage):
    print("==="*20+"page:" + str(page+1))
    offset = page*40
    url2 = "https://www.booking.com/searchresults.zh-tw.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AED6AEBkgIBeagCAw&sid=25f3195cbf76726e8ffac861269a0d24&checkin_month=8&checkin_monthday=24&checkin_year=2017&checkout_month=8&checkout_monthday=27&checkout_year=2017&class_interval=1&dest_id=-235402&dest_type=city&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&src=index&src_elem=sb&ss=%E4%BA%AC%E9%83%BD&ssb=empty&ssne=%E4%BA%AC%E9%83%BD&ssne_untouched=%E4%BA%AC%E9%83%BD&rows=50&offset="+str(offset)###+"&sr_ajax=1&b_gtt=dLYAeZFVJfNTBdAHUdPHUBSSUVJfcbWYaNLDRCAET&_=1501050897864"
    res2 = requests.get(url2, headers = headers, cookies = cookie)
    soup2 = BeautifulSoup(res2.text, 'lxml')
    items = soup2.select(".sr_item")
    x = 1
    for item in items:
        print("Total count:" + str(tot)); tot+=1
        print("# in this page:" + str(x)); x+=1
        name = item.select(".sr-hotel__name")[0].text
        print(name.strip())   
        if "TWD" not in item.select('.sr_rooms_table_block')[0].text: 
            print("--------> Sell Out!!!")
        else:
            print("--------> " + item.select('.sr_rooms_table_block')[0].select('strong > b')[0].text)
#             ii = item.select('.sr_rooms_table_block')[0].select('strong > b')[0]
#             rr = re.findall("TWD\s(\w+,\w+$)", ii.text)
# #         if x%3 == 0:
# #         time.sleep(1);
#             print(rr)
# Out:
# pageAmount= 811
# turnPage= 54
# ============================================================page:1
# Total count:1
# # in this page:1
# APA Hotel Kyoto-eki Horikawa-Dori（京都站堀川通阿帕酒店）
# -------->
# TWD 8,665
#
# Total count:2
# # in this page:2
# HOTEL UNIZO Kyoto Shijo Karasuma（京都四條烏丸UNIZO酒店）
# -------->
# TWD 8,237
#
# Total count:3
# # in this page:3
# Hotel Excellence Kyoto Station Hachijo（京都站八條口卓越酒店）
# --------> Sell Out!!!
# Total count:4
# # in this page:4
# Guest House One More Heart Shichijo Omiya 1（再來心七條大宮1號旅館）
# -------->
# TWD 7,311
#
# Total count:5
# # in this page:5
# Kotoha Kiyomizu - Guest House In Kyoto（京都清水寺科图哈宾馆）
# -------->
# TWD 4,661
#
# Total count:6
# # in this page:6
# APA Hotel Kyoto Gion Excellent（京都祗園優秀APA酒店）
# -------->
# TWD 12,456
#
# Total count:7
# # in this page:7
# Gozan Hotel & Serviced Apartment Higashiyama Sanjo（東山三條五山服務式公寓酒店）
# -------->
# TWD 14,915
#
# Total count:8
# # in this page:8
# HOTEL MYSTAYS Kyoto Shijo（京都四條我的住宿酒店）
# -------->
# TWD 9,126
#
# Total count:9
# # in this page:9
# Kyoto Century Hotel（京都世紀酒店）
# -------->
# TWD 20,242
#
# Total count:10
# # in this page:10
# Hotel M's Est Shijo Karasuma（四條烏丸艾姆斯伊斯特酒店）
# -------->
# TWD 10,967
#
# Total count:11
# # in this page:11
# New Miyako Hotel（新・都酒店）
# -------->
# TWD 16,377
#
# Total count:12
# # in this page:12
# Daiwa Roynet Hotel Kyoto Ekimae（京都站前大和魯內酒店）
# -------->
# TWD 18,630
#
# Total count:13
# # in this page:13
# Hotel Excellence Kyoto Ekimae（京都站前卓越酒店）
# --------> Sell Out!!!
# Total count:14
# # in this page:14
# Hotel Keihan Kyoto Grande（京阪京都大酒店）
# -------->
# TWD 14,731
#
# Total count:15
# # in this page:15
# Hotel Gracery Kyoto Sanjo（京都三条格拉斯丽酒店）
# -------->
# TWD 13,269
#
# Total count:16
# # in this page:16
# APA Hotel Kyoto Ekimae（京都站前APA酒店）
# -------->
# TWD 10,561
#
# Total count:17
# # in this page:17
# Centurion Cabin & Spa Kyoto（京都百夫長膠囊間膠囊旅館及Spa）
# -------->
# TWD 6,770
#
# ============================================================page:2
# Total count:18
# # in this page:1
# Green Rich Hotel Kyoto Station South（格林瑞奇酒店京都站南）
# -------->
# TWD 12,862
#
# Total count:19
# # in this page:2
# Four Seasons Hotel Kyoto（京都四季酒店）
# -------->
# TWD 48,850
#
# Total count:20
# # in this page:3
# Daiwa Roynet Hotel Kyoto Shijo Karasuma（京都四條烏丸大和ROYNET酒店）
# --------> Sell Out!!!
# Total count:21
# # in this page:4
# Hotel Sunline Kyoto Gion Shijo（京都森莱精品酒店）
# -------->
# TWD 12,185
#
# Total count:22
# # in this page:5
# Hotel Nikko Princess Kyoto（日航國際酒店）
# -------->
# TWD 17,872
#
# Total count:23
# # in this page:6
# Nagomi-Ryokan Yuu（Nagomi旅館　悠）
# -------->
# TWD 10,994
#
# Total count:24
# # in this page:7
# Hotel Kanra Kyoto（京都甘樂酒店）
# -------->
# TWD 36,094
#
# Total count:25
# # in this page:8
# RIHGA Royal Hotel Kyoto（京都麗嘉皇家酒店）
# -------->
# TWD 13,174
#
# Total count:26
# # in this page:9
# Japaning Hotel OXA（奧克斯酒店）
# -------->
# TWD 7,149
#
# Total count:27
# # in this page:10
# Hana-Touro Hotel Gion（哈納- 圖羅祗園酒店）
# -------->
# TWD 29,787
#
# Total count:28
# # in this page:11
# Hotel She Kyoto（京都她的酒店）
# -------->
# TWD 9,247
#
# Total count:29
# # in this page:12
# Stay inn Kyoto Gojo（京都五條公寓式酒店）
# -------->
# TWD 8,470
#
# Total count:30
# # in this page:13
# Kyoto Travellers Inn（京都遊客旅館）
# --------> Sell Out!!!
# Total count:31
# # in this page:14
# Village Kyoto（Village京都）
# -------->
# TWD 19,659
#
# Total count:32
# # in this page:15
# Gion Maifukan（祗園舞風館）
# -------->
# TWD 22,746
#
# Total count:33
# # in this page:16
# UNIZO INN Kyoto Kawaramachi Shijo（京都河原町四條酒店）
# -------->
# TWD 11,108
#
# Total count:34
# # in this page:17
# Japaning Hotel Modany Kyoto Enmachi（莫丹京都円町酒店）
# -------->
# TWD 8,773
#
# ============================================================page:3
# Total count:35
# # in this page:1
# Aoi Hotel Kyoto（京都葵酒店）
# -------->
# TWD 30,057
#
# Total count:36
# # in this page:2
# Kizashi The Suite（凱澤西套房酒店）
# -------->
# TWD 55,240
#
# Total count:37
# # in this page:3
# Friends Kyo（友人之家公寓式酒店）
# --------> Sell Out!!!
# Total count:38
# # in this page:4
# Guesthouse Tenkai（騰凱度假屋）
# -------->
# TWD 26,320
#
# Total count:39
# # in this page:5
# Veada（薇雅達酒店）
# -------->
# TWD 16,978
#
# Total count:40
# # in this page:6
# NAZUNA Kyoto Higashiyama tei -Warmth & Functional-（京都東山舒適度假屋）
# -------->
# TWD 45,655
#
# Total count:41
# # in this page:7
# Kyomaru（居丸酒店）
# -------->
# TWD 24,371
#
# Total count:42
# # in this page:8
# Guest House Makotoya（京町屋度假屋）
# -------->
# TWD 18,034
#
# Total count:43
# # in this page:9
# Murasakino Uan（紫野安度假屋）
# -------->
# TWD 31,953
#
# Total count:44
# # in this page:10
# Sakura Terrace The Gallery（樱花台画廊酒店）
# -------->
# TWD 14,081
#
# Total count:45
# # in this page:11
# Natsu House（奈津度假屋）
# -------->
# TWD 17,940
#
# Total count:46
# # in this page:12
# Kyoto Granbell Hotel（京都格兰贝尔酒店 ）
# -------->
# TWD 12,402
#
# Total count:47
# # in this page:13
# Tazuru（田鶴酒店）
# --------> Sell Out!!!
# Total count:48
# # in this page:14
# Kyoto Hatagoya Kamishichiken（京都荷迪歌瓦上七軒度假屋）
# -------->
# TWD 28,053
#
# Total count:49
# # in this page:15
# Kaede Guesthouse（凱德旅館）
# -------->
# TWD 8,394
#
# Total count:50
# # in this page:16
# El Inn Kyoto（京都EI旅館）
# -------->
# TWD 9,857
#
# Total count:51
# # in this page:17
# Rinn Shichijo Ohashi Bridge（鈴七條大橋旅館）
# -------->
# TWD 6,445
#
# ============================================================page:4
# Total count:52
# # in this page:1
# Kyoto Inn Gion（京都祗園酒店）
# -------->
# TWD 12,107
#
# Total count:53
# # in this page:2
# Rinn Tofukuji Riverside（林恩東福寺河濱旅館）
# -------->
# TWD 6,066
#
# Total count:54
# # in this page:3
# Dozen（打仁日式旅館）
# --------> Sell Out!!!
# Total count:55
# # in this page:4
# Citadines Kyoto Karasuma-Gojo（馨樂庭京都烏丸五條酒店）
# -------->
# TWD 10,938
#
# Total count:56
# # in this page:5
# Rinn Nijo Castle（二條城伊恩旅館）
# -------->
# TWD 6,445
#
# Total count:57
# # in this page:6
# Econo-Inn Kyoto（京都經濟酒店）
# -------->
# TWD 11,600
#
# Total count:58
# # in this page:7
# Guesthouse Soi（素居旅舍）
# -------->
# TWD 10,723
#
# Total count:59
# # in this page:8
# Mosaic Hostel Kyoto（京都馬賽克旅舍）
# -------->
# TWD 14,081
#
# Total count:60
# # in this page:9
# The Next Door Hostel lower east nine（隔鄰下東九青年旅館）
# -------->
# TWD 4,357
#
# Total count:61
# # in this page:10
# Tsubame-ya（燕之家旅館）
# -------->
# TWD 5,605
#
# Total count:62
# # in this page:11
# Hotel New Hankyu Kyoto（京都新阪急酒店）
# -------->
# TWD 12,688
#
# Total count:63
# # in this page:12
# Kyomachiya Stay Waka Fushimi Inari（瓦卡伏見稻荷度假屋）
# -------->
# TWD 58,490
#
# Total count:64
# # in this page:13
# Urban Hotel Kyoto（京都城市酒店）
# --------> Sell Out!!!
# Total count:65
# # in this page:14
# Laon Inn Karasuma Ebisugawa（烏丸夷川拉翁旅館）
# -------->
# TWD 10,967
#
# Total count:66
# # in this page:15
# Guest House Ga-Jyun（雅順旅館）
# -------->
# TWD 18,262
#
# Total count:67
# # in this page:16
# The Hotel Kiyomizu Gion（清水祇園酒店）
# -------->
# TWD 15,558
#
# Total count:68
# # in this page:17
# Japaning Kyoto Hotel Enmachi（京都圓町佳帕寧酒店）
# -------->
# TWD 6,851
#
# ============================================================page:5
# Total count:69
# # in this page:1
# Fujitaya Kyoto（京都弗及塔亞酒店）
# -------->
# TWD 9,748
#
# Total count:70
# # in this page:2
# Kiyomizu Sannenzaka - Guest House in Kyoto（京都清水三年坂公寓）
# -------->
# TWD 5,006
#
# Total count:71
# # in this page:3
# River East Nanajo - Guest House In Kyoto（七條河東- 京都公寓）
# --------> Sell Out!!!
# Total count:72
# # in this page:4
# Kyoto Ryokan Gion Sano（京都祗園佐野旅館）
# -------->
# TWD 21,349
#
# Total count:73
# # in this page:5
# THE JUNEI HOTEL Kyoto Imperial Palace West
# -------->
# TWD 27,079
#
# Total count:74
# # in this page:6
# Hotel Granvia Kyoto（京都格蘭比亞大酒店）
# -------->
# TWD 37,531
#
# Total count:75
# # in this page:7
# Guest House Route 53 Goshomae（御所前53號路旅館）
# -------->
# TWD 7,582
#
# Total count:76
# # in this page:8
# Guesthouse Origami（摺紙旅館）
# -------->
# TWD 9,748
#
# Total count:77
# # in this page:9
# Arklead Gojohorikawa - Guest House In Kyoto（京都阿克里德戈捷霍瑞卡瓦賓館）
# -------->
# TWD 5,483
#
# Total count:78
# # in this page:10
# Japaning Hotel Tatsunoya（龍之家日式酒店）
# -------->
# TWD 7,677
#
# Total count:79
# # in this page:11
# LA Kyoto - Guest House In Kyoto（京都LA旅館）
# -------->
# TWD 5,524
#
# Total count:80
# # in this page:12
# Gion Guesthouse Yururi（祗園賓館）
# -------->
# TWD 6,824
#
# Total count:81
# # in this page:13
# Sakura Suite（櫻花套房酒店）
# --------> Sell Out!!!
# Total count:82
# # in this page:14
# Maison Fushimi（伏見旅館）
# -------->
# TWD 6,499
#
# Total count:83
# # in this page:15
# Urbain Kyoto Kawaramachi（京都河原町都市酒店）
# -------->
# TWD 8,042
#
# Total count:84
# # in this page:16
# Guesthouse Chayama（茶山旅館）
# -------->
# TWD 14,622
#
# Total count:85
# # in this page:17
# Kyo Machiya Guest House Makuya（馬克亞京町賓館）
# -------->
# TWD 7,474
#
# ============================================================page:6
# Total count:86
# # in this page:1
# Hotel Anteroom Kyoto（京都安迪魯酒店）
# -------->
# TWD 13,607
#
# Total count:87
# # in this page:2
# Guesthouse Omotenashi Kyoto（京都以心致誠旅館）
# -------->
# TWD 12,402
#
# Total count:88
# # in this page:3
# Grand Prince Hotel Kyoto（京都格蘭王子大飯店）
# --------> Sell Out!!!
# Total count:89
# # in this page:4
# Ohto Ryokan（鸭东旅馆）
# -------->
# TWD 6,174
#
# Total count:90
# # in this page:5
# Guest House Kete（科特旅館）
# -------->
# TWD 5,469
#
# Total count:91
# # in this page:6
# Tanaka-ya（田中亞）
# -------->
# TWD 8,124
#
# Total count:92
# # in this page:7
# ANA Crowne Plaza Hotel Kyoto（京都全日空皇冠廣場酒店）
# -------->
# TWD 12,564
#
# Total count:93
# # in this page:8
# Hotel Grand Fine Kyoto Minami (Adult Only)（京都南部精品大酒店（僅限成人入住））
# -------->
# TWD 9,139
#
# Total count:94
# # in this page:9
# Guesthouse Itoya Kyoto（京都糸屋旅館）
# -------->
# TWD 7,311
#
# Total count:95
# # in this page:10
# Kyoto Takasegawa Bettei（京都高瀨貝特酒店）
# -------->
# TWD 18,766
#
# Total count:96
# # in this page:11
# Stella Gosho（斯特拉旅館）
# -------->
# TWD 6,228
#
# Total count:97
# # in this page:12
# Ryokan Yamazaki（山崎旅館）
# -------->
# TWD 7,019
#
# Total count:98
# # in this page:13
# Nene House（納納度假屋）
# --------> Sell Out!!!
# Total count:99
# # in this page:14
# Yadoya Kikokuso（宿屋枳殼莊酒店）
# -------->
# TWD 17,547
#
# Total count:100
# # in this page:15
# Guest House Taiko-ya Bettei（太鼓屋別邸旅館）
# -------->
# TWD 5,903
#
# Total count:101
# # in this page:16
# Hyatt Regency Kyoto（京都凱悅酒店）
# -------->
# TWD 36,673
#
# Total count:102
# # in this page:17
# Stella Higashiyama（斯特拉東山酒店）
# -------->
# TWD 5,416
#
# ============================================================page:7
# Total count:103
# # in this page:1
# Kazenoya Sara（風雅咲樂度假屋）
# -------->
# TWD 20,255
#
# Total count:104
# # in this page:2
# Tougetsu（陶月旅館）
# -------->
# TWD 12,998
#
# Total count:105
# # in this page:3
# Kyoto Miyabi Inn（京小宿古川雅）
# --------> Sell Out!!!
# Total count:106
# # in this page:4
# Guesthouse Kyoto Kaikonoyashiro（京都蚕之社旅馆）
# -------->
# TWD 7,717
#
# Total count:107
# # in this page:5
# Coto Kyoto Shijoomiya 1（京都古都四条大宫1号公寓）
# -------->
# TWD 10,886
#
# Total count:108
# # in this page:6
# Kamon Kyoto（家徽京都旅館）
# -------->
# TWD 3,899
#
# Total count:109
# # in this page:7
# Hat'n Hat Hostel（漢特恩漢特旅館）
# -------->
# TWD 5,145
#
# Total count:110
# # in this page:8
# Yumoto Onsen OharaSansou（湯溫泉奧哈拉山水酒店）
# -------->
# TWD 26,759
#
# Total count:111
# # in this page:9
# Kyoto Guest House（京都旅館）
# -------->
# TWD 3,249
#
# Total count:112
# # in this page:10
# Kyostay Iroha Umekoji（京都伊呂波烏梅考齊公寓）
# -------->
# TWD 9,369
#
# Total count:113
# # in this page:11
# Kaikoan（懷古庵公寓）
# -------->
# TWD 13,515
#
# Total count:114
# # in this page:12
# Sakura Story（櫻花故事公寓）
# -------->
# TWD 10,967
#
# Total count:115
# # in this page:13
# Guest House One More Heart Kyoto Station South 1（京都車站南更用心1號度假屋）
# --------> Sell Out!!!
# Total count:116
# # in this page:14
# Kyoto Kinkakuji House
# -------->
# TWD 5,687
#
# Total count:117
# # in this page:15
# Japaning Hotel Hakkoen（出雲市日式酒店）
# -------->
# TWD 10,479
#
# Total count:118
# # in this page:16
# Daily Apartment House Ichijo Ivy（豪斯尾池市條日常公寓）
# -------->
# TWD 4,200
#
# Total count:119
# # in this page:17
# Capsule Resort Kyoto Square（京都廣場膠囊旅館）
# -------->
# TWD 7,040
#
# ============================================================page:8
# Total count:120
# # in this page:1
# Ermitage (Adult Only)（愛瑞美特哥情趣酒店（僅限成人））
# -------->
# TWD 9,857
#
# Total count:121
# # in this page:2
# Guest House Oumi（近江旅館）
# -------->
# TWD 8,394
#
# Total count:122
# # in this page:3
# Momo Stays（莫莫住宿旅館）
# --------> Sell Out!!!
# Total count:123
# # in this page:4
# Hanakagari
# -------->
# TWD 25,996
#
# Total count:124
# # in this page:5
# Oyado Sato（和宿裡）
# -------->
# TWD 9,369
#
# Total count:125
# # in this page:6
# Riusu - 流苏 -（流蘇旅館）
# -------->
# TWD 6,499
#
# Total count:126
# # in this page:7
# Hanakiya（哈納基亞）
# -------->
# TWD 6,824
#
# Total count:127
# # in this page:8
# Hanagoromo
# -------->
# TWD 25,996
#
# Total count:128
# # in this page:9
# Kyoto Stay SAKURA Toji I（京都住宿樱花东寺1号公寓）
# -------->
# TWD 9,364
#
# Total count:129
# # in this page:10
# Grand Kyoto Kawaramachi（京都河原町公寓式酒店）
# -------->
# TWD 8,773
#
# Total count:130
# # in this page:11
# Kyoto Guesthouse Hostel Ayame（京都溪蓀賓館）
# -------->
# TWD 8,936
#
# Total count:131
# # in this page:12
# the b Kyoto Sanjo（B京都三條維新酒店集團）
# -------->
# TWD 10,358
#
# Total count:132
# # in this page:13
# Gojo Miyabi Inn（京小宿五條雅）
# --------> Sell Out!!!
# Total count:133
# # in this page:14
# Kyoto Nishijin no Yado（京都西陣之宿旅館）
# -------->
# TWD 8,159
#
# Total count:134
# # in this page:15
# One More Heart at Nijojo 1
# -------->
# TWD 6,336
#
# Total count:135
# # in this page:16
# Mihoreru Annex Toji（東寺陶醉附屬旅館）
# -------->
# TWD 8,936
#
# Total count:136
# # in this page:17
# Daily Apartment House Fushimi Ivy（豪斯尾池伏見日常公寓）
# -------->
# TWD 4,200
#
# ============================================================page:9
# Total count:137
# # in this page:1
# Rinn Sanjusangendo（林恩三十三間堂度假屋）
# -------->
# TWD 11,373
#
# Total count:138
# # in this page:2
# Riraso（里拉索公寓）
# -------->
# TWD 8,936
#
# Total count:139
# # in this page:3
# Hana-Touro Stay Yasakano-Tou Machiya Premium（花灯旅八坂之塔高級町屋）
# --------> Sell Out!!!
# Total count:140
# # in this page:4
# Crossroads（岔路口旅館）
# -------->
# TWD 6,141
#
# Total count:141
# # in this page:5
# Tawara-an（田原庵旅館）
# -------->
# TWD 45,492
#
# Total count:142
# # in this page:6
# Hotel Hokke Club Kyoto（京都法華俱樂部酒店）
# -------->
# TWD 11,590
#
# Total count:143
# # in this page:7
# Luxury Machiya Takeya Gojo（町屋竹屋五條豪華度假屋）
# -------->
# TWD 26,808
#
# Total count:144
# # in this page:8
# Guest House One More Heart Fushimi Inari 1（伏見稻荷大社1號更隨心旅館）
# -------->
# TWD 41,430
#
# Total count:145
# # in this page:9
# Hotel Fine Garden Kyoto Minami (Adult Only)（京都南部花園精品酒店（僅限成人入住））
# -------->
# TWD 9,992
#
# Total count:146
# # in this page:10
# Kiyomizu Sannenzaka-An（清水寺三年坂安酒店）
# -------->
# TWD 37,369
#
# Total count:147
# # in this page:11
# Colours（色彩旅舍）
# -------->
# TWD 9,478
#
# Total count:148
# # in this page:12
# Guest House Links（鏈接旅館）
# -------->
# TWD 5,727
#
# Total count:149
# # in this page:13
# Kyonoyado Senkaku Bettei（京都之宿千鶴別邸度假屋）
# --------> Sell Out!!!
# Total count:150
# # in this page:14
# Kyomachiya Real Kyoto Wabisabi
# -------->
# TWD 9,748
#
# Total count:151
# # in this page:15
# Orange Inn（橙子旅舍）
# -------->
# TWD 7,853
#
# Total count:152
# # in this page:16
# Yamamoto Ryokan（山茂登旅館）
# -------->
# TWD 9,358
#
# Total count:153
# # in this page:17
# Guest House Locokokoro（洛克可科洛旅館）
# -------->
# TWD 10,561
#
# ============================================================page:10
# Total count:154
# # in this page:1
# Aya inn Karasuma gojo（烏丸五阿雅度假屋）
# -------->
# TWD 27,620
#
# Total count:155
# # in this page:2
# Japaning Hotel Fushimiinari
# -------->
# TWD 8,801
#
# Total count:156
# # in this page:3
# Kabuki Ann（傾奇庵度假屋）
# --------> Sell Out!!!
# Total count:157
# # in this page:4
# Kyoto beopen Hostel（京都開放旅館）
# -------->
# TWD 4,955
#
# Total count:158
# # in this page:5
# Yunokian（柚之木庵度假屋）
# -------->
# TWD 22,475
#
# Total count:159
# # in this page:6
# Wajimaya Ryokan（那須鹽原酒店）
# -------->
# TWD 8,773
#
# Total count:160
# # in this page:7
# Kyoto Guesthouse Roujiya（洛基亞京都賓館）
# -------->
# TWD 7,311
#
# Total count:161
# # in this page:8
# RESI STAY Karasuma Gojo（烏丸五條瑞希公寓）
# -------->
# TWD 6,286
#
# Total count:162
# # in this page:9
# Shunju Higashiyama（春秋東山度假屋）
# -------->
# TWD 26,442
#
# Total count:163
# # in this page:10
# Amzing Apartment for Travelers near Kyoto Station
# -------->
# TWD 13,152
#
# Total count:164
# # in this page:11
# Suzakukan Suzaku Crossing
# -------->
# TWD 5,145
#
# Total count:165
# # in this page:12
# Hotel Crystal Gate Kyoto (Adult Only)（京都水晶門情趣酒店（僅限成人））
# -------->
# TWD 12,185
#
# Total count:166
# # in this page:13
# Serendipity at Kyoto（京都好運度假屋）
# --------> Sell Out!!!
# Total count:167
# # in this page:14
# Shinmonzen Ryugin（新廟龍吟旅館）
# -------->
# TWD 33,690
#
# Total count:168
# # in this page:15
# Hotel In The Green (Adult Only)（綠色情趣酒店（僅限成人））
# -------->
# TWD 12,727
#
# Total count:169
# # in this page:16
# Coto Kyoto Tofukuji（京都東福寺古都公寓）
# -------->
# TWD 10,236
#
# Total count:170
# # in this page:17
# Coto Kyoto Toji 3（科托京都東寺3號度假屋）
# -------->
# TWD 12,348
#
# ============================================================page:11
# Total count:171
# # in this page:1
# Samaryoan（左馬寮庵旅館）
# -------->
# TWD 10,967
#
# Total count:172
# # in this page:2
# Karasuma Enishi-Do
# -------->
# TWD 19,497
#
# Total count:173
# # in this page:3
# Kyomachiya Suite Rikyu（科碼琪雅離宮套房旅館）
# --------> Sell Out!!!
# Total count:174
# # in this page:4
# Kogane-An（科根尼恩酒店）
# -------->
# TWD 8,936
#
# Total count:175
# # in this page:5
# Ikumatsu（伊庫瑪蘇酒店）
# -------->
# TWD 43,809
#
# Total count:176
# # in this page:6
# Loft Apartment near Kiyomizu and Gion
# -------->
# TWD 16,441
#
# Total count:177
# # in this page:7
# Guesthouse HANA Kyoto（京都華旅館）
# -------->
# TWD 14,379
#
# Total count:178
# # in this page:8
# Kyotofish Nishiki
# -------->
# TWD 26,537
#
# Total count:179
# # in this page:9
# Takao Kanko Hotel（高尾山觀光酒店）
# -------->
# TWD 26,320
#
# Total count:180
# # in this page:10
# Kyoto Machiya Cottage Karigane（京都町町度假屋）
# -------->
# TWD 28,974
#
# Total count:181
# # in this page:11
# Apartment Ocean Blue Next to Kyoto Station
# -------->
# TWD 13,152
#
# Total count:182
# # in this page:12
# Zen Kyoto（京都禪度假屋）
# -------->
# TWD 20,304
#
# Total count:183
# # in this page:13
# Hosta Toji San（玉簪東寺燦度假屋）
# --------> Sell Out!!!
# Total count:184
# # in this page:14
# Nishijin no Sato（西陣之鄉旅館）
# -------->
# TWD 13,539
#
# Total count:185
# # in this page:15
# Kyobu Horikawa Rokujo
# -------->
# TWD 29,678
#
# Total count:186
# # in this page:16
# Roman Kan（罗马馆日式旅馆）
# -------->
# TWD 12,294
#
# Total count:187
# # in this page:17
# Japaning Nishinokyo（西京日式度假屋）
# -------->
# TWD 8,773
#
# ============================================================page:12
# Total count:188
# # in this page:1
# Two City Convenient Apartment
# -------->
# TWD 16,029
#
# Total count:189
# # in this page:2
# Iori Uzumasa
# -------->
# TWD 23,396
#
# Total count:190
# # in this page:3
# Check in Shijokarasuma（烏丸入住酒店）
# --------> Sell Out!!!
# Total count:191
# # in this page:4
# Yumemaboroshi（夢幻度假屋）
# -------->
# TWD 15,435
#
# Total count:192
# # in this page:5
# Rokuhara Inn（六波羅旅館）
# -------->
# TWD 12,185
#
# Total count:193
# # in this page:6
# Hotel Sugicho（薩奇秋酒店）
# -------->
# TWD 9,207
#
# Total count:194
# # in this page:7
# Guesthouse Mieiken Gogoin（米耶墾果果茵度假屋）
# -------->
# TWD 26,808
#
# Total count:195
# # in this page:8
# Samurai House
# -------->
# TWD 24,371
#
# Total count:196
# # in this page:9
# Rinn Fushimiinari
# -------->
# TWD 13,458
#
# Total count:197
# # in this page:10
# Sanjojuku Kyoto Machiya（桑久庫京都馬馳亞旅館）
# -------->
# TWD 8,633
#
# Total count:198
# # in this page:11
# Kyoto stay SAKURA Toji West I（京都樱东寺西1号度假屋）
# -------->
# TWD 12,727
#
# Total count:199
# # in this page:12
# Shinobi House（忍者度假屋）
# -------->
# TWD 12,884
#
# Total count:200
# # in this page:13
# Laon Inn Gion Shinmonzen（拉昂祗園新廟旅館）
# --------> Sell Out!!!
# Total count:201
# # in this page:14
# Kaikotekimirai (Female and Family Only)（緬懷未來旅館（僅供女性與家庭））
# -------->
# TWD 5,470
#
# Total count:202
# # in this page:15
# Hotel Parco (Adult Only)（帕爾科情趣酒店（僅限成人））
# -------->
# TWD 15,473
#
# Total count:203
# # in this page:16
# Kujo Stays（九條別莊）
# -------->
# TWD 10,561
#
# Total count:204
# # in this page:17
# Maeniiya Machiya Inn（馬恩伊亞町屋度假屋）
# -------->
# TWD 22,746
#
# ============================================================page:13
# Total count:205
# # in this page:1
# Gamon（加蒙旅館）
# -------->
# TWD 11,048
#
# Total count:206
# # in this page:2
# Kyoto Sakaimachiya（京都堺町家）
# -------->
# TWD 48,742
#
# Total count:207
# # in this page:3
# karaksa hotel Kyoto Ⅰ（京都卡拉扎I號酒店）
# --------> Sell Out!!!
# Total count:208
# # in this page:4
# Fushimiinari Shanti Japaning（伏見稻荷香提加帕寧度假屋）
# -------->
# TWD 12,673
#
# Total count:209
# # in this page:5
# Rakuwa（洛和公寓）
# -------->
# TWD 8,530
#
# Total count:210
# # in this page:6
# Kiyomizu Birodo-an
# -------->
# TWD 28,961
#
# Total count:211
# # in this page:7
# Waraku House（和樂旅舍）
# -------->
# TWD 6,932
#
# Total count:212
# # in this page:8
# Kyo Koyado Benten（集雅多本頓度假屋）
# -------->
# TWD 19,497
#
# Total count:213
# # in this page:9
# KYO Sakura House（KYO櫻花民宿）
# -------->
# TWD 8,124
#
# Total count:214
# # in this page:10
# Hotel Grand Fine Kyoto Okazaki (Adult Only)（京都岡崎精品大酒店（僅限成人））
# -------->
# TWD 15,597
#
# Total count:215
# # in this page:11
# Fushimi House（伏見度假屋）
# -------->
# TWD 4,874
#
# Total count:216
# # in this page:12
# Nishihan（西半度假屋）
# -------->
# TWD 12,456
#
# Total count:217
# # in this page:13
# Hotel Centnovum Kyoto（京都森特諾姆酒店）
# --------> Sell Out!!!
# Total count:218
# # in this page:14
# Hotel La cafe Kyoto (Adult Only)（京都酒店（僅限成人））
# -------->
# TWD 10,669
#
# Total count:219
# # in this page:15
# Halo House（光輝民宿）
# -------->
# TWD 15,922
#
# Total count:220
# # in this page:16
# Ryokan Sawaya Honten（薩瓦亞宏騰日式旅館）
# -------->
# TWD 15,792
#
# Total count:221
# # in this page:17
# Hotel Alfa Kyoto (Adult Only)（京都阿爾法情趣酒店（僅限成人））
# -------->
# TWD 13,864
#
# ============================================================page:14
# Total count:222
# # in this page:1
# BnA Gallery Kyoto（京都畫廊旅館）
# -------->
# TWD 24,642
#
# Total count:223
# # in this page:2
# Heian Residence（平安公寓）
# -------->
# TWD 15,435
#
# Total count:224
# # in this page:3
# Guest House Costa del Sol Kyoto（京都科斯塔朗晴酒店）
# --------> Sell Out!!!
# Total count:225
# # in this page:4
# Arashiyama Bamboo Guest House（嵐山竹旅館）
# -------->
# TWD 9,610
#
# Total count:226
# # in this page:5
# Ayame-an
# -------->
# TWD 30,518
#
# Total count:227
# # in this page:6
# Raku Inn（櫻庭落賓館）
# -------->
# TWD 22,746
#
# Total count:228
# # in this page:7
# K's Villa Takasegawa-tei（K之家高瀬川邸公寓）
# -------->
# TWD 19,767
#
# Total count:229
# # in this page:8
# R&Run Kyoto Apartment & Suites（R&Run京都公寓式酒店）
# -------->
# TWD 36,849
#
# Total count:230
# # in this page:9
# Taberu Tomaru Nijo Castle（禁食二條城旅館）
# -------->
# TWD 8,394
#
# Total count:231
# # in this page:10
# Japaning Hotel Kikoan（輝幸庵日本度假屋）
# -------->
# TWD 27,620
#
# Total count:232
# # in this page:11
# Nijo Kikyo-Tei
# -------->
# TWD 24,046
#
# Total count:233
# # in this page:12
# Juichi-an（樹一度假屋）
# -------->
# TWD 20,986
#
# Total count:234
# # in this page:13
# COTO Kyoto Goshonishi（COTO京都御所西度假屋）
# --------> Sell Out!!!
# Total count:235
# # in this page:14
# BnA Machiya Kyoto（京都町屋BnA度假屋）
# -------->
# TWD 24,371
#
# Total count:236
# # in this page:15
# Rakusuian（楽水庵旅館）
# -------->
# TWD 7,365
#
# Total count:237
# # in this page:16
# Shunju Shijo（春秋四條度假屋）
# -------->
# TWD 36,394
#
# Total count:238
# # in this page:17
# Kuraya Nishimatsuyacho（倉谷西松屋町度假屋）
# -------->
# TWD 39,773
#
# ============================================================page:15
# Total count:239
# # in this page:1
# Guesthouse Kotoya Toji（克托亞冬治旅館）
# -------->
# TWD 14,593
#
# Total count:240
# # in this page:2
# Samurai Inn（武士度假屋）
# -------->
# TWD 40,618
#
# Total count:241
# # in this page:3
# Amenity Hotel Kyoto（京都舒適酒店）
# --------> Sell Out!!!
# Total count:242
# # in this page:4
# Tipitaka House（三藏度假屋）
# -------->
# TWD 15,841
#
# Total count:243
# # in this page:5
# Satoi Kosetsu（塞托克賽蘇度假屋）
# -------->
# TWD 26,905
#
# Total count:244
# # in this page:6
# Tonoya（托诺度假屋）
# -------->
# TWD 12,835
#
# Total count:245
# # in this page:7
# Roku an（若庫安度假屋）
# -------->
# TWD 17,872
#
# Total count:246
# # in this page:8
# Estate Tokyu Nishikyogoku（西京極東急公寓）
# -------->
# TWD 14,622
#
# Total count:247
# # in this page:9
# Yadoya Aoi（宿之葵旅館）
# -------->
# TWD 41,972
#
# Total count:248
# # in this page:10
# Great Location Kyoto Apartment（京都理想地點公寓）
# -------->
# TWD 8,814
#
# Total count:249
# # in this page:11
# Oyama Guesthouse Kyoto（京都歐亞馬旅館）
# -------->
# TWD 4,874
#
# Total count:250
# # in this page:12
# Yadoya Mibu Takahi
# -------->
# TWD 15,029
#
# Total count:251
# # in this page:13
# Higurashi-sou（日暮莊旅館）
# --------> Sell Out!!!
# Total count:252
# # in this page:14
# RESI STAY Kiyomizu（清水寺雷西住宿公寓）
# -------->
# TWD 50,772
#
# Total count:253
# # in this page:15
# Oto（奥托旅馆）
# -------->
# TWD 12,185
#
# Total count:254
# # in this page:16
# Cozy Sanjo（舒適三重旅館）
# -------->
# TWD 9,748
#
# Total count:255
# # in this page:17
# BJ family inn（BJ家庭旅館）
# -------->
# TWD 6,824
#
# ============================================================page:16
# Total count:256
# # in this page:1
# RESI STAY Anekoji（炫耀休息住宿度假屋）
# -------->
# TWD 24,492
#
# Total count:257
# # in this page:2
# Kikue Hotel Kyoto（京都菊重酒店）
# -------->
# TWD 15,760
#
# Total count:258
# # in this page:3
# Ryokan Ryokufuso（綠風莊日式旅館）
# --------> Sell Out!!!
# Total count:259
# # in this page:4
# Guest House Keage（基格旅館）
# -------->
# TWD 15,441
#
# Total count:260
# # in this page:5
# Le Machiya Kamishichiken（町家上七軒度假屋）
# -------->
# TWD 35,879
#
# Total count:261
# # in this page:6
# Kyoto Yorokobu Inn（京乃怡宿）
# -------->
# TWD 22,746
#
# Total count:262
# # in this page:7
# Hananoya House（花屋公寓）
# -------->
# TWD 20,580
#
# Total count:263
# # in this page:8
# Hisui An
# -------->
# TWD 24,262
#
# Total count:264
# # in this page:9
# Ichiyo-an（伊齊約安度假屋）
# -------->
# TWD 25,319
#
# Total count:265
# # in this page:10
# Demizu Machiya Machiya Inn（出水町家度假屋）
# -------->
# TWD 23,883
#
# Total count:266
# # in this page:11
# Kuraya Omiya Shimabara（大宮島原藏家度假屋）
# -------->
# TWD 37,784
#
# Total count:267
# # in this page:12
# An-Kona Toji（東寺安科納度假屋）
# -------->
# TWD 15,029
#
# Total count:268
# # in this page:13
# Bakpak Kyoto Hostel（京都巴帕克旅館）
# --------> Sell Out!!!
# Total count:269
# # in this page:14
# Japaning Nishijin（嘉平寧西陣度假屋）
# -------->
# TWD 11,373
#
# Total count:270
# # in this page:15
# Kyoto Nishijin Rozanji（京都西陣度假屋）
# -------->
# TWD 8,977
#
# Total count:271
# # in this page:16
# Saga Grace Hotel（嵯峨格蕾斯日式旅館）
# -------->
# TWD 22,109
#
# Total count:272
# # in this page:17
# Kyo Ichigo（京一護度假屋）
# -------->
# TWD 15,435
#
# ============================================================page:17
# Total count:273
# # in this page:1
# Japanese Style Premium 7BR Apartment
# -------->
# TWD 29,593
#
# Total count:274
# # in this page:2
# Kumo Machiya Yasaka
# -------->
# TWD 38,018
#
# Total count:275
# # in this page:3
# Guest House Kobako（科巴科賓館）
# --------> Sell Out!!!
# Total count:276
# # in this page:4
# Vacation Rental Kishu Nishijin（吉順尼什出租屋）
# -------->
# TWD 24,371
#
# Total count:277
# # in this page:5
# Traditional Zen garden and Machiya
# -------->
# TWD 21,373
#
# Total count:278
# # in this page:6
# Kuraya Kiyomizu Gojo（清水五条藏家度假屋）
# -------->
# TWD 44,160
#
# Total count:279
# # in this page:7
# Le Machiya Mibu（壬生町屋）
# -------->
# TWD 18,684
#
# Total count:280
# # in this page:8
# Kyoto Guest House Yaezakura（京都八重櫻旅館）
# -------->
# TWD 23,017
#
# Total count:281
# # in this page:9
# Coto Kyoto Toji 2（科托京都東寺2號度假屋）
# -------->
# TWD 10,372
#
# Total count:282
# # in this page:10
# Uzuki（卯月度假屋）
# -------->
# TWD 20,038
#
# Total count:283
# # in this page:11
# Kiriha inn & cafe（白霧旅館及咖啡廳）
# -------->
# TWD 19,334
#
# Total count:284
# # in this page:12
# Shimogyou An（下京一旅館）
# -------->
# TWD 24,858
#
# Total count:285
# # in this page:13
# Guesthouse Maika（麥凱賓館）
# --------> Sell Out!!!
# Total count:286
# # in this page:14
# Rakuya Kyoto Station South（京都站南度假屋）
# -------->
# TWD 17,872
#
# Total count:287
# # in this page:15
# Kuraya Kamigojocho（上五條町藏家度假屋）
# -------->
# TWD 39,773
#
# Total count:288
# # in this page:16
# Kyoumachiyado Magokoro（京町家馬誠度假屋）
# -------->
# TWD 26,266
#
# Total count:289
# # in this page:17
# Kyoto Home Tofukuji（京都東福寺度假屋）
# -------->
# TWD 8,936
#
# ============================================================page:18
# Total count:290
# # in this page:1
# Kiyomizu Riverside（清水寺河濱度假屋）
# -------->
# TWD 77,987
#
# Total count:291
# # in this page:2
# Kurenai-an（庫雷尼酒店）
# -------->
# TWD 27,011
#
# Total count:292
# # in this page:3
# Holzbau Higashiyama - Guest House In Kyoto（東山木屋- 京都酒店）
# --------> Sell Out!!!
# Total count:293
# # in this page:4
# Kyoto Graceful Taste Apartment ES107
# -------->
# TWD 72,667
#
# Total count:294
# # in this page:5
# Vacation Rental Campton Nishijin（西陣坎普頓租賃度假屋）
# -------->
# TWD 54,699
#
# Total count:295
# # in this page:6
# Lok's house in Kyoto
# -------->
# TWD 14,550
#
# Total count:296
# # in this page:7
# Zeniya-an（錢屋庵）
# -------->
# TWD 7,799
#
# Total count:297
# # in this page:8
# Le Machiya Rokkaku Suite（町屋六角套房度假屋）
# -------->
# TWD 60,196
#
# Total count:298
# # in this page:9
# Yumeya（名山度假屋）
# -------->
# TWD 19,497
#
# Total count:299
# # in this page:10
# Aoshida Holiday Rentals（奥仕达酒店 ）
# -------->
# TWD 21,067
#
# Total count:300
# # in this page:11
# Guest House Hanalei
# -------->
# TWD 21,663
#
# Total count:301
# # in this page:12
# Tsuyukusa-an（澤優庫薩安度假屋）
# -------->
# TWD 35,812
#
# Total count:302
# # in this page:13
# Kyoto Himawari Shijo Kawaramachi（京都四條河原町向日葵旅館）
# --------> Sell Out!!!
# Total count:303
# # in this page:14
# Tomogaki Inn（禦宿友垣度假屋）
# -------->
# TWD 22,746
#
# Total count:304
# # in this page:15
# Renyouan（蓮容庵旅館）
# -------->
# TWD 28,433
#
# Total count:305
# # in this page:16
# Shimabara Kaiden（嶋原懐傳度假屋）
# -------->
# TWD 33,496
#
# Total count:306
# # in this page:17
# Romankan Annex
# -------->
# TWD 12,294
#
# ============================================================page:19
# Total count:307
# # in this page:1
# Manya
# -------->
# TWD 10,154
#
# Total count:308
# # in this page:2
# Hotel Excellence Enmachi Ekimae
# -------->
# TWD 5,145
#
# Total count:309
# # in this page:3
# Sai Hotel（薩依酒店）
# --------> Sell Out!!!
# Total count:310
# # in this page:4
# Eli
# -------->
# TWD 5,957
#
# Total count:311
# # in this page:5
# Kumo Machiya Kamogawa（雲町屋小川）
# -------->
# TWD 42,243
#
# Total count:312
# # in this page:6
# Hibiki Tofukuji Sta
# -------->
# TWD 16,247
#
# Total count:313
# # in this page:7
# Hostel Ginkakuji（银座寺旅馆）
# -------->
# TWD 4,777
#
# Total count:314
# # in this page:8
# Japaning Hotel Marutamachi
# -------->
# TWD 8,530
#
# Total count:315
# # in this page:9
# Furato
# -------->
# TWD 16,247
#
# Total count:316
# # in this page:10
# Kyoto Four Sisters Residence
# -------->
# TWD 10,967
#
# Total count:317
# # in this page:11
# Kyohanayado Hontei（京華宿本邸）
# -------->
# TWD 15,998
#
# Total count:318
# # in this page:12
# SUZUKI GUESTHOUSE Annex MIYACO
# -------->
# TWD 5,416
#
# Total count:319
# # in this page:13
# Guesthouse Kikokuan（吉克寬旅館）
# --------> Sell Out!!!
# Total count:320
# # in this page:14
# Japanese Modern Style Apartment KT2
# -------->
# TWD 9,671
#
# Total count:321
# # in this page:15
# Japanese Modern Style Apartment KT3
# -------->
# TWD 10,990
#
# Total count:322
# # in this page:16
# Miyako inn Fushimi
# -------->
# TWD 12,592
#
# Total count:323
# # in this page:17
# Iori Kamoichijo
# -------->
# TWD 12,868
#
# ============================================================page:20
# Total count:324
# # in this page:1
# Kyoto Quest Apartment 39
# -------->
# TWD 16,441
#
# Total count:325
# # in this page:2
# Kyoto Quest Apartment 33
# -------->
# TWD 12,331
#
# Total count:326
# # in this page:3
# Casa Nijyo
# --------> Sell Out!!!
# Total count:327
# # in this page:4
# Kuraya Senbonsanjo
# -------->
# TWD 37,784
#
# Total count:328
# # in this page:5
# Toji Houses
# -------->
# TWD 10,764
#
# Total count:329
# # in this page:6
# Kyomachiya no Yado Karin
# -------->
# TWD 28,075
#
# Total count:330
# # in this page:7
# Sotetsu Fresa Inn Kyoto-Shijokarasuma
# -------->
# TWD 11,102
#
# Total count:331
# # in this page:8
# Sotetsu Fresa Inn Kyoto-Hachijoguchi
# -------->
# TWD 11,860
#
# Total count:332
# # in this page:9
# The Prime Pod Kyoto（波德京都膠囊旅館）
# -------->
# TWD 2,843
#
# Total count:333
# # in this page:10
# Sauna & Capsule Hotel Rumor Plaza（盧摩爾廣場桑拿膠囊旅館）
# -------->
# TWD 7,853
#
# Total count:334
# # in this page:11
# Santiago Guesthouse Kyoto（京都聖地亞哥旅館）
# -------->
# TWD 3,249
#
# Total count:335
# # in this page:12
# Book And Bed Tokyo-Kyoto（東京京都旅館）
# -------->
# TWD 9,592
#
# Total count:336
# # in this page:13
# Karasuma Kyoto Hotel（烏丸京都酒店）
# --------> Sell Out!!!
# Total count:337
# # in this page:14
# First Cabin Kyoto Karasuma（第一艙京都烏丸）
# -------->
# TWD 8,611
#
# Total count:338
# # in this page:15
# Guest House Chikyugo - The Earth Ship（地球號賓館）
# -------->
# TWD 4,062
#
# Total count:339
# # in this page:16
# K's House Kyoto - Backpackers Hostel（京都K之家背包客旅舍）
# -------->
# TWD 4,387
#
# Total count:340
# # in this page:17
# The Lower East Nine Hostel（下東九青年旅館）
# -------->
# TWD 4,489
#
# ============================================================page:21
# Total count:341
# # in this page:1
# Kyoto Guest House Hannari（京都漢娜瑞賓館）
# -------->
# TWD 4,062
#
# Total count:342
# # in this page:2
# Guesthouse tu casa（塗卡薩賓館）
# -------->
# TWD 5,362
#
# Total count:343
# # in this page:3
# Mitsuki Kyoto（京都滿月住宿加早餐旅館）
# --------> Sell Out!!!
# Total count:344
# # in this page:4
# Kyoto Guesthouse Otabi-an（京都御旅庵旅館）
# -------->
# TWD 5,687
#
# Total count:345
# # in this page:5
# Guesthouse Hyakumanben Cross（百萬遍穿行旅舍）
# -------->
# TWD 5,957
#
# Total count:346
# # in this page:6
# Tarocafe Inn（塔羅卡菲旅館）
# -------->
# TWD 4,062
#
# Total count:347
# # in this page:7
# Sakura Komachi（櫻花小町酒店）
# -------->
# TWD 4,874
#
# Total count:348
# # in this page:8
# Guest House Taiko-ya（太鼓屋）
# -------->
# TWD 5,297
#
# Total count:349
# # in this page:9
# Ichiensou（一円相旅館）
# -------->
# TWD 4,874
#
# Total count:350
# # in this page:10
# Guesthouse Tonbo（通博旅館）
# -------->
# TWD 4,062
#
# Total count:351
# # in this page:11
# APA Hotel Kyoto Ekikita
# -------->
# TWD 16,518
#
# Total count:352
# # in this page:12
# The Millennials Kyoto（京都千禧一代膠囊旅館）
# -------->
# TWD 5,741
#
# Total count:353
# # in this page:13
# Gion Miyagawacho Grandereverie（祗園宮川町大夢想賓館）
# --------> Sell Out!!!
# Total count:354
# # in this page:14
# Hotel Excellence Kyoto Station Hachijo（京都站八條口卓越酒店）
# --------> Sell Out!!!
# Total count:355
# # in this page:15
# Hotel Excellence Kyoto Ekimae（京都站前卓越酒店）
# --------> Sell Out!!!
# Total count:356
# # in this page:16
# Daiwa Roynet Hotel Kyoto Shijo Karasuma（京都四條烏丸大和ROYNET酒店）
# --------> Sell Out!!!
# Total count:357
# # in this page:17
# Kyoto Travellers Inn（京都遊客旅館）
# --------> Sell Out!!!
# ============================================================page:22
# Total count:358
# # in this page:1
# Kyonoyado Senkaku Bettei（京都之宿千鶴別邸度假屋）
# --------> Sell Out!!!
# Total count:359
# # in this page:2
# Hana-Touro Stay Yasakano-Tou Machiya Premium（花灯旅八坂之塔高級町屋）
# --------> Sell Out!!!
# Total count:360
# # in this page:3
# Kyoto Stay SAKURA Toji West II
# --------> Sell Out!!!
# Total count:361
# # in this page:4
# Piece Hostel Sanjo（三條Piece旅舍）
# --------> Sell Out!!!
# Total count:362
# # in this page:5
# Senraku（千楽度假屋）
# --------> Sell Out!!!
# Total count:363
# # in this page:6
# Kyoto Miyabi Inn（京小宿古川雅）
# --------> Sell Out!!!
# Total count:364
# # in this page:7
# Gion Kyuraku（祗園永樂度假屋）
# --------> Sell Out!!!
# Total count:365
# # in this page:8
# Thank you so muchya Eikando（禪林寺三休荘町家度假屋）
# --------> Sell Out!!!
# Total count:366
# # in this page:9
# Piece Hostel Kyoto（京都Piece旅舍）
# --------> Sell Out!!!
# Total count:367
# # in this page:10
# Kiyomizu Shukuba（清水寺旅館）
# --------> Sell Out!!!
# Total count:368
# # in this page:11
# Check in Shijokarasuma（烏丸入住酒店）
# --------> Sell Out!!!
# Total count:369
# # in this page:12
# Kyoto Uraraka Guest House（京都麗日旅館）
# --------> Sell Out!!!
# Total count:370
# # in this page:13
# Guest House Rakuen（樂園酒店）
# --------> Sell Out!!!
# Total count:371
# # in this page:14
# Bakpak Kyoto Hostel（京都巴帕克旅館）
# --------> Sell Out!!!
# Total count:372
# # in this page:15
# Laon Inn Gion Shinmonzen（拉昂祗園新廟旅館）
# --------> Sell Out!!!
# Total count:373
# # in this page:16
# karaksa hotel Kyoto Ⅰ（京都卡拉扎I號酒店）
# --------> Sell Out!!!
# Total count:374
# # in this page:17
# Izutsu Hotel Kyoto Kawaramachi Sanjo（三條河原町井筒京都酒店）
# --------> Sell Out!!!
# ============================================================page:23
# Total count:375
# # in this page:1
# Azumaya Ryokan（東谷旅館）
# --------> Sell Out!!!
# Total count:376
# # in this page:2
# COTO Kyoto Goshonishi（COTO京都御所西度假屋）
# --------> Sell Out!!!
# Total count:377
# # in this page:3
# Ark Hotel Kyoto（京都亞克酒店）
# --------> Sell Out!!!
# Total count:378
# # in this page:4
# Kyoto Machiya Ryokan Cinq（京都町家旅館Cinq）
# --------> Sell Out!!!
# Total count:379
# # in this page:5
# Ryokan Shimizu（清水日式旅館）
# --------> Sell Out!!!
# Total count:380
# # in this page:6
# Japaning Hotel Briller Kyoto（京都吉安帕寧不勒酒店）
# --------> Sell Out!!!
# Total count:381
# # in this page:7
# Guest House Murasaki（紫之上旅馆）
# --------> Sell Out!!!
# Total count:382
# # in this page:8
# Higurashi-sou（日暮莊旅館）
# --------> Sell Out!!!
# Total count:383
# # in this page:9
# Karasuma Kyoto Hotel（烏丸京都酒店）
# --------> Sell Out!!!
# Total count:384
# # in this page:10
# Guesthouse Engawa（東山之宿 緣側）
# --------> Sell Out!!!
# Total count:385
# # in this page:11
# Yuno Yado Shoei（湯野宿昭榮旅館）
# --------> Sell Out!!!
# Total count:386
# # in this page:12
# Kinparo（金柏來酒店）
# --------> Sell Out!!!
# Total count:387
# # in this page:13
# Nishikiro（西喜樓旅館）
# --------> Sell Out!!!
# Total count:388
# # in this page:14
# Yadoya Manjiro（萬治郎日式旅館）
# --------> Sell Out!!!
# Total count:389
# # in this page:15
# Gosho Nishi Kyoto Heian Hotel（京都御苑西平安酒店）
# --------> Sell Out!!!
# Total count:390
# # in this page:16
# Guest House Rakuen（樂園酒店）
# --------> Sell Out!!!
# Total count:391
# # in this page:17
# Riverside Takase（濱江高瀨）
# --------> Sell Out!!!
# ============================================================page:24
# Total count:392
# # in this page:1
# Kyoto Gion Inn（京都祗園酒店）
# --------> Sell Out!!!
# Total count:393
# # in this page:2
# Inn Keepers House Sanjusangendo（三十三間堂守護者之家公寓）
# --------> Sell Out!!!
# Total count:394
# # in this page:3
# Azumaya Ryokan（東谷旅館）
# --------> Sell Out!!!
# Total count:395
# # in this page:4
# Kyoto Globalhouse Zen（京都全球屋禪旅館）
# --------> Sell Out!!!
# Total count:396
# # in this page:5
# Rangetsu（嵐月旅館）
# --------> Sell Out!!!
# Total count:397
# # in this page:6
# Guesthouse Higashiyama Jao（東山角賓館）
# --------> Sell Out!!!
# Total count:398
# # in this page:7
# Guest House Koiya（鯉屋賓館）
# --------> Sell Out!!!
# Total count:399
# # in this page:8
# Matsumoto Ryokan（松本旅館）
# --------> Sell Out!!!
# Total count:400
# # in this page:9
# Mitsuki Kyoto（京都滿月住宿加早餐旅館）
# --------> Sell Out!!!
# Total count:401
# # in this page:10
# Ryokan Nenrinbo（然林房旅館）
# --------> Sell Out!!!
# Total count:402
# # in this page:11
# Ryokan Hinomoto（海諾莫托旅館）
# --------> Sell Out!!!
# Total count:403
# # in this page:12
# FALDIC inn. ANZU（法爾迪森安津公寓）
# --------> Sell Out!!!
# Total count:404
# # in this page:13
# Guesthouse Engawa（東山之宿 緣側）
# --------> Sell Out!!!
# Total count:405
# # in this page:14
# prinz（普林茨公寓式酒店）
# --------> Sell Out!!!
# Total count:406
# # in this page:15
# Hotel Sunroute Kyoto（京都燦路都大飯店）
# --------> Sell Out!!!
# Total count:407
# # in this page:16
# Oyado Mitsuba（禦宿三葉公寓）
# --------> Sell Out!!!
# Total count:408
# # in this page:17
# Kyoto Hot Spring Hatoya Zuihokaku Hotel（京都溫泉鳩屋瑞鳳閣酒店）
# --------> Sell Out!!!
# ============================================================page:25
# Total count:409
# # in this page:1
# Toshiharu Ryokan（十四春旅館）
# --------> Sell Out!!!
# Total count:410
# # in this page:2
# Momijiya of Takao Kyoto（红叶家本館 高雄山荘）
# --------> Sell Out!!!
# Total count:411
# # in this page:3
# Mugen（無限酒店）
# --------> Sell Out!!!
# Total count:412
# # in this page:4
# Chiyotsuru（京小宿千代鶴度假屋）
# --------> Sell Out!!!
# Total count:413
# # in this page:5
# Sakara Gion（祗園櫻花酒店）
# --------> Sell Out!!!
# Total count:414
# # in this page:6
# Guesthouse Kikokuan（吉克寬旅館）
# --------> Sell Out!!!
# Total count:415
# # in this page:7
# Coto Kyoto Toji 4（京都東寺科托4號度假屋）
# --------> Sell Out!!!
# Total count:416
# # in this page:8
# Guest House Yuyu（雪結度假屋）
# --------> Sell Out!!!
# Total count:417
# # in this page:9
# Casa Nijyo
# --------> Sell Out!!!
# Total count:418
# # in this page:10
# Toyoko Inn Kyoto Gojo-Omiya（京都五條大宮東橫旅館）
# --------> Sell Out!!!
# Total count:419
# # in this page:11
# Yamatoya（亞瑪圖雅旅館）
# --------> Sell Out!!!
# Total count:420
# # in this page:12
# Awesome Japanese Style Apartment in Good Locartion
# --------> Sell Out!!!
# Total count:421
# # in this page:13
# Gosho Nishi Kyoto Heian Hotel（京都御苑西平安酒店）
# --------> Sell Out!!!
# Total count:422
# # in this page:14
# Kyoto Matsuya
# --------> Sell Out!!!
# Total count:423
# # in this page:15
# Kyo no Yado Akizushima（京之宿蜻蛉島旅館）
# --------> Sell Out!!!
# Total count:424
# # in this page:16
# Fujiya Ryokan（藤屋旅館）
# --------> Sell Out!!!
# Total count:425
# # in this page:17
# Rinn Nanajo Takasegawa（鈴七條高瀬川邸度假屋）
# --------> Sell Out!!!
# ============================================================page:26
# Total count:426
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:427
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:428
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:429
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:430
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:431
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:432
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:433
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:434
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:435
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:436
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:437
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:438
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:439
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:440
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:441
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:442
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:27
# Total count:443
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:444
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:445
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:446
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:447
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:448
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:449
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:450
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:451
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:452
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:453
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:454
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:455
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:456
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:457
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:458
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:459
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:28
# Total count:460
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:461
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:462
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:463
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:464
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:465
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:466
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:467
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:468
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:469
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:470
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:471
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:472
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:473
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:474
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:475
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:476
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:29
# Total count:477
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:478
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:479
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:480
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:481
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:482
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:483
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:484
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:485
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:486
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:487
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:488
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:489
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:490
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:491
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:492
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:493
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:30
# Total count:494
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:495
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:496
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:497
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:498
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:499
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:500
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:501
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:502
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:503
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:504
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:505
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:506
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:507
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:508
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:509
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:510
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:31
# Total count:511
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:512
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:513
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:514
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:515
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:516
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:517
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:518
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:519
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:520
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:521
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:522
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:523
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:524
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:525
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:526
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:527
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:32
# Total count:528
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:529
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:530
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:531
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:532
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:533
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:534
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:535
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:536
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:537
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:538
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:539
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:540
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:541
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:542
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:543
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:544
# ...
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:731
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:44
# Total count:732
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:733
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:734
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:735
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:736
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:737
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:738
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:739
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:740
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:741
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:742
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:743
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:744
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:745
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:746
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:747
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:748
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:45
# Total count:749
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:750
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:751
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:752
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:753
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:754
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:755
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:756
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:757
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:758
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:759
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:760
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:761
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:762
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:763
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:764
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:765
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:46
# Total count:766
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:767
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:768
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:769
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:770
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:771
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:772
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:773
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:774
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:775
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:776
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:777
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:778
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:779
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:780
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:781
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:782
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:47
# Total count:783
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:784
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:785
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:786
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:787
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:788
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:789
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:790
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:791
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:792
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:793
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:794
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:795
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:796
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:797
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:798
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:799
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:48
# Total count:800
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:801
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:802
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:803
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:804
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:805
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:806
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:807
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:808
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:809
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:810
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:811
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:812
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:813
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:814
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:815
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:816
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:49
# Total count:817
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:818
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:819
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:820
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:821
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:822
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:823
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:824
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:825
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:826
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:827
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:828
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:829
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:830
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:831
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:832
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:833
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:50
# Total count:834
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:835
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:836
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:837
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:838
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:839
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:840
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:841
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:842
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:843
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:844
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:845
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:846
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:847
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:848
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:849
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:850
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:51
# Total count:851
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:852
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:853
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:854
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:855
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:856
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:857
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:858
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:859
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:860
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:861
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:862
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:863
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:864
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:865
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:866
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:867
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:52
# Total count:868
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:869
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:870
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:871
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:872
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:873
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:874
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:875
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:876
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:877
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:878
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:879
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:880
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:881
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:882
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:883
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:884
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:53
# Total count:885
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:886
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:887
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:888
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:889
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:890
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:891
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:892
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:893
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:894
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:895
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:896
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:897
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:898
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:899
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:900
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:901
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
# ============================================================page:54
# Total count:902
# # in this page:1
# Guest House Route 53 Nagomian（和平庵53號公路度假屋）
# --------> Sell Out!!!
# Total count:903
# # in this page:2
# Guest House Sakura
# --------> Sell Out!!!
# Total count:904
# # in this page:3
# Gion Miyako Kyomachiya（祗園都市京町屋）
# --------> Sell Out!!!
# Total count:905
# # in this page:4
# Nijo Yurakuan
# --------> Sell Out!!!
# Total count:906
# # in this page:5
# Furusatono Ie（鄉村之家旅館）
# --------> Sell Out!!!
# Total count:907
# # in this page:6
# Life Tofukuji（生命東福寺度假屋）
# --------> Sell Out!!!
# Total count:908
# # in this page:7
# Kyoisuke Mukadeyacho（京蘇可百足屋町）
# --------> Sell Out!!!
# Total count:909
# # in this page:8
# SANAN & UHOKU（森安與優和子度假屋）
# --------> Sell Out!!!
# Total count:910
# # in this page:9
# Kyoto Good View Apartment 02
# --------> Sell Out!!!
# Total count:911
# # in this page:10
# Kawasemi an
# --------> Sell Out!!!
# Total count:912
# # in this page:11
# Tateitoan（泰迪托恩度假屋）
# --------> Sell Out!!!
# Total count:913
# # in this page:12
# Satoi Omiya Gojo Seishi
# --------> Sell Out!!!
# Total count:914
# # in this page:13
# KKR Kyoto Kuniso（京都KKR庫尼索酒店）
# --------> Sell Out!!!
# Total count:915
# # in this page:14
# RESI STAY Gion Shijo（萊什祗園孩子旅館）
# --------> Sell Out!!!
# Total count:916
# # in this page:15
# Kyonoya Tofukuji（東福寺京之度假屋）
# --------> Sell Out!!!
# Total count:917
# # in this page:16
# The Gion House (Upper Level)
# --------> Sell Out!!!
# Total count:918
# # in this page:17
# Kobito House（科比託之家）
# --------> Sell Out!!!
