# %%
# Booking hotel crawler
import requests
import time
from bs4 import BeautifulSoup
from collections import Counter

# %%
#homePage = https://www.booking.com/index.zh-tw.html?aid=304142;label=gen173nr-1DCAQoggJCA1hfWEgwYgVub3JlZmjnAYgBAZgBMLgBBsgBDNgBA-gBAfgBApICAXmoAgM;sid=c7ed355e0865f9c5a92a7c284f06b597;sb_price_type=total&
#url = https://www.booking.com/searchresults.zh-tw.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AED6AEBkgIBeagCAw&sid=c7ed355e0865f9c5a92a7c284f06b597&sb=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.zh-tw.html%3Faid%3D304142%3Blabel%3Dgen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AED6AEBkgIBeagCAw%3Bsid%3Dc7ed355e0865f9c5a92a7c284f06b597%3Bsb_price_type%3Dtotal%26%3B&ss=%E4%BA%AC%E9%83%BD&checkin_year=&checkin_month=&checkin_monthday=&checkout_year=&checkout_month=&checkout_monthday=&room1=A%2CA&no_rooms=1&group_adults=2&group_children=0&dest_id=&dest_type=&search_pageview_id=8aa3050eb32a0225&search_selected=false&ss_raw=%E4%BA%AC%E9%83%BD
url2 = "https://www.booking.com/searchresults.zh-tw.html?label=gen173nr-1FCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AEB6AEB-AELkgIBeagCAw&sid=1be0bee52e034c3d2cf97e52fd2cf0d3&checkin_month=10&checkin_monthday=19&checkin_year=2017&checkout_month=10&checkout_monthday=21&checkout_year=2017&class_interval=1&dest_id=-235402&dest_type=city&dtdisc=0&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&src=index&src_elem=sb&ss=%E4%BA%AC%E9%83%BD%2C%20%E4%BA%AC%E9%83%BD%E5%BA%9C%2C%20%E6%97%A5%E6%9C%AC&ss_all=0&ss_raw=%E4%BA%AC%E9%83%BD&ssb=empty&sshis=0&rows=40&offset=40&sr_ajax=1&b_gtt=dLYAeZFVJfNTBdAHUdPHUBSLWVJBJEQNVZXZedHO&_=1500870075261"    
#https://www.booking.com/searchresults.zh-tw.html?label=gen173nr-1FCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AEB6AEB-AELkgIBeagCAw&sid=c7ed355e0865f9c5a92a7c284f06b597&sb=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.zh-tw.html%3Flabel%3Dgen173nr-1FCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AEB6AEB-AELkgIBeagCAw%3Bsid%3Dc7ed355e0865f9c5a92a7c284f06b597%3Bsb_price_type%3Dtotal%26%3B&ss=%E4%BA%AC%E9%83%BD&ssne=%E4%BA%AC%E9%83%BD&ssne_untouched=%E4%BA%AC%E9%83%BD&dest_id=-235402&dest_type=city&checkin_year=2017&checkin_month=7&checkin_monthday=24&checkout_year=2017&checkout_month=7&checkout_monthday=28&room1=A%2CA&no_rooms=1&group_adults=2&group_children=0

# %%
url = "https://www.booking.com/searchresults.zh-tw.html?label=gen173nr-1FCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AEB6AEB-AELkgIBeagCAw&sid=c7ed355e0865f9c5a92a7c284f06b597&sb=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.zh-tw.html%3Flabel%3Dgen173nr-1FCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AEB6AEB-AELkgIBeagCAw%3Bsid%3Dc7ed355e0865f9c5a92a7c284f06b597%3Bsb_price_type%3Dtotal%26%3B&ss=%E4%BA%AC%E9%83%BD&ssne=%E4%BA%AC%E9%83%BD&ssne_untouched=%E4%BA%AC%E9%83%BD&dest_id=-235402&dest_type=city&checkin_year=2017&checkin_month=7&checkin_monthday=24&checkout_year=2017&checkout_month=7&checkout_monthday=28&room1=A%2CA&no_rooms=1&group_adults=2&group_children=0"

# %%
res = requests.get(url2)

# %%
res.status_code
# Out:
# 200

# %%
# Use BeautifulSoup as my text parser
soup = BeautifulSoup(res.text, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# http://www.workingatbooking.com/
# --><!-- wdot-802 --><html class="noJS b_bot b_bot supports_fontface " lang="zh-tw" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# booking_com: http://ogp.me/ns/fb/booking_com#">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="origin" name="referrer"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <link data-main-css="1" href="https://s-ec.bstatic.com/static/css/main_ecv6/7f122d5d28c1dd5cf258d5b2b8de119967af557d.css" rel="stylesheet"/>
# <link href="https://s-ec.bstatic.com/static/css/main_exps_ecv6/8811dc08670a32168da184ac7177aa812ce35f21.css" rel="stylesheet"/>
# <link href="https://t-ec.bstatic.com/static/css/gprof_icons_ecv6/0bc5af18d3af2ff1f28fec8b36f38e0559f1447c.css" rel="stylesheet"/>
# ...

# %%
#hotellist_inner > div.sr_item.sr_item_new.sr_item_default.sr_property_block.sr_flex_layout.sr_item--highlighted.with_dates

# %%
for link in soup.select("h3.dod-banner__hotel-name"):
    print(link)

# %%
# find hotel name   //*[@id="hotellist_inner"]/div[3]/div[2]/div[1]/div[1]/h3/a/span
cnt = 0
for i in soup.select("#hotellist_inner > div.sr_item > div[2]"):
    print(i)
    cnt = cnt + 1
    print("====================================" +  str(cnt)  + "==========================================")

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# http://www.workingatbooking.com/
# --><!-- wdot-802 --><html class="noJS b_bot b_bot supports_fontface " lang="zh-tw" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# booking_com: http://ogp.me/ns/fb/booking_com#">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="origin" name="referrer"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <link data-main-css="1" href="https://s-ec.bstatic.com/static/css/main_ecv6/7f122d5d28c1dd5cf258d5b2b8de119967af557d.css" rel="stylesheet"/>
# <link href="https://s-ec.bstatic.com/static/css/main_exps_ecv6/8811dc08670a32168da184ac7177aa812ce35f21.css" rel="stylesheet"/>
# <link href="https://t-ec.bstatic.com/static/css/gprof_icons_ecv6/0bc5af18d3af2ff1f28fec8b36f38e0559f1447c.css" rel="stylesheet"/>
# ...

# %%
for row in soup.select(".sr_item div"):
    print(row)
# Out:
# <div class="ribbon--outer ribbon__extra" data-et-view="customGoal:YPNdKNKNKZTPeQYccSQJbQBdJOLTQcYdOBHe:1">
# <div class="ribbon js-fly-content-tooltip" data-content-tooltip="&lt;span class='ribbon--tooltip'&gt;此為京都的熱銷住宿－其他旅客於過去 24 小時內已預訂 155 次！&lt;/span&gt;">
# 熱銷
# </div>
# </div>
# <div class="ribbon js-fly-content-tooltip" data-content-tooltip="&lt;span class='ribbon--tooltip'&gt;此為京都的熱銷住宿－其他旅客於過去 24 小時內已預訂 155 次！&lt;/span&gt;">
# 熱銷
# </div>
# <div data-et-view="YdVTbLSVUbLNALKe:1"></div>
# <div class="address">
# <a class=" jq_tooltip district_link visited_link " data-coords="135.753225646913,34.9865518315591" data-et-click="
# OQZcBJHMbTDVdTLO:1
# customGoal:ebcOLWeMZJHScDbRT:1
# " data-et-mouseenter="OQREFeGVNFLUQOJaYO:1" data-google-track="Click/Action: sr_map_link_used" data-map-caption="" href="
# /hotel/jp/apa-kyoto-eki-horikawa-dori.zh-tw.html?dest_type=city;dest_id=-235402;
# #hotelTmpl" rel="noopener" target="_blank" title="
# 下京區
# 是寺廟、觀光和文化的絕佳選擇 &amp;ndash; 顯示地圖">
# ...

# %%
A = soup.select_one(".sr_item").find(lambda x: x.get('data-et-click') == 'customGoal:OQRWSEcYC:4')
A.select(".sr-hotel__name")[0]
# Out:
# <span class="sr-hotel__name">
# APA Hotel Kyoto-eki Horikawa-Dori（京都站堀川通阿帕酒店）
# </span>

# %%
B = soup.select_one(".sr_item")
B
# Out:
# <div class="sr_item sr_item_new sr_item_default sr_property_block sr_item_bs sr_item_no_dates " data-class="3" data-et-click=" " data-hotelid="359484" data-score="7.1">
# <table class="sr_item_legacy">
# <tbody>
# <tr>
# <td class="sr_item_legacy_photo id=" hotel_359484="" rowspan="2">
# <div class="ribbon--outer ribbon__extra" data-et-view="customGoal:YPNdKNKNKZTPeQYccSQJbQBdJOLTQcYdOBHe:1">
# <div class="ribbon js-fly-content-tooltip" data-content-tooltip="&lt;span class='ribbon--tooltip'&gt;此為京都的熱銷住宿－其他旅客於過去 24 小時內已預訂 155 次！&lt;/span&gt;">
# 熱銷
# </div>
# </div>
# <a class=" sr_item_photo_link sr_hotel_preview_track " href="/hotel/jp/apa-kyoto-eki-horikawa-dori.zh-tw.html?dest_type=city;dest_id=-235402?from_hc_img=1#hotelTmpl" rel="noopener" target="_blank">
# ...

# %%
C = soup.select_one(".sr_item").find(lambda x: x['data-et-click'] == 'customGoal:OQRWSEcYC:1')
C
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-e6acc361369d> in <module>()
# ----> 1 C = soup.select_one(".sr_item").find(lambda x: x['data-et-click'] == 'customGoal:OQRWSEcYC:1')
#       2 C
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in find(self, name, attrs, recursive, text, **kwargs)
#    1290         criteria."""
#    1291         r = None
# -> 1292         l = self.find_all(name, attrs, recursive, text, 1, **kwargs)
#    1293         if l:
#    1294             r = l[0]
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1311         if not recursive:
#    1312             generator = self.children
# -> 1313         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1314     findAll = find_all       # BS3
#    1315     findChildren = find_all  # BS2
#
# ...

# %%
//*[@id="hotellist_inner"]/div[3]/div[2]/div[4]/div/table/tbody/tr/td[3]/div/strong/b
