# %%
import requests
import time
from bs4 import BeautifulSoup
from collections import Counter
import re

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}
offset =  0
url = "https://www.booking.com/searchresults.zh-tw.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AED6AEBkgIBeagCAw&sid=25f3195cbf76726e8ffac861269a0d24&checkin_month=8&checkin_monthday=24&checkin_year=2017&checkout_month=8&checkout_monthday=27&checkout_year=2017&class_interval=1&dest_id=-235402&dest_type=city&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&src=index&src_elem=sb&ss=%E4%BA%AC%E9%83%BD&ssb=empty&ssne=%E4%BA%AC%E9%83%BD&ssne_untouched=%E4%BA%AC%E9%83%BD&rows=40&offset="+str(offset)+"&sr_ajax=1&b_gtt=dLYAeZFVJfNTBdAHUdPHUBSSUVJfcbWYaNLDRCAET&_=1501050897864"   

res = requests.get(url, headers = headers)
res.text
# Out:
# '<!-- aHR0cDovL3d3dy53b3JraW5nYXRib29raW5nLmNvbS8K -->\n<template data-id="heading" data-type="block">\n<div class="sr_header--wrapper">\n<div class="sr_header--title ">\n<div class="sr_header " role="heading"\ndata-et-view="TULQWNVLBLWIJDAOfUYdXaO:1"\n>\n<h1>\n京都：找到 815 間住宿&nbsp;－包括 113 項超值優惠\n</h1>\n\t\n<h2>\n3 大旅遊主題：<strong>寺廟</strong>、<strong>文化</strong>、<strong>觀光</strong>\n  \n</h2>\n</div>\n</div>\n<a\nclass=" show_map sr_header--map "\nhref="#map_opened-map-header-cta"\nid="map-header-cta"\ndata-map-id="map-header-cta"\ndata-source="map-header-cta"\n>\n<span class="switch-map-view">\n地圖顯示\n</span>\n</a>\n</div>\n</template>\n<template data-id="sr_messages" data-type="block">\n</template>\n<template\ndata-id="hotel_list"\ndata-type="block"\n>\n<div class="hotellist sr_double_search" >\n<div id="hotellist_inner" class="  wider_image  "\nrole="region" aria-label="搜尋結果"\n>\n<div class=" dod-banner js--dod-banner dod-banner-room__conditions-qty-1  dod-banner--longer-stay     "\ndata-et-click="customGoal:YPNEfAEYfdVO:1\n"\ndata-hotelid="2098073"\ndata-istrackingon="1"\n>\n<div class="dod-banner__header">\n<div class="dod-banner__logo"><i class="bicon-deal-of-the-day"></i></div>\n <div class="dod-banner__cd js--dod-countdown-banner" data-expires-at="1501167600" tabindex="-1"> <div class="dod-banner__cd-label"> <script type=\'track_copy\' data-hash=\'ZOBESIJOPEQNZZPBNPMO\'></script>剩下時間： </div> <div class="dod-banner__cd-timer">  <div class="dod-banner__cd-section dod-banner__cd-days js--days-container"> 1 天 </div>  <div class="dod-banner__cd-section dod-banner__cd-time js--day-time-container"> 6：27：35 </div> </div> </div> \n<div class="dod-banner__title">\n今日特惠\n</div>\n<div class="clearfix"></div>\n</div>\n<div class="dod-banner__body">\n<div class="dod-banner__media">\n<div    data-content-tooltip="<span class=\'ribbon--tooltip ribbon--tooltip__long-copy\'>此折扣價格乃基於您的指定入住日期前後共 30 天內（入住日期前 15 天以及後 15 天，若本日至入住日之間隔未滿 15 天時，將自入住日之後納入相應的天數計算），該住宿現提供相同訂房條款之房型中價格第 3 高的項目計算。為了作出公平的比較，我們始終使用相同的訂房條款（餐飲政策、取消政策和客房類型）。這意味著您將以低於一年中相同時段的其他入住日期的價格預訂相同的客房。</span>"    data-discount="44"    class="ribbon\njs-fly-content-tooltip\njs-ribbon-discount\n" rel="380" >\n<div class="ribbon--number">－44%</div>\n<div class="ribbon--word">今日！</div>\n            <i\n                class="\n                    bicon-question\n                    \n                    crossedout-price-icon"\n                \n                \n                \n                \n                \n            >\n            </i>\n        \n</div>\n<div class="dod-banner__image-outer">\n<img class="dod-banner__image" src="https://s-ec.bstatic.com/images/hotel/square200/855/85589698.jpg">\n</div>\n</div>\n<div class="dod-banner__content">\n<div class="dod-banner__hotel-header">\n<div class="dod-banner__hotel-info">\n<h3 class="dod-banner__hotel-name dod-banner__hotel-info-block">\n<a href="\n/hotel/jp/the-kiyomizu-gion.zh-tw.html?aid=304142;label=gen173nr-1BCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AEB6AEBkgIBeagCAw;sid=cbed99932edfa6301ed0beb1ad5e34d2;checkin=2017-08-24;checkout=2017-08-27;dotd_fb=1;promo=2098073;srpvid=5cad3c0c816a00a4&;from_sr_dod=1;from=searchresults\n#hotelTmpl"\nclass="dod-banner__hotel-link"\ntarget="_blank"\n>\n清水祇園酒店\n</a>\n</h3>\n<div class="dod-banner__hotel-stars dod-banner__hotel-info-block">\n<i class="b-sprite stars ratings_stars_3 star_track"></i>\n</div>\n<div class="dod-banner__hotel-address" data-address="" data-address-2="Higashiyama-ku Yumiyacho 47" data-name="清水祇園酒店" data-name-2="">\n<div class="address">\n<a\nhref="/hotel/jp/the-kiyomizu-gion.zh-tw.html?aid=304142;label=gen173nr-1BCAEoggJCAlhYSDNiBW5vcmVmaOcBiAEBmAEwuAEGyAEM2AEB6AEBkgIBeagCAw;sid=cbed99932edfa6301ed0beb1ad5e34d2;checkin=2017-08-24;checkout=2017-08-27;dotd_fb=1;promo=2098073;srpvid=5cad3c0c816a00a4&;from_sr_dod=1;from=searchresults;\nmap=1\n&amp;msd=1#hotelTmpl"\nid="show_id"\ndata-map-id="show_id"\nclass="\njq_tooltip\ndistrict_link\nhighlighted_district\nvisited_lin ...
