# %%
# Agoda

import requests
from bs4 import BeautifulSoup
import re

# %%
# Agoda

https://www.agoda.com/zh-tw/pages/agoda/default/DestinationSearchResult.aspx?
    asq=vzE13Tw%2BA44FEA9XTR4va3Lm82mxnMePSbV%2BkKBIp45NGaIPwwpUpI0BEB9HfPq9wzTMpqqFWBQkNFdbRVvHxGaVfAwyXfW28jCp0bxDEn67tyOMC%2BZQEWOmKmumml9s%2BqFIBXHNl8IMznDl%2BEp4gWoFY9bJHID%2BW6SU%2F3yw7bWvpAOzjwLqE6MvO5hS%2BUSA3PXigDsrTdOFuDpLfEPc68w8NgfLxl%2B0N57w7IQEAvw%3D
    &city=1784
    &cid=-209
    &tick=636371255578
    &pagetypeid=1
    &origin=TW
    &tag=
    &gclid=
    &aid=130243
    &userId=37072151-b961-47fa-a9f3-7ffe6935a5e6
    &languageId=20
    &sessionId=dq3qlxihubovnmnr1oxyyfpk
    &storefrontId=3
    &currencyCode=TWD
    &htmlLanguage=zh-tw
    &trafficType=User
    &cultureInfoName=zh-TW
    &checkIn=2017-08-25
    &checkOut=2017-08-27
    &los=2
    &rooms=1
    &adults=2
    &children=0
    &childages=
    &priceCur=TWD
    &hotelReviewScore=5
    &ckuid=37072151-b961-47fa-a9f3-7ffe6935a5e6

# %%
# page 2
https://www.agoda.com/zh-tw/pages/agoda/default/DestinationSearchResult.aspx?
    asq=vzE13Tw%2BA44FEA9XTR4va3Lm82mxnMePSbV%2BkKBIp45NGaIPwwpUpI0BEB9HfPq9wzTMpqqFWBQkNFdbRVvHxGaVfAwyXfW28jCp0bxDEn67tyOMC%2BZQEWOmKmumml9s%2BqFIBXHNl8IMznDl%2BEp4gWoFY9bJHID%2BW6SU%2F3yw7bWvpAOzjwLqE6MvO5hS%2BUSA3PXigDsrTdOFuDpLfEPc68w8NgfLxl%2B0N57w7IQEAvw%3D
    &city=1784
    &cid=-209
    &tick=636371255578
    &pagetypeid=1
    &origin=TW
    &tag=
    &gclid=
    &aid=130243
    &userId=37072151-b961-47fa-a9f3-7ffe6935a5e6
    &languageId=20
    &sessionId=dq3qlxihubovnmnr1oxyyfpk
    &storefrontId=3
    &currencyCode=TWD
    &htmlLanguage=zh-tw
    &trafficType=User
    &cultureInfoName=zh-TW
    &checkIn=2017-08-25
    &checkOut=2017-08-27
    &los=2
    &rooms=1
    &adults=2
    &children=0
    &childages=
    &priceCur=TWD
    &hotelReviewScore=5
    &ckuid=37072151-b961-47fa-a9f3-7ffe6935a5e6

# %%
url = "https://www.agoda.com/zh-tw/pages/agoda/default/DestinationSearchResult.aspx?asq=vzE13Tw%2BA44FEA9XTR4va3Lm82mxnMePSbV%2BkKBIp45NGaIPwwpUpI0BEB9HfPq9wzTMpqqFWBQkNFdbRVvHxGaVfAwyXfW28jCp0bxDEn67tyOMC%2BZQEWOmKmumml9s%2BqFIBXHNl8IMznDl%2BEp4gWoFY9bJHID%2BW6SU%2F3yw7bWvpAOzjwLqE6MvO5hS%2BUSA3PXigDsrTdOFuDpLfEPc68w8NgfLxl%2B0N57w7IQEAvw%3D&city=1784&cid=-209&tick=636371255578&pagetypeid=1&origin=TW&tag=&gclid=&aid=130243&userId=37072151-b961-47fa-a9f3-7ffe6935a5e6&languageId=20&sessionId=dq3qlxihubovnmnr1oxyyfpk&storefrontId=3&currencyCode=TWD&htmlLanguage=zh-tw&trafficType=User&cultureInfoName=zh-TW&checkIn=2017-08-25&checkOut=2017-08-27&los=2&rooms=1&adults=2&children=0&childages=&priceCur=TWD&hotelReviewScore=5&ckuid=37072151-b961-47fa-a9f3-7ffe6935a5e6"
$$$$$$$https://www.agoda.com/zh-tw/pages/agoda/default/DestinationSearchResult.aspx?asq=vzE13Tw%2BA44FEA9XTR4va3Lm82mxnMePSbV%2BkKBIp45NGaIPwwpUpI0BEB9HfPq9wzTMpqqFWBQkNFdbRVvHxGaVfAwyXfW28jCp0bxDEn67tyOMC%2BZQEWOmKmumml9s%2BqFIBXHNl8IMznDl%2BEp4gZragcGuMgj%2FYZkE6TEozYOvpAOzjwLqE6MvO5hS%2BUSA3PXigDsrTdOFuDpLfEPc68w8NgfLxl%2B0N57w7IQEAvw%3D&city=1784&cid=-209&tick=636371709663&pagetypeid=1&origin=TW&tag=&gclid=&aid=130243&userId=e6c828c0-a240-4d15-acb1-73dc1d5c09a4&languageId=20&sessionId=5vedcpfk3k4muhn0qdau4pyr&storefrontId=3&currencyCode=TWD&htmlLanguage=zh-tw&trafficType=User&cultureInfoName=zh-TW&checkIn=2017-08-25&checkOut=2017-08-27&los=2&rooms=1&adults=2&children=0&childages=&priceCur=TWD&hotelReviewScore=5&ckuid=e6c828c0-a240-4d15-acb1-73dc1d5c09a4
headers = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36"}

# %%
data = {'asq':'vzE13Tw+A44FEA9XTR4va3Lm82mxnMePSbV+kKBIp45NGaIPwwpUpI0BEB9HfPq9wzTMpqqFWBQkNFdbRVvHxGaVfAwyXfW28jCp0bxDEn67tyOMC+ZQEWOmKmumml9s+qFIBXHNl8IMznDl+Ep4gWoFY9bJHID+W6SU/3yw7bWvpAOzjwLqE6MvO5hS+USA3PXigDsrTdOFuDpLfEPc68w8NgfLxl+0N57w7IQEAvw=',
'city':1784,
'cid':-209,
'tick':636371255578,
'pagetypeid':5,
'origin':'TW',
'tag':"",
'gclid':"",
'aid':130243,
'userId':'37072151-b961-47fa-a9f3-7ffe6935a5e6',
'languageId':20,
'sessionId':'dq3qlxihubovnmnr1oxyyfpk',
'storefrontId':3,
'currencyCode':'TWD',
'htmlLanguage':'zh-tw',
'trafficType':'User',
'cultureInfoName':'zh-TW',
'checkIn':'2017-08-25',
'checkOut':'2017-08-27',
'los':2,
'rooms':1,
'adults':2,
'children':0,
'childages':"",
'priceCur':'TWD',
'hotelReviewScore':5,
'ckuid':'37072151-b961-47fa-a9f3-7ffe6935a5e6'}

# %%
cookie = {"cookie":'ABSTATIC=1; agoda.user.03=UserId=37072151-b961-47fa-a9f3-7ffe6935a5e6; ASP.NET_SessionId=dq3qlxihubovnmnr1oxyyfpk; agoda.prius=PriusID=0&PointsMaxTraffic=Agoda; agodalbhkg=www.agoda.com_cluster_2a; agoda.firstclicks=-209||||2017-07-31T19:17:37||dq3qlxihubovnmnr1oxyyfpk||{"IsPaid":false,"gclid":"","Type":""}; agoda.lastclicks=-209||||2017-07-31T19:17:37||dq3qlxihubovnmnr1oxyyfpk||{"IsPaid":false,"gclid":"","Type":""}; ak_bmsc=9F1D422B57E2CE3DBEDFC5A907F159C13DDC3E9372750000E21F7F598D400B0E~plftxvoDydSIssfDbu6PnQrRGIRINmGVahpKgvNfzgHn9eqxsBH0nQsUMua+c2Szt+mPS7OpIhmOZkbZh72RqCx5clBOdsUPpYa2XBql+aVuq+kagF8GD3iCtWxsGgl5jbH3+WwLcM36WFdOSONut6dPZYydKc8ZMr2rH5tE5juncgjt5XONS/9daLqhFlwULn0Qimg/Mojrut9H6RBwKKs5HGmp4FGotxepUa1ZyUvMM=; _ab50group=GroupB; _40-40-20Split=Group40A; mousestats_vi=4470caaf3ae7699b2822; kampyle_userid=b8a5-7aef-3e14-00dc-93d6-7792-3127-7887; backendDataInSessionFlag=false; kampyleUserSession=1501503348142; kampyleUserSessionsCount=1; cd_user_id=15d9892de38b13-0a390e92d22956-8383667-144000-15d9892de39c3d; ABSTATIC=1; agoda.attr.03=CookieId=3a529dac-3809-4b0d-96a2-4c4950fba57a&ATItems=-209$07-31-2017 19:19$; agoda.cci.attr=CItems=-209$07-31-2017 19:19:17.829$dq3qlxihubovnmnr1oxyyfpk$|; agoda.allclicks=-209||||2017-07-31T20:02:45||dq3qlxihubovnmnr1oxyyfpk||{"IsPaid":false,"gclid":"","Type":"LC"}; agoda.search.01=SHist=1$1784$6080$2$1$2$0$0$$|1$1784$6080$2$1$2$0$0$$|1$1784$6080$2$1$2$0$0$$|1$1784$6080$2$1$2$0$0$$; utag_main=v_id:015d9892d6c300154d825d5a9e8904073002506b00978$_sn:2$_ss:0$_st:1501507854804$_pn:2%3Bexp-session$ses_id:1501505936166%3Bexp-session; _ga=GA1.2.1314784643.1501503347; _gid=GA1.2.143489929.1501503347; _gat_t3=1; kampyleSessionPageCounter=6; _gali=paginationPrev; agoda.version.03=CookieId=9bc9c31a-50a2-4dab-a0a4-b5d23e16df13&AllocId=4ba826318518b3592c05fa90c83f4ebe11788e7def521243a226db84eb329652de2de81b9104a56b4589dc973de6d1f437cba486fe59bf1ea187d39526ffc1b2370da2fa3e4959950f794c267c3a32b2a7abc9c8269bc9c31a50a2dab0a4b5d23e16df13&DPN=1&DLang=zh-tw&CurLabel=TWD&Alloc=953$70|2069$58|2071$50|2079$52|2221$25|2188$100|2192$63|2211$28|2201$73|2273$62|2291$2|2346$19|2226$47|2229$66|2288$81|2308$64|2333$35|2528$35&FEBuildVersion=&CuCur=28; session_cache={"Cache":"HK3","Time":"636371029872660703","SessionID":"dq3qlxihubovnmnr1oxyyfpk","CheckID":"552ef656bcc67c47aa4825b8331d53c88c93d350","CType":"N"}'}

# %%
#res = requests.get(url, headers = headers, cookies = cookie, data = data)
res = requests.get(url)

# 不用放url以外的requests

# %%
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, 'lxml')

# %%
soup.select('script')[43]#.find(lambda x: x.get('data-selenium') == 'script-initparam')
#.find(lambda x: x.get('data-selenium') == 'script-initparam')
#[25]#.find(lambda x: x.get('data-selenium') == 'script-initparam')
#data-selenium="script-initparam"
# Out:
# <script data-selenium="script-initparam" type="text/javascript">
#         var initialResults = {"NumberOfRecommendedProperties":3,"IsDfError":false,"IsComplete":true,"IsLogin":false,"IsReady":true,"SearchId":"1b0c2538-e589-4ce8-abc1-2ba4fd0abf25","CurrencyCode":"TWD","TotalFilteredHotels":1289,"ResultList":[{"HotelID":870960,"EnglishHotelName":"Urban Hotel Kyoto-Nijo Premium","TranslatedHotelName":"京都二條高級城市飯店 (Urban Hotel Kyoto-Nijo Premium)","ImgPath":null,"UrgencyMessage":"<strong>11</strong>人考慮中","DisplayUrgencyMessage":true,"SearchType":1,"AreaName":"京都中心部","CityName":"京都","ObjectName":"京都","AreaId":26671,"CityId":1784,"CountryName":"日本","CountryId":3,"DmcId":0,"RoomDmcId":332,"AwardYear":2016,"GcaTooltipText":"2016年Agoda旅人鑑賞優勝。","StarRating":3.0,"StarRatingColor":"orange-yellow","StarRatingCss":"star-3","StarRatingTooltip":"所有星級的標示皆可作為您判斷舒適度、設施服務與備品完善度的參考指標，資料由住宿方提供。","ReviewScore":8.8,"ReviewScoreFormatted":"8.8","ReviewScoreASD":8,"NumberOfReview":414,"NumberOfReviewASD":null,"FreeWifi":true,"PeopleLooking":11,"IsASD":false,"UniqueHotelId":"870960","IsSoldOut":false,"IsThumbnail":true,"DisplayPrice":3603.55,"DisplayCurrency":"TWD","CrossOutPrice":13693.94,"HasCrossOutRate":true,"CORType":1,"FormattedDisplayPrice":"3,604","FormattedCrossedOutPrice":"13,694","Currency":"TWD","CurrencyCode":null,"OptionDisplay":"00100","IsCurrencyOnBackPosition":false,"IsBNPL":true,"IsBNPLDuringYourStay":true,"IsFreeCancellation":true,"IsBreakfastIncluded":true,"MainPhotoUrl":"//pix6.agoda.net/hotelImages/870/870960/870960_17062518580054063026.jpg?s=312x236&p=true","MainPhotoRetinaUrl":"//pix6.agoda.net/hotelImages/870/870960/870960_17062518580054063026.jpg?s=312x236&p=true","MainPhotoDesktopUrl":"//pix6.agoda.net/hotelImages/870/870960/870960_17062518580054063026.jpg?s=250x250&ar=1x1&p=true","MainPhotoDesktopRetinaUrl":"//pix6.agoda.net/hotelImages/870/870960/870960_17062518580054063026.jpg?s=500x500&ar=1x1&p=true","hotelIndex":0,"IsMobileDeal":false,"HotelRoomTypeId":4492510,"ReviewText":"很讚","IsInsiderDeals":false,"IsRemoveingInsiderDealExperiment":false,"IsReady":true,"PromotionText":null,"HotelUrl":"/zh-tw/urban-hotel-kyoto-nijo-premium/hotel/kyoto-jp.html?checkin=2017-08-25&los=2&adults=2&rooms=1&cid=-209&searchrequestid=b1330aa6-68a8-48a4-ad8c-d8e35dc91ffc","Distance":0.0,"MobileDistanceMessage":"","Latitude":35.015171,"Longitude":135.742234,"IsUnavailableHotel":false,"IsWysiwyp":false,"PriceDetail":{"PriceView":1,"DefaultPrice":3603.55,"TotalExclusive":7207.09,"TotalInclusivePerRoomPerNight":4281.02,"TotalInclusivePerBooking":8562.03,"TotalMandatoryExtraBed":0.0,"CrossOutRateExclusive":13693.94,"CrossOutRateInclusivePerRoomPerNight":13693.94,"OriginalAllInclusivePerRoomPerNight":4355.5,"ChargePriceSellExclusive":3603.55,"ChargePriceSellAllInclusive":4281.02},"ImageBadge":null,"IsMSE":false,"IsPPC":false,"IsRecommendedHotel":false,"IsHighlight":false,"IsPromotionEligible":false,"UnavailableDateText":null,"RemainingRooms":7,"RemainingRoomsUrgencyMessage":"","SaveUpTo":"最多可幫你省下TWD","PromotionTypes":[0,2,3,5],"PointsMaxPromoText":"訂房賺哩程點數","PointsMaxProgramName":null,"IsPointsMaxEligible":true,"IsPointsMaxProgram":true,"PromotionValue":74.0,"PromotionDiscount":"74","PricePromotionDiscount":"<b class=\"discount-txt\">減價</b><strong class=\"price-text\">74%</strong>","HasLocalTaxReceipt":false,"IsNoCreditCardRequired":false,"PriceSummary":{"SellInclusive":8562.0,"SellExclusive":7207.0,"NetInclusive":0.0,"Taxes":[],"RatePlanID":2,"PromotionValue":0.0,"CancellationCode":"1D20P_100P","LastRooms":7,"RoomTypeID":4492510,"IsBreakfastIncluded":true},"IsDisplayReviewScore":true,"AccommodationTypeID":0,"HasNHATag":false,"IsNHA":false,"ShouldShowPriceBreakDownPopUp":true,"ShouldShowCouponOrMoneyBackBadge":false,"Transportation":{"IsCloseToTransport":true,"CloseToTransportList":["距地下鐵 二條站約0.4公里"],"Header":"靠近大眾運輸","Description":"查看鄰近的大眾交通工具"},"Freebies":{"Hilighted":null,"All":null,"AllFreebies":null,"FreebiesItem":[{"Name":"WiFi","Icon":"ficon-wifi"},{"Name":"早餐","Icon":"ficon-breakfast"}],"HilightedFreebiesIndex ...
#         var params = {};
#         params.hotelListSearch = {};
#         params.ssr = {};
#         params.detection = {};
#         params.detection.platform = "desktop";
#
#         params.cms = {};
#         params.cms.alertMsgSearchBox = 52366;
#         params.cms.alertMsgSearchBoxDefault = '若為親子同行，一間客房最多可供大人加兒童共{1}位房客使用。';
#         params.cms.soldOut = 22326;
#         params.cms.soldOutDeafult = '售完';
#
#         params.cacheObj = {};
#
#         params.cacheObj.pageSize = initialResults.SearchCriteria.PageSize;
#         params.cacheObj.totalHotels = 1289;
#         params.cacheObj.hotelList = initialResults;
#         params.cacheObj.pageNumber = 1;
#
#
#         params.cacheObj.searchCriteria = initialResults.SearchCriteria;
#
#
#         params.searchObj = {};
#
#         params.searchObj.getURL = '/api/zh-tw/Main/GetSearchResultList';
#
#         params.searchObj.textSearchUrl = '/newsite/zh-tw/searchresult/Search';
#         params.searchObj.getSuggestionUrl = '/api/zh-tw/Main/GetSuggestionResult';
#         params.searchObj.getAlternativeHotelsUrl = '/api/zh-tw/Main/GetAlternativeHotels';
#         params.searchObj.getRecommendedCities = '/api/zh-tw/SearchPersonalization/GetRecommendedCities';
#
#         params.alternativeHotel = {};
#         params.alternativeHotel.isDateless = false;
#
#         params.searchCriteria = initialResults.SearchCriteria;
#
#         params.pagination = {};
#         params.pagination.data = initialResults;
#         params.pagination.pageNumberCMS = '第{1}頁/ 共{2}頁';
#         // TODO : After Integration (Fix hardcode CMS number)
#
#             params.preFilterParamList = ["hotelStarRating","hotelArea","hotelName","hotelAccom","hotelFacility","hotelReviewScore","hotelNHA","benefits","priceFrom","priceTo","priceCur"];
#
#         params.filters = {};
#         params.filters.initialResults = initialResults;
#         params.filters.allFilters = initialResults.FilterList;
#         params.filters.minReviewScore = 5;
#         params.filters.maxReviewScore = 9.5;
#         params.filters.activeText = '已選';
#         params.filters.clearText = '清除';
#         params.filters.priceSlider = initialResults.FilterList.PriceFilterRange;
#         params.filters.filterTag = {};
#         params.filters.filterTag.cms = {};
#         params.filters.filterTag.cms.star = {};
#         params.filters.filterTag.cms.star.cms1s = '1星級以上';
#         params.filters.filterTag.cms.star.cms2s = '2星級以上';
#         params.filters.filterTag.cms.star.cms3s = '3星級以上';
#         params.filters.filterTag.cms.star.cms4s = '4星級以上';
#         params.filters.filterTag.cms.star.cms5s = '5星級';
#         params.filters.filterTag.decimalSeparator = '.';
#         params.filters.newReviewScore = {};
#         params.filters.newReviewScore.allText = '全選';
#         params.filters.newReviewScore.andUp = '{0}分以上';
#         params.filters.newReviewScore.currentMinReviewScore = initialResults.SearchCriteria.Filters.ReviewScoreMin;
#         params.filters.newReviewScore.minReviewScore = 5;
#         params.filters.newReviewScore.maxReviewScore = 9.5;
#         params.filters.newReviewScore.decimalSeparator = '.';
#         params.filters.newReviewScore.reviewScoreName = '得分 ❤';
#         params.filters.isDateless = params.alternativeHotel.isDateless;
#
#         params.filters.starRating = {};
#             params.filters.starRating.current = null;
#         params.filters.starRating.ui = {};
#         params.filters.starRating.data = {};
#
#         params.filters.cms = {};
#         params.filters.cms.clear = '重新篩選';
#         params.filters.cms.more = '查看全部▼';
#         params.filters.cms.less = '收起清單▲';
#         params.filters.priceView = initialResults.FilterList.PriceView;
#
#         params.polling = {};
#         params.polling.getURL = params.searchObj.getURL;
#         params.polling.container = '#hotelListContainer';
#         params.polling.containerMap = '.map-sidebar-hotellist';
#         params.polling.containerMapPopup = '.map-hotelinfo-container';
#         params.polling.template = '#searchresult_item';
#         params.polling.templateMap = '#ssr-map-sidebar-hotelitem';
#         params.polling.hotelPopupTemplate = '#ssr-map-popup-info';
#         params.polling.itemSelector = 'li[data-isready="false"]';
#         params.polling.itemSelectorMap = 'div[data-isready="false"]';
#         params.polling.soldoutTemplate = '<span class="soldout-text" data-selenium="soldout-text">{0}</span>';
#         params.polling.soldoutCmsID = '22326';
#         params.polling.initialResults = initialResults;
#         params.polling.seeOffersCms = "查看優惠專案";
#
#         params.experiment = {};
#         params.experiment.experimentList = null;
#
#         params.message = {};
#         params.message.sentRankingUrl = '/api/zh-tw/Main/SendSearchMessage';
#
#         params.reviewPopup = {};
#         params.reviewPopup.url = '/NewSite/zh-tw/Review/FetchPopupReviews';
#
#         params.imageSlideshow = {};
#         params.imageSlideshow.url = '/api/zh-tw/SearchPersonalization/GetPropertiesInfo';
#
#         params.maps = {};
#         params.maps.MapSettings = {};
#
#         params.maps.MapSettings.mapProviderName = 'GoogleMaps';
#         params.maps.MapSettings.url = '//maps.googleapis.com/maps/api/js?client=gme-booking&channel=agoda&v=3&sensor=false&language=zh&async=2&callback=agoda.maps.provider.GoogleMaps.APILoaded';
#         params.maps.MapSettings.url_tiles = '';
#         params.maps.MapSettings.key = '';
#         params.maps.MapSettings.loadingMessage = 'Ladevorgang...';
#         params.maps.MapSettings.mapType = {};
#         params.maps.MapSettings.mapType.HYBRID = 'HYBRID';
#         params.maps.MapSettings.mapType.ROAD = 'ROAD';
#         params.maps.MapSettings.mapType.SATELLITE = 'SATELLITE';
#         params.maps.MapSettings.mapType.TERRAIN = 'TERRAIN';
#         params.maps.MapSettings.defaultMapType = 'ROAD';
#
#         params.maps.MapSettings.language = 'en';
#         params.maps.MapSettings.origin = 'TW';
#         params.maps.MapSettings.containerID = 'mapBodyContainer';
#         params.maps.MapSettings.zoom = 14;
#         params.maps.MapSettings.latlng = [35.016667,135.766667]; // Center of map based on center lat and lng
#         params.maps.MapSettings.isSync = false;
#         params.maps.MapSettings.isSave = false;
#
#         //params.maps.MapSettings.latlng = [13.752210, 100.491799]; //Bangkok
#         //params.maps.MapSettings.latlng = [39.915, 116.404]; //Chinaz
#         params.maps.WidgetSettings = {};
#         params.maps.WidgetSettings.initialResults = initialResults;
#         params.maps.WidgetSettings.availablePinTemplate = '#ssr-map-pin-price';
#         params.maps.WidgetSettings.hotelPopupTemplate = '#ssr-map-popup-info';
#         params.maps.WidgetSettings.loadingCms = '讀取中...';
#         params.maps.WidgetSettings.SoldOutCms = '售完';
#
#         params.maps.view = {};
#         params.maps.view.hotelItemTemplate = '#ssr-map-sidebar-hotelitem';
#         params.maps.view.headerTemplate = '#ssr-map-sidebar-header';
#         params.maps.view.zeroResultTemplate = '#ssr-map-zero-result-page';
#         params.maps.view.detection = params.detection;
#
#         params.maps.main = {};
#         params.maps.main.selectedHotel = initialResults.SelectedHotel;
#         params.maps.main.initialResults = initialResults;
#         params.maps.main.defaultCityLocation = {};
#         params.maps.main.defaultCityLocation.lat = 35.016667;
#         params.maps.main.defaultCityLocation.lng = 135.766667;
#
#         params.maps.calendar = {};
#         params.maps.calendar.SearchCriteria = initialResults.SearchCriteria;
#         params.maps.calendar.searchboxTemplate = '#ssr-map-sidebar-searchbox';
#
#         var monthList = [];
#
#             monthList[0] = '一月';
#             monthList[1] = '二月';
#             monthList[2] = '三月';
#             monthList[3] = '四月';
#             monthList[4] = '五月';
#             monthList[5] = '六月';
#             monthList[6] = '七月';
#             monthList[7] = '八月';
#             monthList[8] = '九月';
#             monthList[9] = '十月';
#             monthList[10] = '十一月';
#             monthList[11] = '十二月';
#
#         params.maps.calendar.monthList = monthList;
#
#         params.maps.calendar.alertMessage = '單次預訂最多可預約30天。當然，我們歡迎您預約更多日子，您只需再作預訂就行。我們祝您旅途愉快！';
#
#         params.maps.paging = {};
#         params.maps.paging.pagingCMS = '第{0} - {1}間';
#
#         params.maps.loading = {};
#         params.maps.loading.loadingCMS = '為您更新價格中，請稍候！';
#
#         params.loading = {};
#         params.loading.numberOfLoading = initialResults.SearchCriteria.PageSize;
#         params.loading.loadingTemplate = "#loading-indicator";
#         params.loading.loadingDomTarget = '#hotelListContainer';
#
#         params.sorting = {};
#         params.sorting.SortType = initialResults.SearchCriteria.SortType;
#         params.sorting.ReviewTravelerType = initialResults.SearchCriteria.ReviewTravelerType;
#         params.sorting.HasInsiderDeal = initialResults.HasInsiderDeal;
#         params.sorting.SearchType = initialResults.SearchCriteria.SearchType;
#         params.sorting.HasDeals = initialResults.HasDeals;
#         params.sorting.HasSecretDeal = initialResults.HasSecretDeal;
#         params.sorting.isDateless = params.alternativeHotel.isDateless;
#
#         var wysiwyp = {};
#         wysiwyp.page = 'ssr-desktop';
#         wysiwyp.currentPriceView = 1;
#         wysiwyp.priceViewEnums = {};
#         wysiwyp.priceViewEnums.exclusive = 1;
#         wysiwyp.priceViewEnums.inclusiveWithSurchargePerRoomPerNight = 2;
#         wysiwyp.priceViewEnums.inclusiveWithSurchargePerBooking = 3;
#         params.wysiwyp = wysiwyp;
#
#         params.common = {};
#         params.common.CityId = initialResults.SearchCriteria.CityId;
#         params.common.CityName = initialResults.SearchCriteria.CityName;
#
#         params.recentlyBooked = {};
#         params.recentlyBooked.HeaderTextCMS = '{1}熱賣中！';
#
#         params.landing = {};
#         params.landing.title = initialResults.TitleBar;
#
#         params.view = {};
#         params.view.HotelSize = initialResults.ResultList.length;
#         params.view.IsComplete = initialResults.IsComplete;
#         params.view.IsDateless = initialResults.SearchCriteria.IsDateless;
#         params.view.detection = params.detection;
#         params.view.cms = {};
#         params.view.cms.PercentageBooked = '<span class="book-percent"><span class="book-percent-number">{1}%</span><span class="book-percent-text">已被訂走</span></span>';
#         params.view.cms.PercentageBookedAlready = '超過{1}%的住宿已被其他旅人訂走！';
#             params.view.HasApartmentLink = false;
#
#         params.dym = {};
#         params.dym.DymSelector = "#searchresult-headercontainer a.dymlink";
#         params.dym.DymActionMessageUrl = '/api/zh-tw/Main/SendDymActionMessage';
#
#         params.error = {};
#         params.error.TechnicalDifficultiesCMS = '抱歉，目前發生技術性問題。';
#
#         params.couponAndMoneyBack = {};
#         params.couponAndMoneyBack.IsMoneyBack = false;
#         params.couponAndMoneyBack.ShouldShowTorchPanel = false;
#         params.couponAndMoneyBack.IsCouponSliderDisplayed = false;
#             params.couponAndMoneyBack.ShouldShowSlider = true;
#
#         params.modal = {};
#         params.modal.dateChangedFlag = initialResults.AreDatesChanged;
#         params.modal.dateChangedModal = "#datechanged-modal";
#         params.modal.dateChangedMsg = '你的入住日期已經是過去式...所以我們幫你更新了入住日期，你也可以重新選擇其他日期。';
#
#         //Same day no CC
#         params.samedaybooking = {};
#         params.samedaybooking.hotelCheckInLocalDate = "2017-08-25";
#         params.samedaybooking.noCreditCardSelector = ".no-credit-card-required";
#         params.samedaybooking.noCreditCardSamedaySelector = ".booking-same-day";
#         params.samedaybooking.source = "ssr-desktop";
#
#         suggestionBoxConfig = {
#             defaultText: "default text",
#             languageId: 20,
#             autocompleteUrl: '/Search/Search/GetFilterResult/3/20/20/0/zh-tw',
#             sendMessageUrl: '/api/zh-tw/Main/SendHotelSearchSuggestionMessage',
#             objectId: initialResults.SearchCriteria.SearchType == 1 ? initialResults.SearchCriteria.CityId : initialResults.SearchCriteria.ObjectID,
#             objectTypeId: initialResults.SearchCriteria.SearchType
#         };
#
#         window.countryId = 3;
#         window.isTablet = false;
#
#         params.templates = {};
#         params.templates.additionalParams = {};
#         params.templates.additionalParams.IsTablet = false;
#         params.templates.additionalParams.IsOnMap = false;
#         params.templates.additionalParams.SecretDealLogo = 'https://cdn10.agoda.net/images/abtest/ABTest4493/agoda-secret-deal-logo.png';
#         params.templates.additionalParams.isDateless = params.alternativeHotel.isDateless;
#
# params.templates.cms = {};
#
# params.templates.cms.Welcome = '歡迎訂房！請在搜尋欄位中';
# params.templates.cms.ChangeTravelDate = '輸入日期';
# params.templates.cms.SearchboxDate = '即可開始預訂{1}。';
# params.templates.cms.FavoriteTooltipHeart = '儲存這間住宿到「口袋清單」，下次找房更方便！';
# params.templates.cms.AgodaSecretDealHotelName = '{2}地區的{1}星級住宿';
# params.templates.cms.AgodaSecretDeal = '<h3>A級<span class="green">機密價</span></h3>';
# params.templates.cms.SaveUpTo = '最多可幫你省下{1}{2}';
# params.templates.cms.HotelNameReveal = '住宿名稱將會於訂房後揭曉';
# params.templates.cms.FreebiesTooltipDescription = '提供以下訂房優惠選項：';
# params.templates.cms.FreebiesFree = '優惠選項';
# params.templates.cms.Coupon = '折扣碼減價';
# params.templates.cms.CouponHoverInfo = '剛到手的額外折扣已經開始幫你省錢囉！詳細折扣金額可於價格明細中查看，各間住宿可獲得的折扣金額不同。';
# params.templates.cms.CouponApplied = '折扣碼減價';
# params.templates.cms.FreebiesBreakfast = '可供早餐';
# params.templates.cms.EarnBadge = '哩程躺著賺';
# params.templates.cms.GiftCard = 'A金卡';
# params.templates.cms.HoverTextForPointsmaxOnSSR = '在頁面頂端點選「PointsMAX」，選擇心儀的航空公司哩程回饋專案，然後就可以開始訂房賺哩程或點數囉！';
# params.templates.cms.BestAgodaDiscount = 'Agoda超低特惠';
# params.templates.cms.InsiderDealsDesktopTag = '隱藏版特惠';
# params.templates.cms.PartnerPromoEligible = '適用額外優惠';
# params.templates.cms.NewMSEText = '還有空房，但世事難料...<strong>即早預訂吧！</strong>';
# params.templates.cms.CORNonRackRateToolTipText = '不確定有沒有撿到便宜？比較一下被劃掉的價格見分曉！把最新特惠和這間房在你入住日期附近30天最高的價格相比，一目了然！';
# params.templates.cms.CORToolTipText = '這是住宿的標準價格';
# params.templates.cms.PerNightBeginsWith = '每晚低至';
# params.templates.cms.DesktopTotalPricePerNight = '【含稅價】無隱藏費用';
# params.templates.cms.TotalPricePerNight = '每晚含稅價';
# params.templates.cms.SoldOut = '售完';
# params.templates.cms.HotelNotAvailableForCustomerDate = '抱歉，你想入住的期間Agoda暫無空房。';
# params.templates.cms.AvailableDateOfUnavailable = '下列住宿於<strong class="blue">{1}</strong>間<span class="blue">尚有空房</span>可供預訂。';
# params.templates.cms.RecommendCitiesSeeAllProperties = '查看當地住宿';
# params.templates.cms.RecommendCitiesAboutCity = '關於{1}';
#
# params.templates.cms.DemographicsLoading = '讀取中...';
# params.templates.cms.ReviewPropertyCard = '份評鑑';
# params.templates.cms.ReviewsPropertyCard = '份評鑑';
# params.templates.cms.PercentDiscountWithHTML = '<b class="discount-txt">減價</b><strong class="price-text">{0}%</strong>';
# params.templates.cms.OurNRoom = '本站剩{1}間';
# params.templates.cms.OurLastRoom = '本站最後1間';
# params.templates.cms.ChangeDate = '修改日期';
# params.templates.cms.GreenThumbTooltips = 'Agoda推薦住宿帶有此圖示的住宿表示該飯店盡可能地向顧客提供最低價優惠，且保持一貫的高品質服務並獲得Agoda顧客入住後滿意的住宿評鑑。';
# params.templates.cms.DistanceFrom = '住宿距離…';
# params.templates.cms.DistanceIsCal = '此距離為衛星測試距離，與實際路面距離可能有出入，詳情請查看飯店頁面內的詳細介紹及地圖。';
# params.templates.cms.DistanceWithBracket = '(距離{2}{1}公里)';
# params.templates.cms.PeopleLooking = '<strong>{1}</strong>人考慮中';
# params.templates.cms.OnePeopleLooking = '<strong>1</strong>人考慮中';
# params.templates.cms.BookingForTonight = '預訂今晚住宿？';
# params.templates.cms.NoCreditCardNeeded = '部分房型現在免卡也能訂！';
# params.templates.cms.FreeCancellation = '免費取消';
# params.templates.cms.PromoLinePayLater = '延後扣款';
# params.templates.cms.PayAtHotel = '到店付款';
# params.templates.cms.TaxReceiptAvailable = '可開發票';
# params.templates.cms.NoCreditCardRequired = '免卡訂房';
# params.templates.cms.TitleAgodaBestPick = '精選{0}間好宿：';
# params.templates.cms.CompareDetails = '比較住宿優惠';
# params.templates.cms.HideDetails = '隱藏內容';
# params.templates.cms.TitleOtherRecommendedHotel = '這些{0}住宿也很優：';
# params.templates.cms.ReviewPropertyCardAwaiting = '等待評鑑中';
# params.templates.cms.ReviewPropertyCardAwaitingInfo = '這間住宿還再等待旅人評分中...想要搶頭香嗎？訂房並完成住宿即可分享你的體驗，幫更多旅人找好房。';
# params.templates.cms.AgodaSecretDealTooltip = '<div class=&#39;tooltips-text&#39;><strong>「A級機密價」是什麼呢？</strong><br />許多高級住宿合作夥伴願意提供性價比極高的訂房優惠。由於優惠價格低於市價等各種相關因素，因此客房銷售期間必須保持匿名。<br/><br/><strong>要怎麼訂呢？</strong><br />選擇任何「A級機密價」即可查看該住宿座落區域、設施與評分等資訊。訂房完成後，即會為你揭曉下榻住宿的神秘面紗。</div>';
# params.templates.cms.InsiderDealToolTip = '會員專屬的隱藏版特惠！';
#
# params.templates.cms.SelectTravelDate = '請選擇旅行日期查看特惠與空房';
# params.templates.cms.SelectTravelDateShort = '請選擇旅行日期';
# params.templates.experiments = {};
# params.templates.experiments.PFE_GIFTCARD = 'Z' === 'B';
# params.templates.experiments.APS_PEEK_ON_SEARCH_SWITCH = 'Z' === 'B';
# params.templates.experiments.DISCOUNT_RIBBON_URGENCY_MESSAGING = 'B' === 'B';
# params.templates.experiments.OPTIONS_PILL_ON_PROPERTYCARD = 'B' === 'B';
# params.templates.experiments.COUPON_COR_PROMOTION = 'Z' === 'B';
# params.templates.experiments.PLUS_MANY_MORE_FREEBIES = 'B' === 'B';
#
#
#
#         params.favoriteReminder = {};
#         params.favoriteReminder.endpoint = '/api/zh-tw/SearchPersonalization/GetFavoriteReminder';
#
#         var redirect = {};
#         redirect.hotelids = [870960,1618367,267171,42505,100169,99063,4992,1618153,1161592,240282,240288,336533,3545,59173,1194076,178167,263680,527751,567214,68316,1974835,42491,81775,867655,1120585,813326,186959,1249202,2388,1621582,109849,699386,4315,51414,1618890,400294,169003,69275,51412,1618496,1078120,178223,1974836,542510,200531];
#         redirect.cityid = initialResults.SearchCriteria.CityId;
#         redirect.searchcriteria = initialResults.SearchCriteria;
#         redirect.pagetypeid = 103;
#         redirect.promotion = {};
#         redirect.promotion.endpoint = '/api/zh-tw/RedirectApi/GetPromoEligibleDisplayForPromoinboxCampaign';
#         redirect.promotion.message = '適用額外優惠';
#         redirect.promotion.isMobile = 'False';
#         params.redirect = redirect;
#         params.retailPeek = {};
#         params.retailPeek.url = '/api/zh-tw/Main/RetailPeek';
#
#
#
#         params.experiment = {};
#         params.experiment.shouldRenderPropertyList = true;
#         params.experiment.shouldUseStatelessFreebiesList = true;
#         params.experiment.isHoverOnTransportationBadge = false;
#         params.experiment.isCombinedList = true;
#         params.experiment.isLazyLoadPropertyCards = true;
#         params.experiment.shouldAppliedApsPeek = false;
#         params.experiment.isDiscountRibbonUrgencyMessage = true;
#         params.experiment.paymentOptionsRefactor = true;
#         params.userData = {};
#         params.userData.isDesktop = true;
#         params.userData.isTablet = false;
#         params.functions = {}
#         params.functions.alternativePropertiesFunction = {};
#         params.functions.alternativePropertiesFunction.init = function(){ agoda.ssr.alternativeHotel.init(params.alternativeHotel); }
#         params.functions.onAreaClickedShowMap = function (id) { agoda.ssr.map.main.onShowMapAreaClicked(id); }
#         params.functions.propertyCardFunctions = {};
#         params.functions.propertyCardFunctions.onDatelessCalloutClicked = function(e){ if(agoda.ssr.view.handleDatelessCalloutClicked){agoda.ssr.view.handleDatelessCalloutClicked(e);}};
#         params.functions.triggerCheckInCalendar = function () {
#             $('.checkin-input').trigger('focus');
#             $('.checkin-input').trigger('click');
#         }
#         params.loginBanner = {};
#         params.loginBanner.oneClick = false;
#         params.loginBanner.oneClickCongrats = false;
#         params.loginBanner.discountUptoText = "別讓\u003cspan\u003e低至７折\u003c/span\u003e的會員價成了這世上最遙遠的距離";
#         params.loginBanner.signInNowText = "登入｜免費入會";
#         params.loginBanner.signInToUnlockText = "思念總在分手後，特價給在【登入後】";
#         params.loginBanner.showSignInPopup = function() {if (!agoda.RewardsMember.IsLogin) {agoda.login.NewSignInPopup.show('signin');return;}}
#         params.loginBanner.isUserLoggedIn = function () { return agoda.RewardsMember.IsLogin; };
#         params.cmsValues = {"Welcome":"歡迎訂房！請在搜尋欄位中","ChangeTravelDate":"輸入日期","NewMSEText":"還有空房，但世事難料...\u003cstrong\u003e即早預訂吧！\u003c/strong\u003e","ChangeDate":"修改日期","FreebiesFree":"優惠選項","FreebiesTooltipDescription":"提供以下訂房優惠選項：","HotelNotAvailableForCustomerDate":"抱歉，你想入住的期間Agoda暫無空房。","BestAgodaDiscount":"Agoda超低特惠","Coupon":"折扣碼減價","CouponHoverInfo":"剛到手的額外折扣已經開始幫你省錢囉！詳細折扣金額可於價格明細中查看，各間住宿可獲得的折扣金額不同。","CouponAppliedText":"折扣碼減價","PromoEligible":"適用額外優惠","HoverTextForPointsmaxOnSSR":"在頁面頂端點選「PointsMAX」，選擇心儀的航空公司哩程回饋專案，然後就可以開始訂房賺哩程或點數囉！","InsiderDealsDesktopTag":"隱藏版特惠","InsiderDealToolTip":"會員專屬的隱藏版特惠！","GreenThumbTooltips":"Agoda推薦住宿\n\r\n帶有此圖示的住宿表示該飯店盡可能地向顧客提供最低價優惠，且保持一貫的高品質服務並獲得Agoda顧客入住後滿意的住宿評鑑。","FreeCancellation":"免費取消","PromoLinePayLater":"延後扣款","PayAtHotel":"到店付款","TaxReceiptAvailable":"可開發票","NoCreditCardRequired":"免卡訂房","DistanceFrom":"住宿距離…","DistanceIsCal":"此距離為衛星測試距離，與實際路面距離可能有出入，詳情請查看飯店頁面內的詳細介紹及地圖。","AgodaSecretDeal":"\u003ch3\u003eA級\u003cspan class=\"green\"\u003e機密價\u003c/span\u003e\u003c/h3\u003e","AgodaSecretDealTooltip":"\u003cdiv class=\u0027tooltips-text\u0027\u003e\u003cstrong\u003e「A級機密價」是什麼呢？\u003c/strong\u003e\u003cbr /\u003e許多高級住宿合作夥伴願意提供性價比極高的訂房優惠。由於優惠價格低於市價等各種相關因素，因此客房銷售期間必須保持匿名。\u003cbr/\u003e\u003cbr/\u003e\u003cstrong\u003e要怎麼訂呢？\u003c/strong\u003e\u003cbr /\u003e選擇任何「A級機密價」即可查看該住宿座落區域、設施與評分等資訊。訂房完成後，即會為你揭曉下榻住宿的神秘面紗。\u003c/div\u003e","DemographicsLoading":"讀取中...","DemographicsNoContent":"抱歉，目前還沒有相關資料","HotelNameReveal":"住宿名稱將會於訂房後揭曉","ReviewPropertyCard":"份評鑑","ReviewsPropertyCard":"份評鑑","ReviewPropertyCardAwaiting":"等待評鑑中","ReviewPropertyCardAwaitingInfo":"這間住宿還再等待旅人評分中...想要搶頭香嗎？訂房並完成住宿即可分享你的體驗，幫更多旅人找好房。","YouCanSeeMore":"您可以透過新增篩選項目查看更多飯店：","ClearFilterAll":"清空所有篩選項返回到原始搜索結果列表。","ZeroPageMobile":"抱歉，沒有符合您搜尋條件的訂房選項。建議可以修改搜尋條件後再次嘗試喔！","SelectTravelDate":"請選擇旅行日期查看特惠與空房","BookingForTonight":"預訂今晚住宿？","NoCreditCardNeeded":"部分房型現在免卡也能訂！","PerNightBeginsWith":"每晚低至","CORNonRackRateToolTipText":"不確定有沒有撿到便宜？比較一下被劃掉的價格見分曉！把最新特惠和這間房在你入住日期附近30天最高的價格相比，一目了然！","CORToolTipText":"這是住宿的標準價格","SoldOut":"售完","DesktopTotalPricePerNight":"【含稅價】無隱藏費用","TotalPricePerNight":"每晚含稅價","AlternativeHotelHeader":"查看過{1}的客人，也看了這些住宿選項...","MSEFrom":"每晚最低價","PriceBeforeCouponApplied":"這是還未套用折扣碼的價格","ApsPeekPanelText":"登入再省 {0}","SeeOffers":"查看優惠專案"};
#         params.destinationInfo = {};
#         params.destinationInfo.hotelCheckInLocalDate = '2017-08-25';
#
#         params.staticMap = {};
#
#         params.staticMap.DefaultUrl = "//maps.googleapis.com/maps/api/staticmap?client=gme-booking&channel=agoda&zoom=9&size=252x119&language=zh&center=35.016667%2c135.766667&signature=ZUXdwTQIFudhzl17sgQ8qdK4q1o=";
#         params.staticMap.RetinaUrl = "//maps.googleapis.com/maps/api/staticmap?client=gme-booking&channel=agoda&zoom=9&size=252x119&language=zh&center=35.016667%2c135.766667&scale=2&signature=_PFGeCq1VUKqWKM8BnLfyZPLxz4=";
#
#
#         params.staticMap.ShowStaticMap = true;
#         params.staticMap.ShouldShowMapBtn = true;
#         params.staticMap.Label = "地圖找房";
#         params.staticMap.ShowOverlay = false;
#         params.staticMap.MapHoverText = "在地圖上比較各住宿地點";
#         params.staticMap.OnMapClick = function() { agoda.ssr.map.main.onShowMapButtonClicked(); }
#
#
#     </script>

# %%
## "EnglishHotelName":"Urban Hotel Kyoto-Nijo Premium","TranslatedHotelName":"京都二條高級城市飯店 (Urban Hotel Kyoto-Nijo Premium)"
## "FormattedDisplayPrice":"3,594"
#            "TranslatedHotelName":".+\(.+\)"
target = re.findall('\"TranslatedHotelName\":\"(.*?\))\".*?\"FormattedDisplayPrice\":\"(.*?)\"', soup.text)
target
# Out:
# [('京都二條高級城市飯店 (Urban Hotel Kyoto-Nijo Premium)', '3,405'),
#  ('相鐵FRESA INN - 京都四條烏丸 (Sotetsu Fresa Inn Kyoto-Shijokarasuma)', '2,702'),
#  ('京都世紀旅館 (Kyoto Century Hotel)', '5,302'),
#  ('京都ARK飯店 (Ark Hotel Kyoto)', '2,072'),
#  ('京都皇家Spa飯店 (Kyoto Royal Hotel & Spa)', '3,016'),
#  ('MYSTAYS飯店 - 京都四條 (HOTEL MYSTAYS Kyoto-Shijo)', '2,915'),
#  ('京都新阪急飯店 (Hotel New Hankyu Kyoto)', '3,174'),
#  ("M's Plus飯店 - 四條大宮 (Hotel M's Plus Shijo Omiya)", '2,712'),
#  ('Gracery飯店 - 京都三條 (Hotel Gracery Kyoto Sanjo)', '3,193'),
#  ('APA飯店 - 京都站堀川通 (APA Hotel Kyoto-Eki-Horikawadori)', '2,766'),
#  ('APA VILLA飯店 - 京都站前 (APA Villa Hotel Kyoto-Ekimae)', '2,861'),
#  ('京都阿爾蒙特旅館 (Almont Hotel Kyoto)', '3,166'),
#  ('京都布萊頓飯店 (Kyoto Brighton Hotel)', '5,441'),
#  ('APA飯店 - 京都祇園EXCELLENT (APA Hotel Kyoto-Gion Excellent)', '3,193'),
#  ('京都站前大和ROYNET飯店 (Daiwa Roynet Hotel Kyoto-ekimae)', '5,668'),
#  ('Dormy Inn飯店 - 京都站前高階天然溫泉 (Natural Hot Spring Dormy Inn Premium Kyoto Ekimae)',
#   '4,254'),
#  ('京都新都飯店 (New Miyako Hotel Kyoto)', '4,009'),
#  ('櫻花露台飯店 (Sakura Terrace)', '3,341'),
#  ('京都四條烏丸大和ROYNET飯店 (Daiwa Roynet Hotel Kyoto-Shijokarasuma)', '4,666'),
#  ('京都精選巴哈大飯店 (Hotel Grand Bach Kyoto Select)', '5,356'),
#  ('京都塔飯店分館 (Kyoto Tower Hotel Annex)', '3,121'),
#  ("四條烏丸M's Est飯店 (Hotel M's Est Shijo Karasuma)", '2,712'),
#  ('APA飯店 - 京都站前 (APA Hotel Kyoto-Ekimae)', '3,205'),
#  ('京都格蘭比亞大酒店 (Hotel Granvia Kyoto)', '6,340'),
#  ('櫻花露台畫廊旅館 (Sakura Terrace The Gallery)', '4,289'),
#  ('京都世紀膠囊Spa飯店 - 人工溫泉 (Centurion Cabin & Spa Kyoto - Artificial Hot Spring)',
#   '1,486'),
#  ('UNIZO飯店 - 京都四條烏丸 (HOTEL UNIZO Kyoto Shijo Karasuma)', '2,590'),
#  ('京都法華俱樂部飯店 (Hotel Hokke Club Kyoto)', '3,135'),
#  ('京都庵民宿 (Guest Apartment Kyoto Ann)', '3,048'),
#  ('三井花園飯店京都三條 (Mitsui Garden Hotel Kyoto Sanjo)', '3,997'),
#  ('索拉利亞西鐵飯店 - 京都Premier (Solaria Nishitetsu Hotel Kyoto Premier)', '4,841'),
#  ('Village京都飯店 (Hotel Village Kyoto)', '3,410'),
#  ('京都格蘭小姐飯店 (Hotel Gran Ms Kyoto)', '2,743'),
#  ('京都麗嘉皇家酒店 (RIHGA Royal Hotel Kyoto)', '5,556'),
#  ('三井花園飯店京都四條 (Mitsui Garden Hotel Kyoto Shijo)', '3,603'),
#  ('枸橘七條間之町京都民宿 (Karatachi Nanajo Ainomachi - Guesthouse in Kyoto)', '2,175'),
#  ('京都八條口大和ROYNET飯店 (Daiwa Roynet Hotel Kyoto-Hachijoguchi)', '3,423'),
#  ('京都京阪GRANDE飯店 (Hotel Keihan Kyoto GRANDE)', '3,504'),
#  ('阿蘭維特飯店 (Aranvert Hotel)', '3,424'),
#  ('京都塔飯店 (Kyoto Tower Hotel)', '4,169'),
#  ('相鐵FRESA INN - 京都站八條口 (Sotetsu Fresa Inn Kyoto-Hachijoguchi)', '3,544'),
#  ('Bochibochi烏丸京都民宿 (Bochibochi Karasuma - Guesthouse in Kyoto)', '2,232'),
#  ('京都烏丸五條馨樂庭服務公寓 (Citadines Karasuma-Gojo Kyoto)', '3,263'),
#  ('三井花園飯店京都新町別邸 (Mitsui Garden Hotel Kyoto Shinmachi Bettei)', '5,224'),
#  ('京都感洛飯店 (Hotel Kanra Kyoto)', '8,786')]

# %%
soup.select('#hotelListContainerReact')#[0]#.find(lambda x: x.get('data-et-view') == 'TULQWNVLBLWIJDAOfUYdXaO:1')

# %%
type(target)
# Out:
# list

# %%
with open('AgodaList.txt', 'w', encoding = 'UTF-8') as f:
        f.write(str(target))
