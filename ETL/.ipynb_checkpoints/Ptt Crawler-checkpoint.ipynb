# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests

url = 'https://www.ptt.cc/bbs/Japan_Travel/index.html'
response = requests.get(url)

print(response.text)  # result of setp-1
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Japan_Travel 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Japan_Travel/index.html"><span class="board-label">看板 </span>Japan_Travel</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Japan_Travel/index.html">看板</a>
# 				<a class="btn" href="/man/Japan_Travel/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Japan_Travel/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Japan_Travel/index5177.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Japan_Travel/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502469946.A.7BE.html">[遊記] 日本中部自助．漫步世界文化遺產合掌村</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/12</div>
# 				<div class="author">sailler</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502470124.A.FBE.html">[遊記] Day1吾妻橋/隅田川河岸步道。東京晴空塔</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/12</div>
# 				<div class="author">bluezting</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502471163.A.C44.html">[問題] 請問東北的山寺大概要抓多少時間? </a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/12</div>
# 				<div class="author">leonli</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				(本文已被刪除) [ikeru]
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/12</div>
# 				<div class="author">-</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502473188.A.962.html">[公告] lullabydance版友讓售機票 禁言一周</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/12</div>
# 				<div class="author">sinohara</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502473393.A.880.html">[公告] c0010iacuk0i版友轉貼新聞未達門檻禁言一周</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/12</div>
# 				<div class="author">sinohara</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502473713.A.402.html">[問題]  9/1 - 9/7 東京自助行請益</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/12</div>
# 				<div class="author">tnfsp</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502474232.A.3F2.html">[遊記] 箱根大涌谷交通》箱根登山纜車/電車</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/12</div>
# 				<div class="author">candice0830</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502474418.A.C85.html">[住宿] 河口湖住宿推薦》Mystays飯店富士</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/12</div>
# 				<div class="author">candice0830</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">5</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502479604.A.0C3.html">[問題] ORIX租車corolla fielder或Fit Hybrid</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/12</div>
# 				<div class="author">sodesou</div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark">!</div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1490978492.A.78E.html">[公告] 日本旅遊板板規 106.04</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 4/01</div>
# 				<div class="author">airpretty</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1501735229.A.64A.html">[公告] 106.08實況回報 (含天氣/物候/穿著詢問)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/03</div>
# 				<div class="author">sinohara</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">10</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502254250.A.443.html">[資訊] 酷航台灣發 &amp; 本月日本發促銷</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/09</div>
# 				<div class="author">yhls</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">67</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502269813.A.420.html">[資訊] 樂桃航空仲夏樂促銷 8/10 00:00開始</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/09</div>
# 				<div class="author">weigh2634</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">48</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Japan_Travel/M.1502428288.A.AB9.html">[資訊] 虎航冬季開賣(17 HKD/SDJ 21 NRT/HND/NGO)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 8/11</div>
# 				<div class="author">magicgreet</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.22/bbs.js"></script>
#
#     </body>
# </html>

# %%
soup = BeautifulSoup(response.text, 'lxml')
articles = soup.find_all('div', 'r-ent')

# %%
articles
# Out:
# [<div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501677172.A.C9A.html">[食記] 日本 大阪 梨花食堂 天滿本店 好吃咖哩飯</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">oldfather</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501677950.A.D31.html">[食記] 新竹 語菓 有味道的文青飲料店</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">wei9654</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501678429.A.B1D.html">[食記] 台北天母 on the road義式冰淇淋</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">kurosaki1986</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501678535.A.B2C.html">[食記] 新北永和-自由溫室-超好拍乾燥花餐廳</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">redleeve</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501678799.A.710.html">[廣宣] 台北【Thai cook泰酷泰國料理】宵夜開賣</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">chenmaggie</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501679057.A.93E.html">[食記] 台北 Hooked To Go著迷咖啡 x TAMED FOX </a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">yucon</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501679885.A.556.html">[食記] 台北市文山區歷史悠久的餐廳-聚酩豐</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">fatlee</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"><span class="hl f2">1</span></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501680184.A.4D5.html">[食記] 九州熊本 炸豬排名店勝烈亭-南熊本店</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">rueoque</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501680531.A.F0E.html">[食記] 澳洲墨爾本Rustica Canteen早午餐咖啡</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">evisweet</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501683312.A.FE3.html">[食記] [台中]嘉義阡涼麵：評價很好但嘉義味呢?</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">maggie024</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501683355.A.8F9.html">[食記] 花蓮市區—浪花丸｜沁涼消暑的純正日本冰品</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">shinyban</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501684107.A.6DB.html">[食記] 台中 魚你同在雞蛋糕--創意脆皮雞蛋糕</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">nawg</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501684548.A.995.html">[食記] 豐原 格外幸福法式甜點 水果千層蛋糕</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">paulyear</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501684662.A.672.html">[食記] 台北信義區 魷魚大叔 起司火焰辣炒年糕</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">Farrahliu</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"><span class="hl f2">6</span></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501684665.A.5C1.html">[請益] 尋找北市鯛魚燒(軟厚皮+奶油/紅豆</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">tzumio</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501685233.A.D2C.html">[食記] 台北 剛好的周末來dreamer 38運動酒吧</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">takubin</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501685488.A.5DE.html">[食記] 基隆「豬腳林」原汁口味</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/02</div>
#  <div class="author">ochiochi777</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark"></div>
#  <div class="title">
#  <a href="/bbs/Food/M.1501690074.A.AF4.html">[食記] 北海道 札幌 宵夜聖代懶人包</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 8/03</div>
#  <div class="author">smallta</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark">!</div>
#  <div class="title">
#  <a href="/bbs/Food/M.1355673582.A.5F7.html">[公告] Food板 板規 V3.91</a>
#  </div>
#  <div class="meta">
#  <div class="date">12/16</div>
#  <div class="author">Dilbert</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark">!</div>
#  <div class="title">
#  <a href="/bbs/Food/M.1494321933.A.4B7.html">[公告] 板規第3條 增補詳細說明</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 5/09</div>
#  <div class="author">Dilbert</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"><span class="hl f3">18</span></div>
#  <div class="mark">!</div>
#  <div class="title">
#  <a href="/bbs/Food/M.1190944426.A.E6C.html">[公告] 發文請在標題加上地區及提供地址電話。^^</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 9/28</div>
#  <div class="author">bluefish</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"></div>
#  <div class="mark">!</div>
#  <div class="title">
#  <a href="/bbs/Food/M.1128132666.A.0FD.html">[公告] 文章被刪除者請洽精華區的資源回收桶</a>
#  </div>
#  <div class="meta">
#  <div class="date">10/01</div>
#  <div class="author">Dilbert</div>
#  </div>
#  </div>, <div class="r-ent">
#  <div class="nrec"><span class="hl f2">4</span></div>
#  <div class="mark">S</div>
#  <div class="title">
#  <a href="/bbs/Food/M.1496532469.A.C36.html">[公告] 新增板規22：發文禁附延伸閱讀連結</a>
#  </div>
#  <div class="meta">
#  <div class="date"> 6/04</div>
#  <div class="author">Dilbert</div>
#  </div>
#  </div>]

# %%
for article in articles:
    meta = article.find('div', 'title').find('a')

    title = meta.getText().strip()
    link = meta.get('href')
    push = article.find('div', 'nrec').getText()
    date = article.find('div', 'date').getText()
    author = article.find('div', 'author').getText()

    print(push, title, date, author)  # result of setp-3
# Out:
#  [食記] 日本 大阪 梨花食堂 天滿本店 好吃咖哩飯  8/02 oldfather
#  [食記] 新竹 語菓 有味道的文青飲料店  8/02 wei9654
#  [食記] 台北天母 on the road義式冰淇淋  8/02 kurosaki1986
#  [食記] 新北永和-自由溫室-超好拍乾燥花餐廳  8/02 redleeve
#  [廣宣] 台北【Thai cook泰酷泰國料理】宵夜開賣  8/02 chenmaggie
#  [食記] 台北 Hooked To Go著迷咖啡 x TAMED FOX  8/02 yucon
#  [食記] 台北市文山區歷史悠久的餐廳-聚酩豐  8/02 fatlee
# 1 [食記] 九州熊本 炸豬排名店勝烈亭-南熊本店  8/02 rueoque
#  [食記] 澳洲墨爾本Rustica Canteen早午餐咖啡  8/02 evisweet
#  [食記] [台中]嘉義阡涼麵：評價很好但嘉義味呢?  8/02 maggie024
#  [食記] 花蓮市區—浪花丸｜沁涼消暑的純正日本冰品  8/02 shinyban
#  [食記] 台中 魚你同在雞蛋糕--創意脆皮雞蛋糕  8/02 nawg
#  [食記] 豐原 格外幸福法式甜點 水果千層蛋糕  8/02 paulyear
#  [食記] 台北信義區 魷魚大叔 起司火焰辣炒年糕  8/02 Farrahliu
# 6 [請益] 尋找北市鯛魚燒(軟厚皮+奶油/紅豆  8/02 tzumio
#  [食記] 台北 剛好的周末來dreamer 38運動酒吧  8/02 takubin
#  [食記] 基隆「豬腳林」原汁口味  8/02 ochiochi777
#  [食記] 北海道 札幌 宵夜聖代懶人包  8/03 smallta
#  [公告] Food板 板規 V3.91 12/16 Dilbert
#  [公告] 板規第3條 增補詳細說明  5/09 Dilbert
# 18 [公告] 發文請在標題加上地區及提供地址電話。^^  9/28 bluefish
#  [公告] 文章被刪除者請洽精華區的資源回收桶 10/01 Dilbert
# 4 [公告] 新增板規22：發文禁附延伸閱讀連結  6/04 Dilbert

# %%
widths = [
        (126,    1), (159,    0), (687,     1), (710,   0), (711,   1),
        (727,    0), (733,    1), (879,     0), (1154,  1), (1161,  0),
        (4347,   1), (4447,   2), (7467,    1), (7521,  0), (8369,  1),
        (8426,   0), (9000,   1), (9002,    2), (11021, 1), (12350, 2),
        (12351,  1), (12438,  2), (12442,   0), (19893, 2), (19967, 1),
        (55203,  2), (63743,  1), (64106,   2), (65039, 1), (65059, 0),
        (65131,  2), (65279,  1), (65376,   2), (65500, 1), (65510, 2),
        (120831, 1), (262141, 2), (1114109, 1),
]


def calc_len(string):
    def chr_width(o):
        global widths
        if o == 0xe or o == 0xf:
            return 0
        for num, wid in widths:
            if o <= num:
                return wid
        return 1
    return sum(chr_width(ord(c)) for c in string)


def pretty_print(push, title, date, author):
    pattern = '%3s\t%s%s%s\t%s'
    padding = ' ' * (50 - calc_len(title))
    print(pattern % (push, title, padding, date, author))
    
for article in articles:
    meta = article.find('div', 'title').find('a')

    title = meta.getText().strip()
    link = meta.get('href')
    push = article.find('div', 'nrec').getText()
    date = article.find('div', 'date').getText()
    author = article.find('div', 'author').getText()

    pretty_print(push, title, date, author)  # result of setp-3
# Out:
#    	[食記] 日本 大阪 梨花食堂 天滿本店 好吃咖哩飯      8/02	oldfather
#    	[食記] 新竹 語菓 有味道的文青飲料店                8/02	wei9654
#    	[食記] 台北天母 on the road義式冰淇淋              8/02	kurosaki1986
#    	[食記] 新北永和-自由溫室-超好拍乾燥花餐廳          8/02	redleeve
#    	[廣宣] 台北【Thai cook泰酷泰國料理】宵夜開賣       8/02	chenmaggie
#    	[食記] 台北 Hooked To Go著迷咖啡 x TAMED FOX       8/02	yucon
#    	[食記] 台北市文山區歷史悠久的餐廳-聚酩豐           8/02	fatlee
#   1	[食記] 九州熊本 炸豬排名店勝烈亭-南熊本店          8/02	rueoque
#    	[食記] 澳洲墨爾本Rustica Canteen早午餐咖啡         8/02	evisweet
#    	[食記] [台中]嘉義阡涼麵：評價很好但嘉義味呢?       8/02	maggie024
#    	[食記] 花蓮市區—浪花丸｜沁涼消暑的純正日本冰品     8/02	shinyban
#    	[食記] 台中 魚你同在雞蛋糕--創意脆皮雞蛋糕         8/02	nawg
#    	[食記] 豐原 格外幸福法式甜點 水果千層蛋糕          8/02	paulyear
#    	[食記] 台北信義區 魷魚大叔 起司火焰辣炒年糕        8/02	Farrahliu
#   6	[請益] 尋找北市鯛魚燒(軟厚皮+奶油/紅豆             8/02	tzumio
#    	[食記] 台北 剛好的周末來dreamer 38運動酒吧         8/02	takubin
#    	[食記] 基隆「豬腳林」原汁口味                      8/02	ochiochi777
#    	[食記] 北海道 札幌 宵夜聖代懶人包                  8/03	smallta
#    	[公告] Food板 板規 V3.91                          12/16	Dilbert
#    	[公告] 板規第3條 增補詳細說明                      5/09	Dilbert
#  18	[公告] 發文請在標題加上地區及提供地址電話。^^      9/28	bluefish
#    	[公告] 文章被刪除者請洽精華區的資源回收桶         10/01	Dilbert
#   4	[公告] 新增板規22：發文禁附延伸閱讀連結            6/04	Dilbert

# %%
controls = soup.find('div', 'btn-group-paging').find_all('a', 'btn')

# %%
import urllib

# %%
INDEX = "https://www.ptt.cc/"
link = controls[1].get('href')
page_url = urllib.parse.urljoin(INDEX, link)
NOT_EXIST = BeautifulSoup('<a>本文已被刪除</a>', 'lxml').a
meta = article.find('div', 'title').find('a') or NOT_EXIST
